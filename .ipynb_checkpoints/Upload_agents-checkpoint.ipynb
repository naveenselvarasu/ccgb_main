# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1JOKToaq1PSyQMK9Q2abDejqlzmKaiGyNH0tzwx3kCds/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(5)
# Out:
#    Sl. NO Agent Code    First Name      Last Name      State        District  \
# 0       1      AG001   Arasashetty  Kongalashetty  Karnataka  Chamarajanagar
# 1       3      AG002  Bangaranaika     Siddanaika  Karnataka  Chamarajanagar
# 2      42      AG003        Dileep         Dileep  Karnataka  Chamarajanagar
# 3       8      AG004       Papanna     H Nanjappa  Karnataka  Chamarajanagar
# 4      17      AG005       Madappa        Gurappa  Karnataka  Chamarajanagar
#
#        Taluk      Hobli            Village  Pincode  ... Cheque No  \
# 0  Gundlupet  Gundlupet      Bheemanabeedu   571111  ...    786951
# 1  Gundlupet  Berambadi         Berambadi    571111  ...    522222
# 2  Gundlupet     xxxxxx             xxxxxx   111111  ...    111111
# 3  Gundlupet  Gundlupet         Hongahalli   571111  ...    162348
# 4  Gundlupet    Hangala  Honnegowdanahalli   571126  ...     51503
#
#         Bank Name     Branch Name  Bank Account Name       Account No  \
# 0     Canara Bank       Gundlupet        Arasashetty    4792101010155
# 1  Syndicate Bank       Gundlupet       Bangaranaika   17072250020799
# 2          xxxxxx          xxxxxx             xxxxxx     111111111111
# 3       Axix Bank  Chamarajanagar       H  N Papanna  917010046024219
# 4  Syndicate Bank       Kannegala            Madappa   17282200012019
#
#      IFSC Code PAN Card Number       Area Agreement Signature   \
# 0  CNRB0004792      BNHPA6388L  Gundlupet           Singnature
# 1  SYNB0001707             NaN  Gundlupet           Singnature
# 2   XXXXXX1111          XXXXXX  Gundlupet                  NaN
# 3  UTIB0000880             NaN  Gundlupet           Singnature
# 4  SYNB0001728      EUJPM9961B  Gundlupet           Singnature
#
#                    备注\nRemark
# 0                         NaN
# 1  Pan Card Copy not Received
# 2                         NaN
# 3  Pan Card copy not received
# 4                         NaN
#
# [5 rows x 23 columns]

# %%
def isNaN(num):
    return num != num

# %%
# Uploading agents int User, UserProfile models

busines = Business.objects.get(id=1)

count = 0
for index, row in df.iterrows():
    count = count+1
    
    print('{}:{}'.format(row['First Name'], row['Agent Code']))
    
    
    user, created = User.objects.get_or_create(
        username=str(row['Contact No']),
        first_name=row['First Name'],
        last_name=row['Last Name'],
        defaults = {
            'is_staff': True,
            'is_active': True,
            'is_superuser': False,
            'password':make_password(str(row['Contact No'])[-4:])
            
        }
    )
    if created:
        print(user.username, 'Count:', count, "\tUser created")
    else:
        print(user.username, 'Count:', count, "\tUser existed already")
        
        
    
    # Add new hobli if not available already
    if not Hobli.objects.filter(name=row['Hobli']).exists():
        hobli, created = Hobli.objects.get_or_create(
            name=str(row['Hobli']),
            taluk=Taluk.objects.get(name=row['Taluk']),
            defaults = {
            }
        )
        if created:
            print("\t", hobli.name, "\tHobli created")
        else:
            print("\t", hobli.name, 'Count:', "\tHobli existed already")
    
    village_name=row['Village'].rstrip(' ')
    village, created = Village.objects.get_or_create(
            name=str(village_name),
            hobli=Hobli.objects.get(name=row['Hobli']),
            defaults = {
            }
    )
    if created:
        print("\t", village.name, "\tVillage created")
    else:
        print("\t", village.name, "\tVillage existed already")
        
        
            
        
    
    user_profile, created = UserProfile.objects.update_or_create(
        user=user,
        business=Business.objects.get(id=1),
        defaults = {
            'code':row['Agent Code'],
            'user_type': UserType.objects.get(name='Agent'),
            'gender': Gender.objects.get(name='Male'),
            # 'dob':,
            'mobile':row['Contact No'],
            # 'alternate_mobile':,
            # 'email':,
            'address':row['Address'],
            'state':State.objects.get(name=row['State']),
            'district':District.objects.get(name=row['District']),
            'taluk':Taluk.objects.get(name=row['Taluk']),
            'hobli':Hobli.objects.get(name=row['Hobli']),
            'village':village,
            'pincode':row['Pincode'],
            #'educational_qualification':,
            #'institution_name':row[''],
            #'university_name':row[''],
            'aadhaar_number':row['ID Prof NO'],
            #'aadhaar_document':row[''],
            'pan_number':row['PAN Card Number'],
            #'pan_document':row[''],
            #'driving_licence_document':row[''],
            #'agreement_document':row[''],
            #'prior_experience_in_other_company':row[''],
            #'prior_experience_company_name':row[''],
            #'prior_experience_duration':row[''],
            #'collaborated_with_company_on':row[''],
            
            #'latitude':row[''],
            #'longitude':row[''],
            'created_by':User.objects.get(id=13),
            'modified_by':User.objects.get(id=13)
        }
    )
    if created:
        print("\t\tUser Profile Created")
    else:
        print("\t\t\tUser Profile existed already:" + str(user_profile.id))
        
    
    # Add bank details for Agent
    user_bank, created = UserBankDetails.objects.get_or_create(
        user=user,
        bank=row['Bank Name'],
        branch=row['Branch Name'],
        ifsc_code=row['IFSC Code'],
        account_holder_name=row['Bank Account Name'],
        account_number=row['Account No'],
        post_cheque_number=row['Cheque No'],
        defaults = {
            'created_by':User.objects.get(id=13),
            'modified_by':User.objects.get(id=13)    
        }
    )
    if created:
        print("\t\t\tUser Bank  Created")
    else:
        print("\t\t\tUser Bank existed already")
      
    
    # User Office info for agent
    agent_office, created = AgentOffice.objects.get_or_create(
        user=user,
        business=Business.objects.get(id=1),
        name='Office of' + row['First Name'],
        mobile=row['Contact No'],
        pincode=row['Pincode'],
        defaults = {
            'created_by':User.objects.get(id=13),
            'modified_by':User.objects.get(id=13)    
        }
    )
    if created:
        print("\t\t\tUser Office  Created")
    else:
        print("\t\t\tUser Office existed already")
# Out:
# Arasashetty:AG001
# 8217357218 Count: 1 	User existed already
# 	 Bheemanabeedu 	Village existed already
# 			User Profile existed already:32
# 			User Bank existed already
# 			User Office existed already
# Bangaranaika:AG002
# 9980310639 Count: 2 	User existed already
# 	 Berambadi 	Village existed already
# 			User Profile existed already:33
# 			User Bank existed already
# 			User Office existed already
# Dileep:AG003
# 1111111111 Count: 3 	User existed already
# 	 xxxxxx 	Village created
# 			User Profile existed already:34
# 			User Bank existed already
# 			User Office existed already
# Papanna:AG004
# 9945675534 Count: 4 	User existed already
# 	 Hongahalli 	Village created
# 			User Profile existed already:35
# 			User Bank existed already
# 			User Office existed already
# Madappa:AG005
# 8548092445 Count: 5 	User existed already
# 	 Honnegowdanahalli 	Village created
# 			User Profile existed already:36
# 			User Bank existed already
# 			User Office existed already
# Madappa:AG006
# 9108390550 Count: 6 	User existed already
# 	 Kunagahalli 	Village created
# 			User Profile existed already:37
# 			User Bank existed already
# 			User Office existed already
# Mahadeva Prasad:AG007
# 9845488754 Count: 7 	User existed already
# 	 Berambadi 	Village existed already
# 			User Profile existed already:38
# 			User Bank existed already
# 			User Office existed already
# Mahadevaswamy:AG008
# 9632076751 Count: 8 	User existed already
# 	 Hongahalli 	Village existed already
# 			User Profile existed already:39
# 			User Bank existed already
# 			User Office existed already
# Manikanta :AG009
# 9743908690 Count: 9 	User existed already
# 	 Channamallipura  Maddur 	Village created
# 			User Profile existed already:40
# 			User Bank existed already
# 			User Office existed already
# Shanidevara Murthy:AG010
# 9900906681 Count: 10 	User existed already
# 	 Berambadi 	Village existed already
# 			User Profile existed already:41
# 			User Bank existed already
# 			User Office existed already
# Shivamahadevu:AG011
# 9611664134 Count: 11 	User existed already
# 	 Berambadi 	Village existed already
# 			User Profile existed already:42
# 			User Bank existed already
# 			User Office existed already
# Chandrashekhararadya:AG012
# 9632820922 Count: 12 	User existed already
# 	 Ballurundi 	Village created
# 			User Profile existed already:43
# 			User Bank existed already
# 			User Office existed already
# Gopala:AG013
# 7406990508 Count: 13 	User existed already
# 	 Bankahalli 	Village created
# 			User Profile existed already:44
# 			User Bank existed already
# 			User Office existed already
# Kumaraswamy:AG014
# 9880838227 Count: 14 	User existed already
# 	 Aralikatte 	Village created
# 			User Profile existed already:45
# 			User Bank existed already
# 			User Office existed already
# Mahesha:AG015
# 7026921888 Count: 15 	User existed already
# 	 Kethahalli , Mudnakudu, Chamarajanagar 	Village created
# 			User Profile existed already:46
# 			User Bank existed already
# 			User Office existed already
# Manjesh:AG016
# 9164262016 Count: 16 	User existed already
# 	 Mallahalli 	Village created
# 			User Profile existed already:47
# 			User Bank existed already
# 			User Office existed already
# Manu:AG017
# 7259919705 Count: 17 	User existed already
# 	 Uganedahundi  Udigala 	Village created
# 			User Profile existed already:48
# 			User Bank existed already
# 			User Office existed already
# Ranga Swamy:AG018
# 9743165940 Count: 18 	User existed already
# 	 Doddakavalande Nerle 	Village created
# 			User Profile existed already:49
# 			User Bank existed already
# 			User Office existed already
# Chandrappa:AG019
# 9741650872 Count: 19 	User existed already
# 	 Kodasoge 	Village created
# 			User Profile existed already:50
# 			User Bank existed already
# 			User Office existed already
# Shivappa:AG020
# 9626341827 Count: 20 	User existed already
# 	 3/142  , Lingayath street Igglore 	Village created
# 			User Profile existed already:51
# 			User Bank existed already
# 			User Office existed already
# Mahesha :AG021
# 9964757811 Count: 21 	User existed already
# 	 Depapura 	Village created
# 			User Profile existed already:52
# 			User Bank existed already
# 			User Office existed already
# Mahesha 01:AG022
# 1111111112 Count: 22 	User existed already
# 	 xxxxxx 	Village existed already
# 			User Profile existed already:53
# 			User Bank existed already
# 			User Office existed already
# Mahesha M:AG023
# 6361760906 Count: 23 	User existed already
# 	 Basaveswara Temple Street 	Village created
# 			User Profile existed already:54
# 			User Bank existed already
# 			User Office existed already
# Nanjundanayaka:AG024
# 9606014675 Count: 24 	User existed already
# 	 Yanagahalli 	Village created
# 			User Profile existed already:55
# 			User Bank existed already
# 			User Office existed already
# Rajashekhara Murthy:AG025
# 9844426251 Count: 25 	User existed already
# 	 Depapura Post, Sheelavanthapura 	Village created
# 			User Profile existed already:56
# 			User Bank existed already
# 			User Office existed already
# Basavanna:AG026
# 9964162912 Count: 26 	User existed already
# 	 S/o Shivabasappa, Harve Hobali, Sagade , Chamarajanagar 	Village created
# 			User Profile existed already:57
# 			User Bank existed already
# 			User Office existed already
# Shivamadu:AG027
# 1111111115 Count: 27 	User existed already
# 	 xxxxxx 	Village existed already
# 			User Profile existed already:58
# 			User Bank existed already
# 			User Office existed already
# Muruga:AG028
# 9449203315 Count: 28 	User existed already
# 	 #342 , Terakanambihundi 	Village created
# 			User Profile existed already:59
# 			User Bank existed already
# 			User Office existed already
# Nataraju:AG029
# 9731359912 Count: 29 	User existed already
# 	 #45 Sagade 	Village created
# 			User Profile existed already:60
# 			User Bank existed already
# 			User Office existed already
# Shivakumar:AG030
# 9663901004 Count: 30 	User existed already
# 	 Kothalavadi 	Village created
# 			User Profile existed already:61
# 			User Bank existed already
# 			User Office existed already
# Subramaniam  :AG031
# 9443945485 Count: 31 	User existed already
# 	 209, Patramangalam , Pudupeerkadavu 	Village created
# 			User Profile existed already:62
# 			User Bank existed already
# 			User Office existed already
# Mahadevaswamy :AG032
# 9964143368 Count: 32 	User existed already
# 	 Sriramabadavane, 1st Ward Sargur town 	Village created
# 			User Profile existed already:63
# 			User Bank existed already
# 			User Office existed already
# Parameswaran:AG033
# 9738080982 Count: 33 	User existed already
# 	 53 Kuvempunagar 	Village created
# 			User Profile existed already:64
# 			User Bank existed already
# 			User Office existed already
# Mahesh:AG034
# 8722866490 Count: 34 	User existed already
# 	 Sagare 	Village created
# 			User Profile existed already:65
# 			User Bank existed already
# 			User Office existed already
# Nagaraju Naika:AG035
# 9164855585 Count: 35 	User existed already
# 	 #28, Bavikere, B. Matakere Post 	Village created
# 			User Profile existed already:66
# 			User Bank existed already
# 			User Office existed already
# Nagendra:AG036
# 9731216125 Count: 36 	User existed already
# 	 Thumbasoge Post, Thoravally 	Village created
# 			User Profile existed already:67
# 			User Bank existed already
# 			User Office existed already
# Lokanatha:AG037
# 9944318848 Count: 37 	User existed already
# 	 Kandayyanapalya, Lokkanahalli 	Village created
# 			User Profile existed already:68
# 			User Bank existed already
# 			User Office existed already
# Mahammed Saleem Pasha:AG038
# 9731636749 Count: 38 	User existed already
# 	 Pasha M M hills Road 	Village created
# 			User Profile existed already:69
# 			User Bank existed already
# 			User Office existed already
# Roopendra Kumar:AG039
# 7353104238 Count: 39 	User existed already
# 	 #63 Uppara Street, Lokkanahalli 	Village created
# 			User Profile existed already:70
# 			User Bank existed already
# 			User Office existed already
# Venkatesha:AG040
# 9844840856 Count: 40 	User existed already
# 	 Uppara Street, Doddinduvadi 	Village created
# 			User Profile existed already:71
# 			User Bank existed already
# 			User Office existed already
# Basappa:AG041
# 9632034111 Count: 41 	User existed already
# 	 Bargi 	Village created
# 			User Profile existed already:72
# 			User Bank existed already
# 			User Office existed already
# Maheshappa:AG042
# 8971034363 Count: 42 	User existed already
# 	 Bargi 	Village existed already
# 			User Profile existed already:73
# 			User Bank existed already
# 			User Office existed already
# Nagappa:AG043
# 9663958671 Count: 43 	User existed already
# 	 Bargi 	Village existed already
# 			User Profile existed already:74
# 			User Bank existed already
# 			User Office existed already
# Mahesh:AG044
# 9008791197 Count: 44 	User existed already
# 	 Yariyooru 	Village created
# 			User Profile existed already:75
# 			User Bank existed already
# 			User Office existed already

# %%
busines = Business.objects.get(id=1)

# %%
busines
# Out:
# <Business: 1-ccgb>

# %%
'rerere   '.rstrip(' ')
# Out:
# 'rerere'
