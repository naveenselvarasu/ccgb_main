# %%
import pandas as pd
import datetime
from pytz import timezone
import pandas as pd
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', None)  
import calendar
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1n2s8F6PPgXXwMRMlhlY30RJKV5hjPZyn3cQkufIWx-0/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(5)
# Out:
#    Sl. No  Rl. No Old Agent/New Agent Distribution/Return       Date  \
# 0      17      55           Old Agent        Distribution  26/2/2021
# 1      32      70           Old Agent        Distribution  26/2/2021
# 2      39      18           Old Agent        Distribution  27/2/2021
# 3      41      72           Old Agent        Distribution  27/2/2021
# 4      63      33           Old Agent        Distribution   2/3/2021
#
#               Agent Name Agent Code       Village Name  Supervisor Name  \
# 0              Kemparaju       110B          Gopalpura               22
# 1  Shanidevaramurthy B K      AG010          Berambadi               22
# 2                Madappa      AG005  Honnegowdanahalli               22
# 3              Kemparaju       110B          Gopalpura               22
# 4     Mahadevaprasad B S      AG007          Berambadi               22
#
#   Cluster Name  ...  100 pkts  Acre  From.1  To.1  50pkts  Acre.1  Total Acre  \
# 0    Berambadi  ...        75    75     641   690      50      25         100
# 1    Berambadi  ...        20    20    1231  1240      10       5          25
# 2    Berambadi  ...        75    75    1371  1420      50      25         100
# 3    Berambadi  ...        30    30       0     0       0       0          30
# 4    Berambadi  ...        50    50    1861  1900      40      20          70
#
#    Amount (Rs)  Signature Balance (Agent/Supervisor)  Remarks
# 0       230000                             Completed      NaN
# 1        57500                             Completed      NaN
# 2       230000                             Completed      NaN
# 3        69000                             Completed      NaN
# 4       161000                             Completed      NaN
#
# [5 rows x 22 columns]

# %%
from django.db import transaction
@transaction.atomic
def register_combo_issue_request():
    sid = transaction.savepoint()
    df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y', errors='ignore')
    try:
        for index, row in df.iterrows():
            agent_id = UserProfile.objects.get(code=row['Agent Code']).user.id
            if not ComboIssueRequest.objects.filter(input_combo_id=8,  issue_rised_date=row['Date'],  supervisor_id=row['Supervisor Name']):
                combo_request_obj_full = ComboIssueRequest(request_code=generate_request_code(8),
                                    season_id=3,
                                    input_combo_id=8,
                                    quantity_in_numbers=0,
                                    quantity_for_area=0,
                                    expected_date=row['Date'],
                                    issue_rised_date=row['Date'],
                                    max_status_id=2,
                                    max_status_date=row['Date'],
                                    supervisor_id=row['Supervisor Name'])
            
                combo_request_obj_full.save()
                print(row['Agent Code'] , 'created 100 grams')
            else:
                combo_request_obj_full = ComboIssueRequest.objects.get(input_combo_id=8,  issue_rised_date=row['Date'],  supervisor_id=row['Supervisor Name'])
            if not ComboIssueRequest.objects.filter(input_combo_id=9,  issue_rised_date=row['Date'],  supervisor_id=row['Supervisor Name']).exists():
                combo_request_obj_half = ComboIssueRequest(request_code=generate_request_code(9),
                                    season_id=3,
                                    input_combo_id=9,
                                    quantity_in_numbers=0,
                                    quantity_for_area=0,
                                    expected_date=row['Date'],
                                    issue_rised_date=row['Date'],
                                    max_status_id=2,
                                    max_status_date=row['Date'],
                                    supervisor_id=row['Supervisor Name'])
            
                combo_request_obj_half.save()
                print(row['Agent Code'] , 'created 50 grams')
            else:
                combo_request_obj
    class Meta:
        unique_together = (("business", "season","user_type", "prefix_code"),)_half = ComboIssueRequest.objects.get(input_combo_id=9,  issue_rised_date=row['Date'],  supervisor_id=row['Supervisor Name'])
            
            if not ComboIssueRequestAgentMap.objects.filter(combo_issue_request=combo_request_obj_full, agent_id=agent_id).exists():
                combo_request_agent_obj = ComboIssueRequestAgentMap(combo_issue_request=combo_request_obj_full,
                                                                    agent_id=agent_id, 
                                                                    issue_rised_date=combo_request_obj_full.issue_rised_date,
                                                                    quantity_in_numbers=row['100 pkts'],
                                                                    max_status_id=2)

                combo_request_agent_obj.save()
                print('agent for full')
                old_req = combo_request_obj_full.quantity_in_numbers
                combo_request_obj_full.quantity_in_numbers = old_req + row['100 pkts']
                combo_request_obj_full.save()
            
            if not ComboIssueRequestAgentMap.objects.filter(combo_issue_request=combo_request_obj_half, agent_id=agent_id).exists():
                combo_request_agent_obj = ComboIssueRequestAgentMap(combo_issue_request=combo_request_obj_half,
                                                                    agent_id=agent_id, 
                                                                    issue_rised_date=combo_request_obj_half.issue_rised_date,
                                                                    quantity_in_numbers=row['50pkts'],
                                                                    max_status_id=2)

                combo_request_agent_obj.save()
                print(print('agent for half'))
                old_half_req = combo_request_obj_half.quantity_in_numbers
                combo_request_obj_half.quantity_in_numbers = old_half_req + row['50pkts']
                combo_request_obj_half.save()
                
        transaction.savepoint_commit(sid)
    except Exception as e:
        print('error on {}'.format(e))
        transaction.savepoint_rollback(sid)
register_combo_issue_request()
# Out:
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-02-27 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-02 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-05 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-02 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-02 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-02 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# AG041 created 100 grams
# AG041 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG041 created 100 grams
# AG041 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG043 created 100 grams
# AG043 created 50 grams
# agent for full
# agent for half
# None
# AG013 created 100 grams
# AG013 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG013 created 100 grams
# AG013 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-02-27 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-02-27 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-02-27 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-06 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-08 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-08 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-08 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-08 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# AG045 created 100 grams
# AG045 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG016 created 100 grams
# AG016 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG013 created 100 grams
# AG013 created 50 grams
# agent for full
# agent for half
# None
# AG028T created 100 grams
# AG028T created 50 grams
# agent for full
# agent for half
# None
# AG030 created 100 grams
# AG030 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG029 created 100 grams
# AG029 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG033S created 100 grams
# AG033S created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# 137 created 100 grams
# 137 created 50 grams
# agent for full
# agent for half
# None
# AG050 created 100 grams
# AG050 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG035 created 100 grams
# AG035 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# 135 created 100 grams
# 135 created 50 grams
# agent for full
# agent for half
# None
# AG019 created 100 grams
# AG019 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG049 created 100 grams
# AG049 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# 17 created 100 grams
# 17 created 50 grams
# agent for full
# agent for half
# None
# AG033H created 100 grams
# AG033H created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG051 created 100 grams
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# AG051 created 50 grams
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# agent for full
# agent for half
# None
# AG047 created 100 grams
# AG047 created 50 grams
# agent for full
# agent for half
# None
# 139 created 100 grams
# 139 created 50 grams
# agent for full
# agent for half
# None
# AG033H created 100 grams
# AG033H created 50 grams
# agent for full
# agent for half
# None

# %%
def generate_request_code(input_combo_id):
    code_bank_obj = ComboIssueRequestCodeBank.objects.filter(input_combo_id=input_combo_id)[0]
    last_digit_code = code_bank_obj.last_digit
    new_code = last_digit_code + 1
    value = str(code_bank_obj.input_combo.name) + str(new_code).zfill(3)
    code_bank_obj.last_digit = new_code
    code_bank_obj.save()
    return value

# %%
 for index, row in df.iterrows():
        print(row['Date'])
# Out:
# 26/2/2021
# 26/2/2021
# 27/2/2021
# 27/2/2021
# 2/3/2021
# 3/3/2021
# 5/3/2021
# 5/3/2021

# %%
AgentFarmerMap.objects.filter(agent_id=57).update(agent_id=41)
# Out:
# 168

# %%
UserProfileCodeBank.objects.filter()
# Out:
# <QuerySet [<UserProfileCodeBank: UserProfileCodeBank object>]>

# %%
for farmer in Farmer.objects.filter().order_by('time_created'):
    code_bank_obj = FarmerCodeBank.objects.get(id=1)
    last_count = code_bank_obj.last_count
    prefix = code_bank_obj.prefix_code
    print(farmer_code_autogenraion(last_count, prefix))
    farmer.common_code = farmer_code_autogenraion(last_count, prefix)
    farmer.save()
# Out:
# FA0001
# FA0002
# FA0003
# FA0004
# FA0005
# FA0006
# FA0007
# FA0008
# FA0009
# FA0010
# FA0011
# FA0012
# FA0013
# FA0014
# FA0015
# FA0016
# FA0017
# FA0018
# FA0019
# FA0020
# FA0021
# FA0022
# FA0023
# FA0024
# FA0025
# FA0026
# FA0027
# FA0028
# FA0029
# FA0030
# FA0031
# FA0032
# FA0033
# FA0034
# FA0035
# FA0036
# FA0037
# FA0038
# FA0039
# FA0040
# FA0041
# FA0042
# FA0043
# FA0044
# FA0045
# FA0046
# FA0047
# FA0048
# FA0049
# FA0050
# FA0051
# FA0052
# FA0053
# FA0054
# FA0055
# FA0056
# FA0057
# FA0058
# FA0059
# FA0060
# FA0061
# FA0062
# FA0063
# FA0064
# FA0065
# FA0066
# FA0067
# FA0068
# FA0069
# FA0070
# FA0071
# FA0072
# FA0073
# FA0074
# FA0075
# FA0076
# FA0077
# FA0078
# FA0079
# FA5939

# %%
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=1):
    farmer.seasonal_farmer_code =  '19' + farmer.farmer.code[2:]
    farmer.save()
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=2):
    farmer.seasonal_farmer_code =  farmer.farmer.code
    farmer.save()

# %%
'19'+FarmerClusterSeasonMap.objects.filter(season_id=2)[0].seasonal_farmer_code[2:]
# Out:
# '19BAM010'

# %%
FarmerClusterSeasonMap.objects.filter().count()
# Out:
# 5825

# %%
2603+3219
# Out:
# 5822

# %%
UserClusterMap.objects.filter(season_id=3, user__userprofile__user_type_id=5,user__username='naveen')[0].id
# Out:
# 415

# %%
Cluster.objects.filter
# Out:
# <bound method BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method of <django.db.models.manager.Manager object at 0x7f7ec10fe1f0>>

# %%
master_dict = {}
master_dict['all_clusters'] = []
master_dict['current_season_clusters'] = []
season_id=3
current_season_cluster_ids = list(ClusterSeasonMap.objects.filter(season_id=season_id).values_list('cluster_id',flat=True))
master_dict['all_clusters'] = list(Cluster.objects.filter().values())
master_dict['clusters_not_included_for_this_season'] = list(Cluster.objects.filter().exclude(id__in=current_season_cluster_ids).values())
master_dict['current_season_clusters'] = list(Cluster.objects.filter(id__in=current_season_cluster_ids).values())
master_dict
# Out:
# {'all_clusters': [{'id': 1, 'name': 'Berambadi', 'notes': 'Gundlupet Zone'},
#   {'id': 2, 'name': 'Terakanambi', 'notes': 'Gundlupet Zone'},
#   {'id': 3, 'name': 'Bommanahalli', 'notes': 'Gundlupet Zone'},
#   {'id': 5, 'name': 'Yadalaya', 'notes': 'Sargur Zone'},
#   {'id': 7, 'name': 'HD Kote', 'notes': 'Sargur Zone'},
#   {'id': 8, 'name': 'Nanjangud', 'notes': 'Sargur Zone'},
#   {'id': 4, 'name': 'Baragi', 'notes': 'Gundlupet Zone'},
#   {'id': 6, 'name': 'Sargur', 'notes': 'Sargur Zone'},
#   {'id': 9, 'name': 'Talavadi', 'notes': 'talavadi'},
#   {'id': 10, 'name': 'masinakudi', 'notes': 'masinakudi'}],
#  'current_season_clusters': [{'id': 1,
#    'name': 'Berambadi',
#    'notes': 'Gundlupet Zone'},
#   {'id': 2, 'name': 'Terakanambi', 'notes': 'Gundlupet Zone'},
#   {'id': 3, 'name': 'Bommanahalli', 'notes': 'Gundlupet Zone'},
#   {'id': 5, 'name': 'Yadalaya', 'notes': 'Sargur Zone'},
#   {'id': 7, 'name': 'HD Kote', 'notes': 'Sargur Zone'},
#   {'id': 8, 'name': 'Nanjangud', 'notes': 'Sargur Zone'},
#   {'id': 4, 'name': 'Baragi', 'notes': 'Gundlupet Zone'},
#   {'id': 6, 'name': 'Sargur', 'notes': 'Sargur Zone'},
#   {'id': 9, 'name': 'Talavadi', 'notes': 'talavadi'},
#   {'id': 10, 'name': 'masinakudi', 'notes': 'masinakudi'}],
#  'clusters_not_included_for_this_season': []}

# %%
season_id=3
UserClusterMap.objects.filter(season_id=season_id, user__userprofile__user_type_id=5).count()
# Out:
# 8

# %%
import pandas as pd
master_dict = {}
season_id=3
user_type_id = 6
current_season_users = list(UserClusterMap.objects.filter(season_id=season_id, user__userprofile__user_type_id=user_type_id).values_list('user_id', flat=True))
active_users = list(User.objects.filter(id__in=current_season_users).values_list('id', 'username'))
active_users_columns = ['id','name']
active_users_df = pd.DataFrame(active_users, columns=active_users_columns)

positions = list(PositionManUserMap.objects.filter().values_list('user_id',flat=True))
inactive_users = User.objects.filter(userprofile__user_type_id=user_type_id).exclude(id__in=current_season_users)
inactive_users = list(inactive_users.exclude(id__in=positions).values_list('id', flat=True))
in_active_users = list(User.objects.filter(id__in=inactive_users).values_list('id', 'username'))
in_active_users_columns = ['id','name']
in_active_users_df = pd.DataFrame(in_active_users, columns=in_active_users_columns)

master_dict['current_season_clusters'] = active_users_df.to_dict('r')

master_dict['inactive_users'] = in_active_users_df.to_dict('r')
master_dict
# Out:
# {'current_season_clusters': [{'id': 33, 'name': '1111111111'},
#   {'id': 45, 'name': '7026921888'},
#   {'id': 52, 'name': '1111111112'},
#   {'id': 42, 'name': '9632820922'},
#   {'id': 37, 'name': '9845488754'},
#   {'id': 43, 'name': '7406990508'},
#   {'id': 48, 'name': '9743165940'},
#   {'id': 41, 'name': '9611664134'},
#   {'id': 40, 'name': '9900906681'},
#   {'id': 46, 'name': '9164262016'},
#   {'id': 38, 'name': '9632076751'},
#   {'id': 36, 'name': '9108390550'},
#   {'id': 34, 'name': '9945675534'},
#   {'id': 39, 'name': '9743908690'},
#   {'id': 53, 'name': '6361760906'},
#   {'id': 54, 'name': '9606014675'},
#   {'id': 35, 'name': '8548092445'},
#   {'id': 51, 'name': '9964757811'},
#   {'id': 31, 'name': '8217357218'},
#   {'id': 32, 'name': '9980310639'},
#   {'id': 47, 'name': '7259919705'},
#   {'id': 61, 'name': '9443945485'},
#   {'id': 66, 'name': '9731216125'},
#   {'id': 88, 'name': 'ccgb_kollegala'},
#   {'id': 63, 'name': '09738080982'},
#   {'id': 50, 'name': '9626341827'},
#   {'id': 49, 'name': '9741650872'},
#   {'id': 86, 'name': 'ccgb_gundlupet_2'},
#   {'id': 64, 'name': '8722866490'},
#   {'id': 60, 'name': '9663901004'},
#   {'id': 59, 'name': '9731359912'},
#   {'id': 44, 'name': '9880838227'},
#   {'id': 77, 'name': '1111111116'},
#   {'id': 65, 'name': '9164855585'},
#   {'id': 73, 'name': '9663958671'},
#   {'id': 72, 'name': '8971034363'},
#   {'id': 56, 'name': '9964162912'},
#   {'id': 71, 'name': '9632034111'},
#   {'id': 62, 'name': '9964143368'},
#   {'id': 114, 'name': '1234556132'},
#   {'id': 111, 'name': '3648666854'},
#   {'id': 126, 'name': '09741650872'},
#   {'id': 124, 'name': '09663958671'},
#   {'id': 103, 'name': '9991112223'},
#   {'id': 107, 'name': '9611937238'},
#   {'id': 74, 'name': '9008791197'},
#   {'id': 89, 'name': 'ccgb_nanjangud'},
#   {'id': 91, 'name': 'ccgb_sargur_ch_nagar'},
#   {'id': 90, 'name': 'ccgb_sargur'},
#   {'id': 87, 'name': 'ccgb_hanoor'},
#   {'id': 85, 'name': 'ccgb_gundlupet'},
#   {'id': 58, 'name': '09449203315'},
#   {'id': 55, 'name': '9844426251'},
#   {'id': 125, 'name': '9731116332'},
#   {'id': 121, 'name': '1234512347'},
#   {'id': 109, 'name': '4343234322'},
#   {'id': 112, 'name': '7634736526'},
#   {'id': 113, 'name': '4354535323'},
#   {'id': 104, 'name': '1232174034'},
#   {'id': 117, 'name': '8884306058'},
#   {'id': 123, 'name': '9900914192'},
#   {'id': 106, 'name': '9902235560'},
#   {'id': 110, 'name': '01234512347'},
#   {'id': 122, 'name': '9738080982'},
#   {'id': 118, 'name': '9880769480'},
#   {'id': 134, 'name': '9980661837'},
#   {'id': 135, 'name': '9900695224'},
#   {'id': 138, 'name': '1234567912'},
#   {'id': 146, 'name': '9159344255'},
#   {'id': 145, 'name': '9632499326'},
#   {'id': 137, 'name': '1234567891'},
#   {'id': 127, 'name': '1234567890'},
#   {'id': 139, 'name': '8861650010'},
#   {'id': 140, 'name': '8494824676'},
#   {'id': 141, 'name': '8151835533'},
#   {'id': 142, 'name': '9019108583'},
#   {'id': 143, 'name': '9902945452'},
#   {'id': 144, 'name': '7406595718'},
#   {'id': 120, 'name': '9449203315'},
#   {'id': 148, 'name': '2332434323'}],
#  'inactive_users': [{'id': 67, 'name': '9944318848'},
#   {'id': 70, 'name': '9844840856'},
#   {'id': 69, 'name': '7353104238'},
#   {'id': 68, 'name': '9731636749'}]}

# %%
# Out:
# <QuerySet [(9,), (81,), (10,), (11,), (19,), (15,), (18,), (13,), (84,), (21,), (14,), (16,), (115,), (17,), (20,), (128,), (132,)]>

# %%
User.objects.filter(id=149)[0]
# Out:
# <User: 4223432432>

# %%
current_agent_list = list(AgentSupervisorSeasonMap.objects.filter(season_id=3).values_list('agent_id', flat=True))
current_agent_list
# Out:
# [41,
#  40,
#  38,
#  36,
#  34,
#  39,
#  35,
#  31,
#  32,
#  88,
#  77,
#  111,
#  121,
#  43,
#  48,
#  46,
#  44,
#  85,
#  58,
#  104,
#  123,
#  106,
#  110,
#  140,
#  73,
#  72,
#  71,
#  124,
#  143,
#  51,
#  50,
#  49,
#  86,
#  126,
#  107,
#  74,
#  89,
#  55,
#  125,
#  117,
#  118,
#  144,
#  63,
#  114,
#  91,
#  87,
#  113,
#  134,
#  145,
#  141,
#  142,
#  53,
#  47,
#  60,
#  59,
#  56,
#  103,
#  138,
#  146,
#  120,
#  54,
#  64,
#  65,
#  62,
#  90,
#  109,
#  112,
#  122,
#  135,
#  137,
#  139,
#  37]

# %%
UserProfile.objects.filter(user_type_id=6).exclude(user_id__in=current_agent_list).count()
# Out:
# 12

# %%
import pandas as pd
supervisor_id=22
master_dict = {}
season_id = 3

current_agent_list = list(AgentSupervisorSeasonMap.objects.filter(season_id=3).values_list('agent_id', flat=True))
un_active_users = list(UserProfile.objects.filter(user_type_id=6).exclude(user_id__in=current_agent_list).values_list('user_id', 'user__first_name', 'user__last_name'))
un_active_users_columns = ['user_id', 'first_name', 'last_name']
un_active_users_df = pd.DataFrame(un_active_users, columns=un_active_users_columns)
master_dict['in_active'] = un_active_users_df.to_dict('r')

active_users = list(AgentSupervisorSeasonMap.objects.filter(supervisor_id=supervisor_id, season_id=season_id).values_list('agent_id', 'agent__first_name', 'agent__last_name'))
active_users_columns = ['user_id', 'first_name', 'last_name']
active_users_df = pd.DataFrame(active_users, columns=active_users_columns)
master_dict['active']=active_users_df.to_dict('r')
master_dict
# Out:
# {'in_active': [{'user_id': 33, 'first_name': 'Dileep', 'last_name': 'Dileep'},
#   {'user_id': 45, 'first_name': 'Mahesha', 'last_name': 'Basavarajappa'},
#   {'user_id': 52, 'first_name': 'Mahesha 01', 'last_name': 'Mahesa 01'},
#   {'user_id': 42,
#    'first_name': 'Chandrashekhararadya',
#    'last_name': 'Channaveeraradya'},
#   {'user_id': 61, 'first_name': 'Subramaniam  ', 'last_name': 'Kariyakavudar'},
#   {'user_id': 66, 'first_name': 'Nagendra', 'last_name': 'nan'},
#   {'user_id': 67, 'first_name': 'Lokanatha', 'last_name': 'Muthuswamy'},
#   {'user_id': 70, 'first_name': 'Venkatesha', 'last_name': 'Doddarangashetty'},
#   {'user_id': 69,
#    'first_name': 'Roopendra Kumar',
#    'last_name': 'Kullurashetty'},
#   {'user_id': 68,
#    'first_name': 'Mahammed Saleem Pasha',
#    'last_name': 'B Anvar'},
#   {'user_id': 127, 'first_name': 'Shankara B P', 'last_name': 'Puttamadaiah'},
#   {'user_id': 148, 'first_name': 'fsadfs', 'last_name': 'dsfa'}],
#  'active': [{'user_id': 37,
#    'first_name': 'Mahadevaprasad B S',
#    'last_name': 'Siddappa'},
#   {'user_id': 41, 'first_name': 'Shivamahadevu', 'last_name': 'Mudalagiriah'},
#   {'user_id': 40,
#    'first_name': 'Shanidevara Murthy B K',
#    'last_name': 'Krishnaiah'},
#   {'user_id': 38,
#    'first_name': 'H B Mahadevaswamy',
#    'last_name': 'H M Basavanna'},
#   {'user_id': 36, 'first_name': 'Madappa G B', 'last_name': 'Bellappa'},
#   {'user_id': 34, 'first_name': 'H N Papanna', 'last_name': 'Nanjappa'},
#   {'user_id': 39, 'first_name': 'Manikanta ', 'last_name': 'Shivalingappa'},
#   {'user_id': 35, 'first_name': 'Madappa', 'last_name': 'Gurappa'},
#   {'user_id': 31, 'first_name': 'Arasashetty', 'last_name': 'Kongalashetty'},
#   {'user_id': 32, 'first_name': 'Bangaranaika', 'last_name': 'Siddanaika'},
#   {'user_id': 88, 'first_name': 'Mahendra', 'last_name': 'Nagarajappa'},
#   {'user_id': 77, 'first_name': 'Mahadevappa', 'last_name': 'Ningappa'},
#   {'user_id': 111, 'first_name': 'Basavashetty', 'last_name': 'Rajashetty'},
#   {'user_id': 121,
#    'first_name': 'Kemparaju_Beerambadi',
#    'last_name': 'Madappa'}]}

# %%
user_type_id = 92
master_dict = {}
import pandas as pd
subordinates = UserHierarchyMap.objects.filter(superior_id=user_type_id)
subordinate_user_ids = list(subordinates.values_list("subordinate", flat=True))

all_subordinates = UserHierarchyMap.objects.filter(superior_user_type_id=3)
all_subordinate_user_ids = list(all_subordinates.values_list("subordinate", flat=True))

active_users = list(UserProfile.objects.filter(user_id__in=subordinate_user_ids).values_list('user_id', 'user__username', 'user__last_name'))
active_users_columns = ['user_id', 'first_name', 'last_name']
active_users_df = pd.DataFrame(active_users, columns=active_users_columns)
master_dict['active'] = active_users_df.to_dict('r')


position_users = list(PositionManUserMap.objects.filter(user__userprofile__user_type_id=5).values_list('user_id',flat=True))
users = UserProfile.objects.filter(user_type_id=5).exclude(user_id__in=all_subordinate_user_ids)
in_active_users = list(users.exclude(user_id__in=position_users).values_list('user_id', 'user__username', 'user__first_name'))
in_active_users_columns = ['user_id', 'first_name', 'last_name']
in_active_users_df = pd.DataFrame(in_active_users, columns=in_active_users_columns)
master_dict['in_active'] = in_active_users_df.to_dict('r')
master_dict
# Out:
# {'active': [{'user_id': 29, 'first_name': 'afs08', 'last_name': ''},
#   {'user_id': 28, 'first_name': 'siddapa', 'last_name': ''},
#   {'user_id': 26, 'first_name': 'mahadevaprasad', 'last_name': ''},
#   {'user_id': 30, 'first_name': 'afs09', 'last_name': ''},
#   {'user_id': 27, 'first_name': 'pratap', 'last_name': ''}],
#  'in_active': [{'user_id': 149,
#    'first_name': '4223432432',
#    'last_name': 'sdfdsfs'}]}

# %%
all_subordinate_user_ids
# Out:
# [26, 27, 28, 29, 30]

# %%
position_users = list(PositionManUserMap.objects.filter(user__userprofile__user_type_id=3).values_list('user_id',flat=True))
position_users
# Out:
# [10]

# %%
position_users = list(PositionManUserMap.objects.filter(user__userprofile__user_type_id=3).values_list('user_id',flat=True))
user_ids = list(UserProfile.objects.filter(user_type_id=3).exclude(user_id__in=position_users).values_list('user_id', flat=True))
active_users = list(UserProfile.objects.filter(user_id__in=user_ids).values_list('user_id', 'user__username', 'user__last_name'))
active_users_columns = ['user_id', 'first_name', 'last_name']
active_users_df = pd.DataFrame(active_users, columns=active_users_columns)
master_dict = active_users_df.to_dict('r')
master_dict
# Out:
# [{'user_id': 92, 'first_name': 'mahadevaprasad_sfs2', 'last_name': 'sfs2'},
#  {'user_id': 80, 'first_name': 'ajith_sfs1', 'last_name': 'sfs1'}]

# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
# google_sheet_url = 'https://docs.google.com/spreadsheets/d/1JOKToaq1PSyQMK9Q2abDejqlzmKaiGyNH0tzwx3kCds/export?format=csv'
google_sheet_url = 'https://docs.google.com/spreadsheets/d/16KLNi_bShAChHup-SSdRRKN6ICLRiiDoKKjK1SguZHg/export?format=csv'
r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df
# Out:
#      Sl No      Village Name      State        District      Taluk  \
# 0        1           Hangala  Karnataka  Chamarajanagar  Gundlupet
# 1        2      Vadayanapura  Karnataka  Chamarajanagar  Gundlupet
# 2        3         Ankahalli  Karnataka  Chamarajanagar  Gundlupet
# 3        4       Bhachahalli  Karnataka  Chamarajanagar  Gundlupet
# 4        5  Vaddanahosahalli  Karnataka  Chamarajanagar  Gundlupet
# ..     ...               ...        ...             ...        ...
# 274    275       Naganahalli  Karnataka          Mysore   H D Kote
# 275    276         Nanjipura  Karnataka          Mysore   H D Kote
# 276    277   Nisana Belathur  Karnataka          Mysore   H D Kote
# 277    278            Sargur  Karnataka          Mysore   H D Kote
# 278    279           Tagadur  Karnataka          Mysore  Nanjangud
#
#             Hobali
# 0          Hangala
# 1          Hangala
# 2          Hangala
# 3          Hangala
# 4          Hangala
# ..             ...
# 274       H D Kote
# 275       H D Kote
# 276  Antharasanthe
# 277         Sargur
# 278        Tagadur
#
# [279 rows x 6 columns]

# %%
for index, row in df.iterrows():
    print('=================')
    print(row['Hobali'], row['Taluk'])
    print('=================')
    if not State.objects.filter(name=row['State']).exists():
        state_obj = State(name=row['State'],
                          code=row['State'][0:2])
        state_obj.save()
    else:
        state_obj = State.objects.get(name=row['State'])


    if not District.objects.filter(name=row['District']).exists():
        district_obj = District(
            state_id=state_obj.id,
            name=row['District'],
            code=row['District'][:2],
            capital=row['District']
        )
        district_obj.save()
    else:
#         print('District_exist',row['District'])
        if not District.objects.filter(name=row['District'], state_id=state_obj.id).exists():
            District.objects.filter(name=row['District']).update(state_id=state_obj.id)
        district_obj = District.objects.get(name=row['District'], state_id=state_obj.id)
       
   
   
    if not Taluk.objects.filter(name=row['Taluk']).exists():
        taluk_obj = Taluk(
            district_id=district_obj.id,
            name=row['Taluk'])
        taluk_obj.save()
    else:
#         print('taluk_exist', row['Taluk'])
        if not Taluk.objects.filter(name=row['Taluk'], district_id=district_obj.id).exists():
            Taluk.objects.filter(name=row['Taluk']).update(district_id=district_obj.id)
        taluk_obj = Taluk.objects.get(name=row['Taluk'], district_id=district_obj.id)
   
    if not Hobli.objects.filter(name=row['Hobali']).exists():
        hobli_obj = Hobli(taluk_id=taluk_obj.id,name=row['Hobali'])
        hobli_obj.save()
        print('new hobli',row['Hobali'])
    else:
        if not Hobli.objects.filter(name=row['Hobali'], taluk_id=taluk_obj.id).exists():
            Hobli.objects.filter(name=row['Hobali']).update(taluk_id=taluk_obj.id)
           
        hobli_obj = Hobli.objects.get(name=row['Hobali'], taluk_id=taluk_obj.id)
   
    if not Village.objects.filter(name=row['Village Name']).exists():
        village_obj = Village(hobli_id = hobli_obj.id,name = row['Village Name'])
        village_obj.save()
        print('new village',row['Village Name'])
    else:
        if not Village.objects.filter(name=row['Village Name'],  hobli_id=hobli_obj.id).exists():
            Village.objects.filter(name=row['Village Name']).update(hobli_id=hobli_obj.id)
           
        village_obj = Village.objects.filter(name=row['Village Name'], hobli_id=hobli_obj.id)
# Out:
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Hangala Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Terakanambi Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Hullahalli Nanjangud
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Begur Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Antharasanthe H D Kote
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
# Kasaba Gundlupet
# =================
# =================
#
# =================
# =================
# Hullahalli Nanjangud
# =================
# =================
# Kandalike H D Kote
# =================
# =================
# Kandalike Sargur
# =================
# =================
# Kandalike Sargur
# =================
# new village Hunasooru
# =================
# Sargur Sargur
# =================
# =================
# Kandalike Sargur
# =================
# new village kadagere
# =================
# Kandalike H D Kote
# =================
# =================
# Kandalike Sargur
# =================
# new village Muguthalanamule
# =================
# Sargur H D Kote
# =================
# =================
# Hullahalli Nanjangud
# =================
# =================
# Kandalike Sargur
# =================
# =================
# Hullahalli Nanjangud
# =================
# =================
# N Begur H D Kote
# =================
# new hobli N Begur
# new village Beeramballi
# =================
# Sargur H D Kote
# =================
# new village Beeravalu
# =================
# Sargur H D Kote
# =================
# =================
# Handpost H D Kote
# =================
# new village Chakkur
# =================
# Handpost H D Kote
# =================
# new village Chikkeriyur
# =================
# Handpost H D Kote
# =================
# new village Doddabyranakuppe
# =================
# Jayapura Mysore
# =================
# =================
# Jayapura H D Kote
# =================
# new village Gujjegowdanapura
# =================
# Jayapura Mysore
# =================
# new village Gurur
# =================
# Hampapura H D Kote
# =================
# new village Hampapura H D
# =================
# Kavlande Nanjangud
# =================
# new village Hedathale
# =================
# Hullahalli Nanjangud
# =================
# =================
# Antharasanthe H D Kote
# =================
# =================
# Antharasanthe H D Kote
# =================
# new village Hosaholalu
# =================
# Sargur H D Kote
# =================
# new village Itna
# =================
# Hampapura H D Kote
# =================
# new village Jampanahalli
# =================
# Jayapura Mysore
# =================
# new village Jayapura
# =================
# Sargur H D Kote
# =================
# new village Kabini Colony
# =================
# Handpost H D Kote
# =================
# new village Kolagala
# =================
# Handpost H D Kote
# =================
# new village Kollegowdanahalli
# =================
# Sargur H D Kote
# =================
# =================
# Handpost H D Kote
# =================
# new village Kunthanabelathur
# =================
# Gddige H D Kote
# =================
# new hobli Gddige
# new village Kyathanahalli
# =================
# Handpost H D Kote
# =================
# =================
# Gddige H D Kote
# =================
# =================
# Handpost H D Kote
# =================
# new village Matakere
# =================
# H D Kote H D Kote
# =================
# new hobli H D Kote
# new village Metikuppe
# =================
# Kandalike H D Kote
# =================
# new village Moleyur
# =================
# Sargur H D Kote
# =================
# new village Mullur
# =================
# Antharasanthe H D Kote
# =================
# new village N Begur
# =================
# H D Kote H D Kote
# =================
# new village Naganahalli
# =================
# H D Kote H D Kote
# =================
# new village Nanjipura
# =================
# Antharasanthe H D Kote
# =================
# new village Nisana Belathur
# =================
# Sargur H D Kote
# =================
# new village Sargur
# =================
# Tagadur Nanjangud
# =================
# new village Tagadur

# %%
Hobli.objects.filter(name='Kandalike', taluk__name='Sargur').values()
# Out:
# <QuerySet [{'id': 8, 'name': 'Kandalike', 'taluk_id': 237}, {'id': 48, 'name': 'Kandalike', 'taluk_id': 237}]>

# %%
hobli_list = [65]
UserProfile.objects.filter(hobli_id__in=hobli_list).update(hobli_id=17)
AgentOffice.objects.filter(hobli_id__in=hobli_list).update(hobli_id=17)
Sowing.objects.filter(hobli_id__in=hobli_list).update(hobli_id=)
Farmer.objects.filter(hobli_id__in=hobli_list).update(hobli_id=2)
Village.objects.filter(hobli_id__in=hobli_list).update(hobli_id=2)
# Out:
# (0, {})
# (0, {})
# (1, {'instance.UserProfile': 0, 'instance.AgentOffice': 0, 'knowledgebase.Hobli': 1})

# %%
remove_list = [
    {'hobli_list': [65],'replace_id':17 },
    {'hobli_list': [47],'replace_id':23 },
    {'hobli_list': [37],'replace_id':5 },
    {'hobli_list': [48],'replace_id':8 },
]
for row in remove_list:
    UserProfile.objects.filter(hobli_id__in=row['hobli_list']).update(hobli_id=row['replace_id'])
    AgentOffice.objects.filter(hobli_id__in=row['hobli_list']).update(hobli_id=row['replace_id'])
    Sowing.objects.filter(hobli_id__in=row['hobli_list']).update(hobli_id=row['replace_id'])
    Farmer.objects.filter(hobli_id__in=row['hobli_list']).update(hobli_id=row['replace_id'])
    Village.objects.filter(hobli_id__in=row['hobli_list']).update(hobli_id=row['replace_id'])
    print(Hobli.objects.filter(id__in=row['hobli_list']).delete())
# Out:
# (0, {})
# (0, {})
# (0, {})
# (0, {})

# %%
Hobli.objects.filter(id__in=[53,32,33,34,41,44,49,51,13,54,52]).delete()
village_obj = Village.objects.filter(id__in =[48, 265, 344, 345, 372])
village_obj.delete()
# Out:
# (0, {})

# %%
Village.objects.filter(id=2).values()
Hobli.objects.filter(id=2)
# Out:
# <QuerySet [<Hobli: Alathur>]>

# %%
UserProfile.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52,]).update(hobli_id=2,village_id=2)
AgentOffice.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52]).update(hobli_id=2,village_id=2)
Sowing.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52]).update(hobli_id=2,village_id=2)
Farmer.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52]).update(hobli_id=2,village_id=2)
Village.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52]).update(hobli_id=2)
# Out:
# 156

# %%
Farmer.objects.filter(hobli_id__in=[53,32,33,34,41,44,49,51,13,54,52]).count()
# Out:
# 0

# %%
list(Village.objects.filter().order_by.values())
# Out:
# [{'id': 1, 'hobli_id': 1, 'name': 'Kurumbampalayam'},
#  {'id': 2, 'hobli_id': 2, 'name': 'Alathur'},
#  {'id': 3, 'hobli_id': 3, 'name': 'gobichettipalayam'},
#  {'id': 4, 'hobli_id': 4, 'name': 'Gundlupet Town'},
#  {'id': 5, 'hobli_id': 5, 'name': 'Bettadamadahalli'},
#  {'id': 6, 'hobli_id': 5, 'name': 'Bhogayyyanahundi Village'},
#  {'id': 7, 'hobli_id': 5, 'name': 'Begur'},
#  {'id': 8, 'hobli_id': 5, 'name': 'Somahalli Village'},
#  {'id': 9, 'hobli_id': 6, 'name': 'Gopalpura Village'},
#  {'id': 10, 'hobli_id': 7, 'name': 'Bankahalli Village'},
#  {'id': 11, 'hobli_id': 8, 'name': 'Channagundi Village '},
#  {'id': 12, 'hobli_id': 9, 'name': 'Yaraganahalli Village'},
#  {'id': 13, 'hobli_id': 10, 'name': 'Terakanambi'},
#  {'id': 14, 'hobli_id': 28, 'name': 'Bheemanabeedu'},
#  {'id': 15, 'hobli_id': 28, 'name': 'Berambadi'},
#  {'id': 16, 'hobli_id': 5, 'name': 'Aralikatte'},
#  {'id': 17, 'hobli_id': 7, 'name': 'Ballurundi'},
#  {'id': 18, 'hobli_id': 7, 'name': 'Bankahalli'},
#  {'id': 19, 'hobli_id': 11, 'name': 'Bargi'},
#  {'id': 20, 'hobli_id': 16, 'name': 'Basaveswara'},
#  {'id': 21, 'hobli_id': 8, 'name': 'Bavikere'},
#  {'id': 22, 'hobli_id': 12, 'name': 'Berambadi'},
#  {'id': 23, 'hobli_id': 11, 'name': 'Bheemanabeedu'},
#  {'id': 24, 'hobli_id': 14, 'name': 'Channamallipura  Maddur'},
#  {'id': 25, 'hobli_id': 20, 'name': 'Depapura'},
#  {'id': 26, 'hobli_id': 18, 'name': 'Doddakavalande Nerle'},
#  {'id': 27, 'hobli_id': 28, 'name': 'Doddinduvadi'},
#  {'id': 28, 'hobli_id': 11, 'name': 'Hongahalli'},
#  {'id': 29, 'hobli_id': 14, 'name': 'Honnegowdanahalli'},
#  {'id': 30, 'hobli_id': 19, 'name': 'Igglore'},
#  {'id': 31, 'hobli_id': 26, 'name': 'Kandayyanapalya'},
#  {'id': 32, 'hobli_id': 16, 'name': 'Kethahalli'},
#  {'id': 33, 'hobli_id': 11, 'name': 'Kodasoge'},
#  {'id': 34, 'hobli_id': 21, 'name': 'Kothalavadi'},
#  {'id': 35, 'hobli_id': 15, 'name': 'Kunagahalli'},
#  {'id': 36, 'hobli_id': 24, 'name': 'Kuvempunagar'},
#  {'id': 37, 'hobli_id': 26, 'name': 'Lokkanahalli'},
#  {'id': 38, 'hobli_id': 7, 'name': 'Mallahalli'},
#  {'id': 39, 'hobli_id': 27, 'name': 'Pasha'},
#  {'id': 40, 'hobli_id': 22, 'name': 'Patramangalam'},
#  {'id': 41, 'hobli_id': 16, 'name': 'Sagade'},
#  {'id': 42, 'hobli_id': 23, 'name': 'Sagare'},
#  {'id': 43, 'hobli_id': 21, 'name': 'Sheelavanthapura'},
#  {'id': 44, 'hobli_id': 23, 'name': 'Sriramabadavane'},
#  {'id': 45, 'hobli_id': 21, 'name': 'Terakanambihundi'},
#  {'id': 46, 'hobli_id': 25, 'name': 'Thoravally'},
#  {'id': 47, 'hobli_id': 17, 'name': 'Uganedahundi  Udigala'},
#  {'id': 49, 'hobli_id': 17, 'name': 'Yanagahalli'},
#  {'id': 50, 'hobli_id': 11, 'name': 'Yariyooru'},
#  {'id': 51, 'hobli_id': 29, 'name': 'Berambadi'},
#  {'id': 52, 'hobli_id': 5, 'name': 'Kotekere'},
#  {'id': 53, 'hobli_id': 29, 'name': 'Maddur'},
#  {'id': 54, 'hobli_id': 11, 'name': 'Maddayya ahundi'},
#  {'id': 55, 'hobli_id': 11, 'name': 'Bimanabeedu'},
#  {'id': 56, 'hobli_id': 11, 'name': 'Desipura'},
#  {'id': 57, 'hobli_id': 29, 'name': 'Honnegowdanahalli'},
#  {'id': 58, 'hobli_id': 10, 'name': 'Huradahalli'},
#  {'id': 59, 'hobli_id': 29, 'name': 'Kannegala'},
#  {'id': 60, 'hobli_id': 30, 'name': 'Kuttegowdarahundi'},
#  {'id': 61, 'hobli_id': 10, 'name': 'Mudaguru'},
#  {'id': 62, 'hobli_id': 10, 'name': 'Padaguru'},
#  {'id': 63, 'hobli_id': 29, 'name': 'Puthanpura'},
#  {'id': 64, 'hobli_id': 31, 'name': 'Ragavapura'},
#  {'id': 65, 'hobli_id': 29, 'name': 'Gopalpura'},
#  {'id': 66, 'hobli_id': 29, 'name': 'Kalligowdanahalli'},
#  {'id': 67, 'hobli_id': 29, 'name': 'Kallipura'},
#  {'id': 68, 'hobli_id': 29, 'name': 'Kunagahalli'},
#  {'id': 69, 'hobli_id': 29, 'name': 'Maguvinahalli'},
#  {'id': 70, 'hobli_id': 29, 'name': 'Muguvinahalli'},
#  {'id': 71, 'hobli_id': 29, 'name': 'Pasayyanapura'},
#  {'id': 72, 'hobli_id': 29, 'name': 'Shivapura'},
#  {'id': 73, 'hobli_id': 29, 'name': 'Beechanahalli'},
#  {'id': 74, 'hobli_id': 29, 'name': 'Lakkipura'},
#  {'id': 75, 'hobli_id': 29, 'name': 'Maddayya ahundi'},
#  {'id': 76, 'hobli_id': 11, 'name': 'Channamallipura'},
#  {'id': 77, 'hobli_id': 29, 'name': 'Channamallipura'},
#  {'id': 78, 'hobli_id': 11, 'name': 'Muntipura'},
#  {'id': 106, 'hobli_id': 35, 'name': 'Bankahalli'},
#  {'id': 128, 'hobli_id': 36, 'name': 'Shivapura'},
#  {'id': 132, 'hobli_id': 37, 'name': 'Aralikatte'},
#  {'id': 137, 'hobli_id': 38, 'name': 'Sagade'},
#  {'id': 145, 'hobli_id': 38, 'name': 'Kethahalli'},
#  {'id': 154, 'hobli_id': 29, 'name': 'Bommalapura'},
#  {'id': 155, 'hobli_id': 10, 'name': 'Kodasoge'},
#  {'id': 156, 'hobli_id': 39, 'name': 'Arakalavadi'},
#  {'id': 157, 'hobli_id': 40, 'name': 'Arakalavadi'},
#  {'id': 158, 'hobli_id': 10, 'name': 'B M  Kattehundi'},
#  {'id': 159, 'hobli_id': 10, 'name': 'Balachavadi'},
#  {'id': 160, 'hobli_id': 10, 'name': 'Depapura'},
#  {'id': 163, 'hobli_id': 42, 'name': 'Gattavadipura'},
#  {'id': 165, 'hobli_id': 10, 'name': 'Guruvinapura'},
#  {'id': 167, 'hobli_id': 42, 'name': 'Haraginapura'},
#  {'id': 168, 'hobli_id': 30, 'name': 'Harepura'},
#  {'id': 169, 'hobli_id': 10, 'name': 'Huthuru'},
#  {'id': 172, 'hobli_id': 10, 'name': 'Kadathalakattehundi'},
#  {'id': 173, 'hobli_id': 16, 'name': 'Katnavadi'},
#  {'id': 174, 'hobli_id': 43, 'name': 'Kilagere'},
#  {'id': 176, 'hobli_id': 16, 'name': 'Kothalavadi'},
#  {'id': 177, 'hobli_id': 10, 'name': 'Kundakere'},
#  {'id': 178, 'hobli_id': 10, 'name': 'Lakkuru'},
#  {'id': 179, 'hobli_id': 43, 'name': 'Madalavadi'},
#  {'id': 186, 'hobli_id': 10, 'name': 'Sheelavanthapura'},
#  {'id': 187, 'hobli_id': 11, 'name': 'Shindanapura'},
#  {'id': 188, 'hobli_id': 10, 'name': 'Somanapura'},
#  {'id': 190, 'hobli_id': 43, 'name': 'Yanagahalli'},
#  {'id': 191, 'hobli_id': 43, 'name': 'Yanagumba'},
#  {'id': 192, 'hobli_id': 42, 'name': 'Aralikatte'},
#  {'id': 193, 'hobli_id': 42, 'name': 'Bendaravadi'},
#  {'id': 194, 'hobli_id': 30, 'name': 'Harave'},
#  {'id': 195, 'hobli_id': 42, 'name': 'Kilalipura'},
#  {'id': 196, 'hobli_id': 30, 'name': 'Maleyooru'},
#  {'id': 197, 'hobli_id': 29, 'name': 'Bachahalli'},
#  {'id': 200, 'hobli_id': 10, 'name': 'Daribeguru'},
#  {'id': 201, 'hobli_id': 10, 'name': 'Karakalamadahalli'},
#  {'id': 202, 'hobli_id': 10, 'name': 'Shilavanthapura'},
#  {'id': 203, 'hobli_id': 10, 'name': 'Chirakanahalli'},
#  {'id': 204, 'hobli_id': 10, 'name': 'Karukkalmadhahalli'},
#  {'id': 205, 'hobli_id': 29, 'name': 'Maalapura'},
#  {'id': 206, 'hobli_id': 29, 'name': 'Malapura'},
#  {'id': 207, 'hobli_id': 10, 'name': 'Vaddagere'},
#  {'id': 208, 'hobli_id': 10, 'name': 'Yariyooru'},
#  {'id': 209, 'hobli_id': 30, 'name': 'Bettadapura'},
#  {'id': 210, 'hobli_id': 5, 'name': 'Kengaki'},
#  {'id': 211, 'hobli_id': 30, 'name': 'Kethahalli'},
#  {'id': 212, 'hobli_id': 30, 'name': 'Sagade'},
#  {'id': 213, 'hobli_id': 10, 'name': 'Kumachahalli'},
#  {'id': 214, 'hobli_id': 10, 'name': 'Paramapura'},
#  {'id': 215, 'hobli_id': 10, 'name': 'Shyanatrahalli'},
#  {'id': 216, 'hobli_id': 30, 'name': 'Thamadahalli'},
#  {'id': 217, 'hobli_id': 11, 'name': 'Bedarapura'},
#  {'id': 219, 'hobli_id': 16, 'name': 'Kalanahundi'},
#  {'id': 220, 'hobli_id': 5, 'name': 'Kuttegowdarahundi'},
#  {'id': 221, 'hobli_id': 10, 'name': 'Moodalahundi'},
#  {'id': 222, 'hobli_id': 30, 'name': 'Mukhadahalli'},
#  {'id': 223, 'hobli_id': 10, 'name': 'Terakanambihundi'},
#  {'id': 224, 'hobli_id': 10, 'name': 'Hooradahally'},
#  {'id': 225, 'hobli_id': 42, 'name': 'Araginapura'},
#  {'id': 226, 'hobli_id': 45, 'name': 'Bujaganpura'},
#  {'id': 227, 'hobli_id': 42, 'name': 'Hirebeguru'},
#  {'id': 228, 'hobli_id': 5, 'name': 'Kabballi'},
#  {'id': 229, 'hobli_id': 42, 'name': 'Konanooru'},
#  {'id': 230, 'hobli_id': 30, 'name': 'Maleeyooru'},
#  {'id': 231, 'hobli_id': 30, 'name': 'Mukadahalli'},
#  {'id': 232, 'hobli_id': 30, 'name': 'Mukadalli'},
#  {'id': 233, 'hobli_id': 16, 'name': 'Nanjadevanapura'},
#  {'id': 234, 'hobli_id': 10, 'name': 'Padagooru'},
#  {'id': 236, 'hobli_id': 16, 'name': 'Ssgade'},
#  {'id': 237, 'hobli_id': 11, 'name': 'Hosahalli'},
#  {'id': 238, 'hobli_id': 43, 'name': 'Linganapura'},
#  {'id': 239, 'hobli_id': 43, 'name': 'Narasamangala'},
#  {'id': 240, 'hobli_id': 43, 'name': 'Nijalinganapura'},
#  {'id': 241, 'hobli_id': 10, 'name': 'Thriyambakapura'},
#  {'id': 242, 'hobli_id': 43, 'name': 'Vaddarahalli'},
#  {'id': 243, 'hobli_id': 43, 'name': 'Vadgalpura'},
#  {'id': 244, 'hobli_id': 29, 'name': 'Hullapura'},
#  {'id': 246, 'hobli_id': 46, 'name': 'Kempanapura'},
#  {'id': 247, 'hobli_id': 46, 'name': 'Mangala'},
#  {'id': 248, 'hobli_id': 11, 'name': 'Nadukal Mule'},
#  {'id': 254, 'hobli_id': 47, 'name': 'Sagare'},
#  {'id': 260, 'hobli_id': 36, 'name': 'Beechanahalli'},
#  {'id': 268, 'hobli_id': 48, 'name': 'Bavikere'},
#  {'id': 284, 'hobli_id': 50, 'name': 'Kallipura'},
#  {'id': 301, 'hobli_id': 11, 'name': 'Bannithalapura'},
#  {'id': 302, 'hobli_id': 11, 'name': 'Bargi  Colony'},
#  {'id': 303, 'hobli_id': 11, 'name': 'Deshipura'},
#  {'id': 304, 'hobli_id': 11, 'name': 'H S  Hundi'},
#  {'id': 305, 'hobli_id': 11, 'name': 'Hulasagundi'},
#  {'id': 306, 'hobli_id': 5, 'name': 'Kallahalli'},
#  {'id': 307, 'hobli_id': 11, 'name': 'Kandegala'},
#  {'id': 308, 'hobli_id': 11, 'name': 'Kodahalli'},
#  {'id': 309, 'hobli_id': 11, 'name': 'Madralli'},
#  {'id': 310, 'hobli_id': 11, 'name': 'Mallainapura'},
#  {'id': 311, 'hobli_id': 11, 'name': 'Mukhahalli'},
#  {'id': 312, 'hobli_id': 11, 'name': 'Mukhahalli Colony'},
#  {'id': 313, 'hobli_id': 11, 'name': 'Mukhalli'},
#  {'id': 170, 'hobli_id': 2, 'name': 'Jannuru'},
#  {'id': 314, 'hobli_id': 11, 'name': 'Mukhalli Colony'},
#  {'id': 315, 'hobli_id': 11, 'name': 'Mukthi  Colony'},
#  {'id': 316, 'hobli_id': 11, 'name': 'Mukthi Calony'},
#  {'id': 317, 'hobli_id': 11, 'name': 'Mukthi Colony'},
#  {'id': 318, 'hobli_id': 11, 'name': 'Nagapattanna'},
#  {'id': 319, 'hobli_id': 11, 'name': 'Nenekatte'},
#  {'id': 320, 'hobli_id': 11, 'name': 'Panjanalli'},
#  {'id': 321, 'hobli_id': 11, 'name': 'Siddayyanapura Colony'},
#  {'id': 322, 'hobli_id': 11, 'name': 'Tenkalahundi'},
#  {'id': 323, 'hobli_id': 11, 'name': 'Uttangerihundi'},
#  {'id': 324, 'hobli_id': 11, 'name': 'Alathuru'},
#  {'id': 325, 'hobli_id': 11, 'name': 'Kutanooru'},
#  {'id': 326, 'hobli_id': 11, 'name': 'Maddayyanahundi'},
#  {'id': 327, 'hobli_id': 11, 'name': 'Manchalli'},
#  {'id': 329, 'hobli_id': 11, 'name': 'Savakanalli palya'},
#  {'id': 330, 'hobli_id': 11, 'name': 'Achakarai'},
#  {'id': 331, 'hobli_id': 11, 'name': 'bargi'},
#  {'id': 333, 'hobli_id': 11, 'name': 'Hosuru'},
#  {'id': 336, 'hobli_id': 11, 'name': 'Mukhahalli  Colony'},
#  {'id': 338, 'hobli_id': 2, 'name': 'New'},
#  {'id': 339, 'hobli_id': 39, 'name': 'Yaraganahalli'},
#  {'id': 340, 'hobli_id': 4, 'name': 'muntipura '},
#  {'id': 341, 'hobli_id': 36, 'name': 'honnegowdanahalli '},
#  {'id': 342, 'hobli_id': 14, 'name': 'hangala'},
#  {'id': 343, 'hobli_id': 8, 'name': 'Telagu Masahalli'},
#  {'id': 346, 'hobli_id': 7, 'name': 'Vadeyanapura'},
#  {'id': 347, 'hobli_id': 7, 'name': 'Bhadagalapura'},
#  {'id': 348, 'hobli_id': 8, 'name': 'M C Thalalu'},
#  {'id': 349, 'hobli_id': 8, 'name': 'Hethige'},
#  {'id': 350, 'hobli_id': 8, 'name': 'Yasavanthapura'},
#  {'id': 351, 'hobli_id': 7, 'name': 'Hadanoru'},
#  {'id': 352, 'hobli_id': 8, 'name': 'Chikkabhargi'},
#  {'id': 353, 'hobli_id': 8, 'name': 'Hosakote'},
#  {'id': 354, 'hobli_id': 8, 'name': 'Haralali'},
#  {'id': 355, 'hobli_id': 8, 'name': 'Kadabeguru'},
#  {'id': 356, 'hobli_id': 8, 'name': 'Hunasuru circle'},
#  {'id': 357, 'hobli_id': 7, 'name': 'Hediyala'},
#  {'id': 358, 'hobli_id': 17, 'name': 'kothalavadi'},
#  {'id': 359, 'hobli_id': 17, 'name': 'katnavadi'},
#  {'id': 360, 'hobli_id': 8, 'name': 'Moleyuru kaval'},
#  {'id': 361, 'hobli_id': 8, 'name': 'Bankavadi'},
#  {'id': 362, 'hobli_id': 14, 'name': 'lakkipura'},
#  {'id': 363, 'hobli_id': 14, 'name': 'berambadi'},
#  {'id': 364, 'hobli_id': 14, 'name': 'bachanahalli ( maddur)'},
#  {'id': 365, 'hobli_id': 23, 'name': 'Kothegala'},
#  {'id': 366, 'hobli_id': 47, 'name': 'Kothegala'},
#  {'id': 367, 'hobli_id': 23, 'name': 'Jayanagar'},
#  {'id': 368, 'hobli_id': 17, 'name': 'linganapura'},
#  {'id': 369, 'hobli_id': 17, 'name': 'nijalinganapura'},
#  {'id': 370, 'hobli_id': 17, 'name': 'vaddaralli'},
#  {'id': 371, 'hobli_id': 17, 'name': 'narasamangala'},
#  {'id': 374, 'hobli_id': 39, 'name': 'Honnahalli'},
#  {'id': 375, 'hobli_id': 43, 'name': 'Honnahalli'},
#  {'id': 376, 'hobli_id': 55, 'name': 'Lanke'},
#  {'id': 377, 'hobli_id': 56, 'name': 'Hosaveedu'},
#  {'id': 378, 'hobli_id': 11, 'name': 'Berambadi'},
#  {'id': 379, 'hobli_id': 39, 'name': 'Linganapura'},
#  {'id': 380, 'hobli_id': 23, 'name': 'Magudilu'},
#  {'id': 381, 'hobli_id': 8, 'name': 'Teranimunti'},
#  {'id': 382, 'hobli_id': 8, 'name': 'Chennipura'},
#  {'id': 383, 'hobli_id': 8, 'name': 'Sagare'},
#  {'id': 384, 'hobli_id': 8, 'name': 'Agatturu'},
#  {'id': 385, 'hobli_id': 8, 'name': 'Dodabhargi'},
#  {'id': 386, 'hobli_id': 8, 'name': 'Siddapura'},
#  {'id': 387, 'hobli_id': 8, 'name': 'Muguthanamule'},
#  {'id': 388, 'hobli_id': 57, 'name': 'Karepura'},
#  {'id': 389, 'hobli_id': 43, 'name': 'Yaraganahalli'},
#  {'id': 390, 'hobli_id': 8, 'name': 'Halanahalli'},
#  {'id': 391, 'hobli_id': 7, 'name': 'Chanigowdanahalli'},
#  {'id': 392, 'hobli_id': 7, 'name': 'Kelupura'},
#  {'id': 393, 'hobli_id': 7, 'name': 'Hosapura.B'},
#  {'id': 394, 'hobli_id': 8, 'name': 'Kadagere'},
#  {'id': 395, 'hobli_id': 8, 'name': 'matadakatte'},
#  {'id': 397, 'hobli_id': 7, 'name': 'Seramahalli'},
#  {'id': 401, 'hobli_id': 45, 'name': 'Bhojagayanahundi'},
#  {'id': 402, 'hobli_id': 4, 'name': 'Somahalli'},
#  {'id': 403, 'hobli_id': 5, 'name': 'Somahalli'},
#  {'id': 405, 'hobli_id': 22, 'name': 'Iggluru'},
#  {'id': 406, 'hobli_id': 8, 'name': 'Magudilu'},
#  {'id': 407, 'hobli_id': 18, 'name': 'Basavatige'},
#  {'id': 408, 'hobli_id': 4, 'name': 'mukahalli'},
#  {'id': 409, 'hobli_id': 4, 'name': 'mukthi colony'},
#  {'id': 410, 'hobli_id': 4, 'name': 'mukthi coloni'},
#  {'id': 411, 'hobli_id': 10, 'name': 'sagade'},
#  {'id': 412, 'hobli_id': 42, 'name': 'Basavatige'},
#  {'id': 416, 'hobli_id': 18, 'name': 'P Marahalli'},
#  {'id': 417, 'hobli_id': 18, 'name': 'Kowalande'},
#  {'id': 418, 'hobli_id': 18, 'name': 'Chunchanahalli'},
#  {'id': 419, 'hobli_id': 7, 'name': 'Makanapura'},
#  {'id': 421, 'hobli_id': 5, 'name': 'Halahalli'},
#  {'id': 422, 'hobli_id': 5, 'name': 'segavadi'},
#  {'id': 423, 'hobli_id': 10, 'name': 'kabballi'},
#  {'id': 424, 'hobli_id': 10, 'name': 'bokkepura'},
#  {'id': 425, 'hobli_id': 1, 'name': 'bokkepura'},
#  {'id': 426, 'hobli_id': 10, 'name': 'ugedanahudi'},
#  {'id': 427, 'hobli_id': 10, 'name': 'sanegala'},
#  {'id': 428, 'hobli_id': 18, 'name': 'Karepura'},
#  {'id': 429, 'hobli_id': 18, 'name': 'Hadya'},
#  {'id': 430, 'hobli_id': 18, 'name': 'Badanagupe'},
#  {'id': 431, 'hobli_id': 18, 'name': 'Karya'},
#  {'id': 432, 'hobli_id': 18, 'name': 'Koonoru'},
#  {'id': 433, 'hobli_id': 18, 'name': 'Dasanoru'},
#  {'id': 434, 'hobli_id': 58, 'name': 'Magudilu'},
#  {'id': 435, 'hobli_id': 59, 'name': 'Hebbalaguppe'},
#  {'id': 436, 'hobli_id': 48, 'name': 'Haleheggudilu'},
#  {'id': 437, 'hobli_id': 48, 'name': 'Nemmanahalli'},
#  {'id': 438, 'hobli_id': 48, 'name': 'Herehalli'},
#  {'id': 439, 'hobli_id': 48, 'name': 'Kanakanahadi'},
#  {'id': 440, 'hobli_id': 8, 'name': 'Nemmanahalli '},
#  {'id': 441, 'hobli_id': 8, 'name': 'kanakanahadi'},
#  {'id': 442, 'hobli_id': 8, 'name': 'Haleheggudilu'},
#  {'id': 443, 'hobli_id': 11, 'name': 'veeranapura'},
#  {'id': 444, 'hobli_id': 11, 'name': 'kannegala'},
#  {'id': 445, 'hobli_id': 14, 'name': 'haggadalla'},
#  {'id': 446, 'hobli_id': 14, 'name': 'gopalpura'},
#  {'id': 447, 'hobli_id': 14, 'name': 'killipura'},
#  {'id': 448, 'hobli_id': 14, 'name': 'kaloni'},
#  {'id': 449, 'hobli_id': 14, 'name': 'kunagalli'},
#  {'id': 450, 'hobli_id': 14, 'name': 'kaggaladahundi'},
#  {'id': 451, 'hobli_id': 10, 'name': 'thamadalli'},
#  {'id': 452, 'hobli_id': 16, 'name': 'kk hundi'},
#  {'id': 453, 'hobli_id': 16, 'name': 'heggottara'},
#  {'id': 454, 'hobli_id': 10, 'name': 'kootegowdanahundi'},
#  {'id': 455, 'hobli_id': 10, 'name': 'jogikaloni'},
#  {'id': 456, 'hobli_id': 16, 'name': 'shivapura'},
#  {'id': 457, 'hobli_id': 4, 'name': 'nenekatte'},
#  {'id': 458, 'hobli_id': 42, 'name': 'bedarapura'},
#  {'id': 459, 'hobli_id': 16, 'name': 'kengaki'},
#  {'id': 460, 'hobli_id': 16, 'name': 'bettadapura'},
#  {'id': 461, 'hobli_id': 16, 'name': 'Aralikate'},
#  {'id': 462, 'hobli_id': 4, 'name': 'Baragi colony'},
#  {'id': 463, 'hobli_id': 5, 'name': 'Thorahalli'},
#  {'id': 464, 'hobli_id': 58, 'name': 'Niluvagilu'},
#  {'id': 465, 'hobli_id': 14, 'name': 'beechanahalli'},
#  {'id': 466, 'hobli_id': 4, 'name': 'Baragi'},
#  {'id': 467, 'hobli_id': 5, 'name': 'Hongahalli'},
#  {'id': 468, 'hobli_id': 4, 'name': 'nagapattana'},
#  {'id': 469, 'hobli_id': 45, 'name': 'bedarapura'},
#  {'id': 470, 'hobli_id': 38, 'name': 'shivapura'},
#  {'id': 471, 'hobli_id': 59, 'name': 'tumbusoge'},
#  {'id': 472, 'hobli_id': 59, 'name': 'Shanthipura'},
#  {'id': 473, 'hobli_id': 23, 'name': 'sargur'},
#  {'id': 474, 'hobli_id': 47, 'name': 'Bidagalu'},
#  {'id': 475, 'hobli_id': 8, 'name': 'katwalu'},
#  {'id': 476, 'hobli_id': 61, 'name': 'Dhadahalli'},
#  {'id': 477, 'hobli_id': 61, 'name': 'Dhodahalli'},
#  {'id': 478, 'hobli_id': 4, 'name': 'T K Hundi'},
#  {'id': 479, 'hobli_id': 4, 'name': 'mukahalli colony'},
#  {'id': 480, 'hobli_id': 60, 'name': 'Dhadadahalli'},
#  {'id': 481, 'hobli_id': 10, 'name': 'syanandralli'},
#  {'id': 482, 'hobli_id': 10, 'name': 'channanjayyanahundi'},
#  {'id': 483, 'hobli_id': 10, 'name': 'kelasipura'},
#  {'id': 484, 'hobli_id': 10, 'name': 'kilagere'},
#  {'id': 485, 'hobli_id': 10, 'name': 'ingalavadi'},
#  {'id': 486, 'hobli_id': 14, 'name': 'shivapura'},
#  {'id': 487, 'hobli_id': 4, 'name': 'Hongahalli'},
#  {'id': 488, 'hobli_id': 16, 'name': 'maleyuru'},
#  {'id': 489, 'hobli_id': 18, 'name': 'bhujanganapura'},
#  {'id': 490, 'hobli_id': 4, 'name': 'Desipura'},
#  {'id': 491, 'hobli_id': 18, 'name': 'konanuru'},
#  {'id': 492, 'hobli_id': 16, 'name': 'halepura'},
#  {'id': 493, 'hobli_id': 16, 'name': 'harave'},
#  {'id': 494, 'hobli_id': 18, 'name': 'heggottara'},
#  {'id': 495, 'hobli_id': 16, 'name': 'mukadalli'},
#  {'id': 496, 'hobli_id': 18, 'name': 'gatvadipura'},
#  {'id': 497, 'hobli_id': 18, 'name': 'hiribeguru'},
#  {'id': 498, 'hobli_id': 10, 'name': 'sampigepura'},
#  {'id': 499, 'hobli_id': 4, 'name': 'Allatooru'},
#  {'id': 500, 'hobli_id': 18, 'name': 'gatvadi'},
#  {'id': 501, 'hobli_id': 18, 'name': 'kilalipura'},
#  {'id': 502, 'hobli_id': 18, 'name': 'bendaravadi'},
#  {'id': 503, 'hobli_id': 4, 'name': 'Hulasagundi'},
#  {'id': 504, 'hobli_id': 4, 'name': 'mallayyanapura'},
#  {'id': 505, 'hobli_id': 4, 'name': 'Honnashettarahundi'},
#  {'id': 506, 'hobli_id': 4, 'name': 'Uttengarahundi'},
#  {'id': 507, 'hobli_id': 4, 'name': 'Thenkalahundi'},
#  {'id': 508, 'hobli_id': 31, 'name': 'agathagowdanahalli'},
#  {'id': 509, 'hobli_id': 16, 'name': 'hosalli'},
#  {'id': 510, 'hobli_id': 16, 'name': 'moodnakudu'},
#  {'id': 511, 'hobli_id': 5, 'name': 'Ragavapura'},
#  {'id': 512, 'hobli_id': 4, 'name': 'Pallya'},
#  {'id': 513, 'hobli_id': 5, 'name': 'Savakanahallipallya'},
#  {'id': 514, 'hobli_id': 5, 'name': 'manchahalli'},
#  {'id': 515, 'hobli_id': 5, 'name': 'Shattahalli'},
#  {'id': 516, 'hobli_id': 4, 'name': 'Madahalli'},
#  {'id': 517, 'hobli_id': 4, 'name': 'kuthanur'},
#  {'id': 518, 'hobli_id': 39, 'name': 'narasamangala'},
#  {'id': 519, 'hobli_id': 5, 'name': 'madapattana'},
#  {'id': 520, 'hobli_id': 39, 'name': 'kattanavadi'},
#  {'id': 521, 'hobli_id': 17, 'name': 'kotalavadi'},
#  {'id': 522, 'hobli_id': 10, 'name': 'bommalapura'},
#  {'id': 523, 'hobli_id': 10, 'name': 'terakanabi'},
#  {'id': 524, 'hobli_id': 39, 'name': 'yangahalli'},
#  {'id': 525, 'hobli_id': 10, 'name': 'kallahalli'},
#  {'id': 526, 'hobli_id': 10, 'name': 'devalapura'},
#  {'id': 527, 'hobli_id': 10, 'name': 'kalpura'},
#  {'id': 528, 'hobli_id': 10, 'name': 'kethahalli'},
#  {'id': 529, 'hobli_id': 7, 'name': 'Maduvinahalli'},
#  {'id': 530, 'hobli_id': 11, 'name': 'madahalli'},
#  {'id': 531, 'hobli_id': 11, 'name': 'mallavalli'},
#  {'id': 532, 'hobli_id': 10, 'name': 'vadayanapura'},
#  {'id': 533, 'hobli_id': 39, 'name': 'vadagalapura'},
#  {'id': 534, 'hobli_id': 5, 'name': 'kamarahalli'},
#  {'id': 535, 'hobli_id': 8, 'name': 'udkuru'},
#  {'id': 536, 'hobli_id': 8, 'name': 'Huskuru Colony'},
#  {'id': 537, 'hobli_id': 62, 'name': 'Vatalapura'},
#  {'id': 538, 'hobli_id': 63, 'name': 'Yaragamballi'},
#  {'id': 539, 'hobli_id': 7, 'name': 'Anjanaputa'},
#  {'id': 540, 'hobli_id': 7, 'name': 'Hulahalli'},
#  {'id': 541, 'hobli_id': 63, 'name': 'yakanoru'},
#  {'id': 542, 'hobli_id': 14, 'name': 'elchatti'},
#  {'id': 543, 'hobli_id': 14, 'name': 'mangla '},
#  {'id': 544, 'hobli_id': 14, 'name': 'jakkalli'},
#  {'id': 545, 'hobli_id': 14, 'name': 'kannegala'},
#  {'id': 546, 'hobli_id': 14, 'name': 'adinakanive '},
#  {'id': 547, 'hobli_id': 14, 'name': 'maguvina halli'},
#  {'id': 548, 'hobli_id': 14, 'name': 'kaligowdanahalli'},
#  {'id': 549, 'hobli_id': 11, 'name': 'kallahalli'},
#  {'id': 550, 'hobli_id': 39, 'name': 'madalava do i'},
#  {'id': 551, 'hobli_id': 39, 'name': 'madalavadi'},
#  {'id': 552, 'hobli_id': 39, 'name': 'basavapura'},
#  {'id': 553, 'hobli_id': 39, 'name': 'laxmipura'},
#  {'id': 554, 'hobli_id': 39, 'name': 'vadagalapuradahundi'},
#  {'id': 555, 'hobli_id': 39, 'name': 'akashettepura'},
#  {'id': 556, 'hobli_id': 39, 'name': 'amachavadi'},
#  {'id': 557, 'hobli_id': 39, 'name': 'bisalavadi'},
#  {'id': 558, 'hobli_id': 14, 'name': 'kunagahalli'},
#  {'id': 559, 'hobli_id': 10, 'name': 'shindanapura'},
#  {'id': 560, 'hobli_id': 10, 'name': 'kattanavadi'},
#  {'id': 561, 'hobli_id': 39, 'name': 'kotyalavadi'},
#  {'id': 562, 'hobli_id': 39, 'name': 'kottalavadi'},
#  {'id': 563, 'hobli_id': 7, 'name': 'mahadevanagara'},
#  {'id': 564, 'hobli_id': 35, 'name': 'Anjanapora '},
#  {'id': 565, 'hobli_id': 7, 'name': 'Naganapora '},
#  {'id': 566, 'hobli_id': 7, 'name': 'Anjanapura'},
#  {'id': 567, 'hobli_id': 7, 'name': 'Hanchipura '},
#  {'id': 568, 'hobli_id': 7, 'name': 'inderanagara'},
#  {'id': 569, 'hobli_id': 16, 'name': 'Udigala'},
#  {'id': 570, 'hobli_id': 39, 'name': 'Atagulipura'},
#  {'id': 571, 'hobli_id': 39, 'name': 'Attagulipura'},
#  {'id': 572, 'hobli_id': 7, 'name': 'hosaveedu'},
#  {'id': 573, 'hobli_id': 7, 'name': 'devarajashattipura'},
#  {'id': 574, 'hobli_id': 8, 'name': 'Hosakeresunda'},
#  {'id': 575, 'hobli_id': 8, 'name': 'mosarahalla'},
#  {'id': 576, 'hobli_id': 8, 'name': 'Nerale'},
#  {'id': 577, 'hobli_id': 4, 'name': 'bimanabidu'},
#  {'id': 578, 'hobli_id': 58, 'name': 'jiyaracoloni'},
#  {'id': 579, 'hobli_id': 58, 'name': 'Basvanageree'},
#  {'id': 580, 'hobli_id': 58, 'name': '  k yadathore'},
#  {'id': 581, 'hobli_id': 58, 'name': 'Alathalahundi'},
#  {'id': 582, 'hobli_id': 58, 'name': 'agasarahindi'},
#  {'id': 583, 'hobli_id': 23, 'name': 'Shanthipura'},
#  {'id': 584, 'hobli_id': 5, 'name': 'garaganahalli'},
#  {'id': 585, 'hobli_id': 17, 'name': 'V C hosuru'},
#  {'id': 586, 'hobli_id': 17, 'name': 'Doddahalla'},
#  {'id': 587, 'hobli_id': 39, 'name': 'Doddahalla'},
#  {'id': 588, 'hobli_id': 43, 'name': 'Basavapura'},
#  {'id': 589, 'hobli_id': 17, 'name': 'basavapura'},
#  {'id': 590, 'hobli_id': 17, 'name': 'attugulipura'},
#  {'id': 591, 'hobli_id': 43, 'name': 'attagulipura'},
#  {'id': 592, 'hobli_id': 39, 'name': 'haradanahalli'},
#  {'id': 593, 'hobli_id': 59, 'name': 'Magudilu'},
#  {'id': 594, 'hobli_id': 57, 'name': 'Banoru'},
#  {'id': 595, 'hobli_id': 57, 'name': 'Karya'},
#  {'id': 596, 'hobli_id': 57, 'name': 'Kamahalli'},
#  {'id': 597, 'hobli_id': 57, 'name': 'Hadya'},
#  {'id': 598, 'hobli_id': 14, 'name': 'hanagalapura'},
#  {'id': 599, 'hobli_id': 14, 'name': 'hangalapura'},
#  {'id': 600, 'hobli_id': 14, 'name': 'lokkere'},
#  {'id': 601, 'hobli_id': 18, 'name': 'devanooru'},
#  {'id': 602, 'hobli_id': 4, 'name': 'Gundulpet'},
#  {'id': 603, 'hobli_id': 16, 'name': 'megalahundi'},
#  {'id': 604, 'hobli_id': 10, 'name': 'udigala'},
#  {'id': 605, 'hobli_id': 17, 'name': 'shivapura'},
#  {'id': 606, 'hobli_id': 10, 'name': 'baratalli'},
#  {'id': 607, 'hobli_id': 40, 'name': 'maadralli'},
#  {'id': 608, 'hobli_id': 10, 'name': 'narasamangala'},
#  {'id': 609, 'hobli_id': 55, 'name': 'kannegowdanapura'},
#  {'id': 610, 'hobli_id': 55, 'name': 'Chamalapura'},
#  {'id': 611, 'hobli_id': 45, 'name': 'Nerale'},
#  {'id': 612, 'hobli_id': 55, 'name': 'S kallahalli'},
#  {'id': 613, 'hobli_id': 55, 'name': 'SKallahalli'},
#  {'id': 614, 'hobli_id': 55, 'name': 'Harohalli'},
#  {'id': 615, 'hobli_id': 55, 'name': 'Chunchirayanahundi'},
#  {'id': 616, 'hobli_id': 55, 'name': 'Gopalapura'},
#  {'id': 617, 'hobli_id': 23, 'name': 'Lanke'},
#  {'id': 618, 'hobli_id': 11, 'name': 'puttanapura'},
#  {'id': 619, 'hobli_id': 8, 'name': 'B. Matakere'},
#  {'id': 620, 'hobli_id': 55, 'name': 'Hampapura'},
#  {'id': 621, 'hobli_id': 8, 'name': 'kandegala'},
#  {'id': 622, 'hobli_id': 23, 'name': 'Agatturu'},
#  {'id': 623, 'hobli_id': 58, 'name': 'myraganahalli'},
#  {'id': 624, 'hobli_id': 58, 'name': 'Muraganahalli'},
#  {'id': 625, 'hobli_id': 58, 'name': 'penjahalli'},
#  {'id': 626, 'hobli_id': 58, 'name': 'Belaganahalli'},
#  {'id': 627, 'hobli_id': 58, 'name': 'Anatharasnthe'},
#  {'id': 628, 'hobli_id': 22, 'name': ' b g c olony'},
#  {'id': 629, 'hobli_id': 22, 'name': 'chikkalli'},
#  {'id': 630, 'hobli_id': 39, 'name': 'b g halli'},
#  {'id': 631, 'hobli_id': 39, 'name': 'b g colony'},
#  {'id': 632, 'hobli_id': 22, 'name': 'm r pura'},
#  {'id': 633, 'hobli_id': 22, 'name': 'housr'},
#  {'id': 634, 'hobli_id': 30, 'name': 'udigala'},
#  {'id': 635, 'hobli_id': 58, 'name': 'Herehalli'},
#  {'id': 636, 'hobli_id': 58, 'name': 'Ankanathaputa'},
#  {'id': 637, 'hobli_id': 55, 'name': 'Soligaracolony'},
#  {'id': 638, 'hobli_id': 11, 'name': 'bettadapura'},
#  {'id': 639, 'hobli_id': 7, 'name': 'Kellupura'},
#  {'id': 640, 'hobli_id': 16, 'name': 'kalapura'},
#  {'id': 641, 'hobli_id': 39, 'name': 'kullur'},
#  {'id': 642, 'hobli_id': 39, 'name': 'yanaguba'},
#  {'id': 643, 'hobli_id': 64, 'name': 'Bokapura'},
#  {'id': 644, 'hobli_id': 2, 'name': 'Desipura'},
#  {'id': 645, 'hobli_id': 10, 'name': 'Sindanapura'},
#  {'id': 646, 'hobli_id': 10, 'name': 'hulllapura'},
#  {'id': 647, 'hobli_id': 64, 'name': 'masanigudi'},
#  {'id': 648, 'hobli_id': 57, 'name': 'Dasanoru'},
#  {'id': 649, 'hobli_id': 14, 'name': 'madduru '},
#  {'id': 650, 'hobli_id': 37, 'name': 'ragavapura'},
#  {'id': 651, 'hobli_id': 8, 'name': 'Nadadi'},
#  {'id': 652, 'hobli_id': 14, 'name': 'karamala '},
#  {'id': 655, 'hobli_id': 29, 'name': 'Bichanahalli'},
#  {'id': 656, 'hobli_id': 40, 'name': 'channamallipura'},
#  {'id': 657, 'hobli_id': 18, 'name': 'kerehalli'},
#  {'id': 658, 'hobli_id': 10, 'name': 'mulayanahundi'},
#  {'id': 659, 'hobli_id': 31, 'name': 'kudagapura'},
#  {'id': 660, 'hobli_id': 16, 'name': 'desigowdanapura'},
#  {'id': 661, 'hobli_id': 35, 'name': 'maduvinahalli'},
#  {'id': 662, 'hobli_id': 17, 'name': 'honnahalli'},
#  {'id': 663, 'hobli_id': 5, 'name': 'nitre'},
#  {'id': 664, 'hobli_id': 14, 'name': 'Bommalapura'},
#  {'id': 665, 'hobli_id': 8, 'name': 'Bidarahalli'},
#  {'id': 666, 'hobli_id': 48, 'name': 'Nadadi'},
#  {'id': 667, 'hobli_id': 18, 'name': 'Haraganapur'},
#  {'id': 668, 'hobli_id': 19, 'name': 'Erode'},
#  {'id': 669, 'hobli_id': 18, 'name': 'Haraginapura'},
#  {'id': 670, 'hobli_id': 23, 'name': 'Jakkahalli'},
#  {'id': 671, 'hobli_id': 58, 'name': 'Malali'},
#  {'id': 672, 'hobli_id': 65, 'name': 'Bommalapura'},
#  {'id': 673, 'hobli_id': 66, 'name': 'Bargi'},
#  {'id': 674, 'hobli_id': 67, 'name': 'Hirehalli'},
#  {'id': 675, 'hobli_id': 68, 'name': 'Talavadi'},
#  {'id': 676, 'hobli_id': 23, 'name': 'Hanchipura'},
#  {'id': 48, 'hobli_id': 2, 'name': 'xxxxxx'},
#  {'id': 79, 'hobli_id': 2, 'name': 'Kelupura'},
#  {'id': 80, 'hobli_id': 2, 'name': 'Badagalapura'},
#  {'id': 81, 'hobli_id': 2, 'name': 'Bokkepura'},
#  {'id': 82, 'hobli_id': 2, 'name': 'Chikkakempehundi'},
#  {'id': 83, 'hobli_id': 2, 'name': 'Chunchanahalli'},
#  {'id': 84, 'hobli_id': 2, 'name': 'Harathale'},
#  {'id': 85, 'hobli_id': 2, 'name': 'Kalale'},
#  {'id': 86, 'hobli_id': 2, 'name': 'Nerle'},
#  {'id': 87, 'hobli_id': 2, 'name': 'P Marahalli'},
#  {'id': 88, 'hobli_id': 2, 'name': 'Sindhuvalli'},
#  {'id': 89, 'hobli_id': 2, 'name': 'Ugedanahundi'},
#  {'id': 90, 'hobli_id': 2, 'name': 'Yanagahalli'},
#  {'id': 91, 'hobli_id': 2, 'name': 'Alaganahalli'},
#  {'id': 92, 'hobli_id': 2, 'name': 'Basavattige'},
#  {'id': 93, 'hobli_id': 2, 'name': 'Bhaguru'},
#  {'id': 94, 'hobli_id': 2, 'name': 'Bhujanayyanahundi'},
#  {'id': 95, 'hobli_id': 2, 'name': 'Chikkakavalande'},
#  {'id': 96, 'hobli_id': 2, 'name': 'Chikkakowlande'},
#  {'id': 97, 'hobli_id': 2, 'name': 'Hedthale'},
#  {'id': 98, 'hobli_id': 2, 'name': 'Hemaragala'},
#  {'id': 99, 'hobli_id': 2, 'name': 'Kodalapura'},
#  {'id': 100, 'hobli_id': 2, 'name': 'Kumbrahalli'},
#  {'id': 101, 'hobli_id': 2, 'name': 'Sannamallipura'},
#  {'id': 102, 'hobli_id': 2, 'name': 'Siramahalli'},
#  {'id': 103, 'hobli_id': 2, 'name': 'Badagalapura'},
#  {'id': 104, 'hobli_id': 2, 'name': 'Bankahalli'},
#  {'id': 105, 'hobli_id': 2, 'name': 'Hediyala'},
#  {'id': 107, 'hobli_id': 2, 'name': 'Channagowdanahalli'},
#  {'id': 108, 'hobli_id': 2, 'name': 'Chikkabargi'},
#  {'id': 109, 'hobli_id': 2, 'name': 'Ettige'},
#  {'id': 110, 'hobli_id': 2, 'name': 'Hadanooru'},
#  {'id': 111, 'hobli_id': 2, 'name': 'Halemala'},
#  {'id': 112, 'hobli_id': 2, 'name': 'Haralahalli'},
#  {'id': 113, 'hobli_id': 2, 'name': 'Honaragalli'},
#  {'id': 114, 'hobli_id': 2, 'name': 'Hoonasuru'},
#  {'id': 115, 'hobli_id': 2, 'name': 'Hosakote'},
#  {'id': 116, 'hobli_id': 2, 'name': 'Hullahalli'},
#  {'id': 117, 'hobli_id': 2, 'name': 'Hunasoor'},
#  {'id': 118, 'hobli_id': 2, 'name': 'Hunasoor Circle'},
#  {'id': 119, 'hobli_id': 2, 'name': 'Hunasooru Circle'},
#  {'id': 120, 'hobli_id': 2, 'name': 'Jayalakshmipura'},
#  {'id': 121, 'hobli_id': 2, 'name': 'Jompanahalli'},
#  {'id': 122, 'hobli_id': 2, 'name': 'Kadabeguru'},
#  {'id': 123, 'hobli_id': 2, 'name': 'Karagala'},
#  {'id': 124, 'hobli_id': 2, 'name': 'Karepura'},
#  {'id': 125, 'hobli_id': 2, 'name': 'M C Talalu'},
#  {'id': 126, 'hobli_id': 2, 'name': 'Madaruru'},
#  {'id': 127, 'hobli_id': 2, 'name': 'Muguthanamule'},
#  {'id': 129, 'hobli_id': 2, 'name': 'Vadayanapura'},
#  {'id': 130, 'hobli_id': 2, 'name': 'Vadeyanapura'},
#  {'id': 131, 'hobli_id': 2, 'name': 'Yashavanthapura'},
#  {'id': 133, 'hobli_id': 2, 'name': 'Belachalavadi'},
#  {'id': 134, 'hobli_id': 2, 'name': 'Jannuru'},
#  {'id': 135, 'hobli_id': 2, 'name': 'Jannuru Hosuru'},
#  {'id': 136, 'hobli_id': 2, 'name': 'Navilooru'},
#  {'id': 138, 'hobli_id': 2, 'name': 'Vatalapura'},
#  {'id': 139, 'hobli_id': 2, 'name': 'Yaraganahalli'},
#  {'id': 140, 'hobli_id': 2, 'name': 'Basapanapalya'},
#  {'id': 141, 'hobli_id': 2, 'name': 'Beguru'},
#  {'id': 142, 'hobli_id': 2, 'name': 'Devanahalli Moole'},
#  {'id': 143, 'hobli_id': 2, 'name': 'Hebosuru'},
#  {'id': 144, 'hobli_id': 2, 'name': 'Kagalavadi'},
#  {'id': 146, 'hobli_id': 2, 'name': 'Kothanahalli'},
#  {'id': 147, 'hobli_id': 2, 'name': 'Naguralli'},
#  {'id': 148, 'hobli_id': 2, 'name': 'Nalluru'},
#  {'id': 149, 'hobli_id': 2, 'name': 'Nalluru  Moole'},
#  {'id': 150, 'hobli_id': 2, 'name': 'Naviluru'},
#  {'id': 151, 'hobli_id': 2, 'name': 'Santhemaralli'},
#  {'id': 152, 'hobli_id': 2, 'name': 'Yaragamballi'},
#  {'id': 153, 'hobli_id': 2, 'name': 'Udigala'},
#  {'id': 161, 'hobli_id': 2, 'name': 'Ganiganooru'},
#  {'id': 162, 'hobli_id': 2, 'name': 'Ganinooru'},
#  {'id': 164, 'hobli_id': 2, 'name': 'Gejjenahalli'},
#  {'id': 166, 'hobli_id': 2, 'name': 'Hallikerehundi'},
#  {'id': 171, 'hobli_id': 2, 'name': 'Jannuru Hosuru'},
#  {'id': 175, 'hobli_id': 2, 'name': 'Kiragasuru'},
#  {'id': 180, 'hobli_id': 2, 'name': 'Madapura'},
#  {'id': 181, 'hobli_id': 2, 'name': 'Malapura'},
#  {'id': 182, 'hobli_id': 2, 'name': 'Heggadahalli'},
#  {'id': 183, 'hobli_id': 2, 'name': 'Moosavinakoppalu'},
#  {'id': 184, 'hobli_id': 2, 'name': 'Naviluru'},
#  {'id': 185, 'hobli_id': 2, 'name': 'Ramapura'},
#  {'id': 189, 'hobli_id': 2, 'name': 'Vatal'},
#  {'id': 198, 'hobli_id': 2, 'name': 'Bokkapura'},
#  {'id': 199, 'hobli_id': 2, 'name': 'Chikkahalli'},
#  {'id': 218, 'hobli_id': 2, 'name': 'Heggotara'},
#  {'id': 235, 'hobli_id': 2, 'name': 'Sriramapura'},
#  {'id': 245, 'hobli_id': 2, 'name': 'Kamarvadi'},
#  {'id': 249, 'hobli_id': 2, 'name': 'Agathur'},
#  {'id': 250, 'hobli_id': 2, 'name': 'Bidagalu'},
#  {'id': 251, 'hobli_id': 2, 'name': 'Hegganooru'},
#  {'id': 252, 'hobli_id': 2, 'name': 'Katavalu'},
#  {'id': 253, 'hobli_id': 2, 'name': 'Moodalahundi'},
#  {'id': 255, 'hobli_id': 2, 'name': 'Santhipura'},
#  {'id': 256, 'hobli_id': 2, 'name': 'Telagumasahalli'},
#  {'id': 257, 'hobli_id': 2, 'name': 'Thumbasoge'},
#  {'id': 258, 'hobli_id': 2, 'name': 'Uskuru'},
#  {'id': 259, 'hobli_id': 2, 'name': 'Agathuru'},
#  {'id': 261, 'hobli_id': 2, 'name': 'Bidrahalli'},
#  {'id': 262, 'hobli_id': 2, 'name': 'Magudilu'},
#  {'id': 263, 'hobli_id': 2, 'name': 'Teranimunti'},
#  {'id': 264, 'hobli_id': 2, 'name': 'Uyyamballi'},
#  {'id': 265, 'hobli_id': 2, 'name': 'xxxx'},
#  {'id': 266, 'hobli_id': 2, 'name': 'B Matakere'},
#  {'id': 267, 'hobli_id': 2, 'name': 'Bankavadi'},
#  {'id': 269, 'hobli_id': 2, 'name': 'Channipura'},
#  {'id': 270, 'hobli_id': 2, 'name': 'Heerahalli'},
#  {'id': 271, 'hobli_id': 2, 'name': 'Herehalli'},
#  {'id': 272, 'hobli_id': 2, 'name': 'Kolipura'},
#  {'id': 273, 'hobli_id': 2, 'name': 'Maleyooru'},
#  {'id': 274, 'hobli_id': 2, 'name': 'Matadakatte'},
#  {'id': 275, 'hobli_id': 2, 'name': 'Moleyooru'},
#  {'id': 276, 'hobli_id': 2, 'name': 'Nadadi'},
#  {'id': 277, 'hobli_id': 2, 'name': 'Nemmanahalli'},
#  {'id': 278, 'hobli_id': 2, 'name': 'Hulikura'},
#  {'id': 279, 'hobli_id': 2, 'name': 'Niluvagilu'},
#  {'id': 280, 'hobli_id': 2, 'name': 'Toravalli'},
#  {'id': 281, 'hobli_id': 2, 'name': 'Haleheggudilu'},
#  {'id': 282, 'hobli_id': 2, 'name': 'Jayanagar'},
#  {'id': 283, 'hobli_id': 2, 'name': 'Bavinahalli'},
#  {'id': 285, 'hobli_id': 2, 'name': 'Kethupura'},
#  {'id': 286, 'hobli_id': 2, 'name': 'Alagumule'},
#  {'id': 287, 'hobli_id': 2, 'name': 'Bandalli'},
#  {'id': 288, 'hobli_id': 2, 'name': 'Chinchalli'},
#  {'id': 289, 'hobli_id': 2, 'name': 'Halagapura'},
#  {'id': 290, 'hobli_id': 2, 'name': 'Ranapura'},
#  {'id': 291, 'hobli_id': 2, 'name': 'Aladamada'},
#  {'id': 292, 'hobli_id': 2, 'name': 'Channalinganahalli'},
#  {'id': 293, 'hobli_id': 2, 'name': 'Aankanapura'},
#  {'id': 294, 'hobli_id': 2, 'name': 'Chikkahindavadi'},
#  {'id': 295, 'hobli_id': 2, 'name': 'Doddahindavadi'},
#  {'id': 296, 'hobli_id': 2, 'name': 'Kariyanapura'},
#  {'id': 297, 'hobli_id': 2, 'name': 'Kempanapalya'},
#  {'id': 298, 'hobli_id': 2, 'name': 'Malurkatte'},
#  {'id': 299, 'hobli_id': 2, 'name': 'Manipura'},
#  {'id': 300, 'hobli_id': 2, 'name': 'Thellanur'},
#  {'id': 328, 'hobli_id': 2, 'name': 'Masanigudi'},
#  {'id': 332, 'hobli_id': 2, 'name': 'Bokkapuram'},
#  {'id': 334, 'hobli_id': 2, 'name': 'Masanigudi'},
#  {'id': 335, 'hobli_id': 2, 'name': 'Mavinahalla'},
#  {'id': 337, 'hobli_id': 2, 'name': 'Kotthegala'},
#  {'id': 344, 'hobli_id': 2, 'name': '1234'},
#  {'id': 345, 'hobli_id': 2, 'name': 'h'},
#  {'id': 372, 'hobli_id': 2, 'name': 'xxx'},
#  {'id': 373, 'hobli_id': 2, 'name': 'Test vill'},
#  {'id': 396, 'hobli_id': 2, 'name': 'Hosapura B'},
#  {'id': 398, 'hobli_id': 2, 'name': 'Hunasanahalu'},
#  {'id': 399, 'hobli_id': 2, 'name': 'Sindhuvalli'},
#  {'id': 400, 'hobli_id': 2, 'name': 'Bhaguru'},
#  {'id': 404, 'hobli_id': 2, 'name': 'Iggaluru'},
#  {'id': 413, 'hobli_id': 2, 'name': 'Kumbarahalli'},
#  {'id': 414, 'hobli_id': 2, 'name': 'Kurati'},
#  {'id': 415, 'hobli_id': 2, 'name': 'Hemaragala'},
#  {'id': 420, 'hobli_id': 2, 'name': 'Depegowdanapura'}]

# %%
Village.objects.get(id=372).delete()
# Out:
# (1,
#  {'instance.UserProfile': 0,
#   'instance.AgentOffice': 0,
#   'knowledgebase.Village': 1})

# %%
len(list(UserClusterMap.objects.filter(season_id=3, cluster_id=6, user__userprofile__user_type_id=6).values_list('user_id', flat=True)))
# Out:
# 16

# %%
AgentSupervisorSeasonMap.objects.filter(supervisor_id=24).count()
# Out:
# 11

# %%
supervisor_ids = list(PositionPositionUserMap.objects.filter(user__userprofile__user_type_id=5).values_list('user__id', flat=True))
season_id=3
for supervisor_id in supervisor_ids:
    if UserClusterMap.objects.filter(user_id=supervisor_id, season_id=season_id).exists():
        cluster_id = UserClusterMap.objects.get(user_id=supervisor_id, season_id=season_id).cluster_id
        agent_count = UserClusterMap.objects.filter(season_id=3, cluster_id=cluster_id, user__userprofile__user_type__id=6).count()
        under_agents = AgentSupervisorSeasonMap.objects.filter(season_id=season_id, supervisor_id=supervisor_id).count()
        if agent_count != under_agents:
            print('mismatched')
            print('agent_count :', agent_count)
            print('under_agents :', under_agents)
        else:
            print(User.objects.get(id=supervisor_id).username)
            print('0000000000000000000')
# Out:
# 24

# %%
PositionPositionUserMap.objects.filter(user__userprofile__user_type_id=5).values_list('user__username')
# Out:
# <QuerySet [('ajith',), ('naveen',), ('prasad',), ('madappa',), ('mahadevaprasad',), ('pratap',), ('siddapa',), ('kiran',), ('afs09',), ('afs10',)]>

# %%
User.objects.get(id=22).username[0:1]
# Out:
# 'a'

# %%
supervisor_ids = list(PositionPositionUserMap.objects.filter(user__userprofile__user_type_id=5).values_list('user__id', flat=True))
season_id = 3
for supervisor_id in supervisor_ids:
    if UserClusterMap.objects.filter(season_id=season_id, user_id=supervisor_id).exists():
        cluster_id = UserClusterMap.objects.get(season_id=season_id, user_id=supervisor_id).cluster_id
        agent_under_this_sup = AgentSupervisorSeasonMap.objects.filter(season_id=season_id, supervisor_id=supervisor_id).count()
        print(agent_under_this_sup)
        agents_under_cluster_count = UserClusterMap.objects.filter(cluster_id=cluster_id, season_id=season_id, user__userprofile__user_type_id=6).count()
        print(agents_under_cluster_count)
        if agent_under_this_sup == agents_under_cluster_count:
            print('matched')
        else:
            print('ERROR')
            print(cluster_id)
            print(AgentSupervisorSeasonMap.objects.filter(season_id=season_id, supervisor_id=supervisor_id).order_by('agent_id').values_list('agent_id',flat=True))
            print(UserClusterMap.objects.filter(cluster_id=cluster_id, season_id=season_id, user__userprofile__user_type_id=6).order_by('user_id').values_list('user_id', flat=True))
# Out:
# 11
# 11
# matched
# 7
# 7
# matched
# 4
# 4
# matched
# 5
# 5
# matched
# 6
# 6
# matched
# 8
# 8
# matched
# 8
# 8
# matched

# %%
removing_ids = [77,126, 49, 86,107, 117, 118, 125, 144, 54, 62, 64,  66, 109, 127, 134,237, 139, 142,53, 61,  113, 114,85,137]
UserClusterMap.objects.filter(season_id=3, user_id__in=removing_ids).delete()
# Out:
# (2, {'instance.UserClusterMap': 2})

# %%
UserClusterMap.objects.create(user_id=117,season_id=3,cluster_id=2, unique_code='', modified_by_id=26)
# Out:
# <UserClusterMap: UserClusterMap object>

# %%
UserClusterMap.objects.create(user_id=85,season_id=3,cluster_id=7, unique_code='', modified_by_id=26)
UserClusterMap.objects.create(user_id=134,season_id=3,cluster_id=7, unique_code='', modified_by_id=26)
UserClusterMap.objects.create(user_id=137,season_id=3,cluster_id=7, unique_code='', modified_by_id=26)
UserClusterMap.objects.create(user_id=139,season_id=3,cluster_id=7, unique_code='', modified_by_id=26)
UserClusterMap.objects.create(user_id=142,season_id=3,cluster_id=7, unique_code='', modified_by_id=26)
# Out:
# <UserClusterMap: UserClusterMap object>

# %%
UserClusterMap.objects.filter().values()
# Out:
# <QuerySet [{'id': 134, 'season_id': 2, 'user_id': 40, 'cluster_id': 1, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 11, 37, 34, 861035, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 11, 37, 34, 861066, tzinfo=<UTC>)}, {'id': 135, 'season_id': 2, 'user_id': 44, 'cluster_id': 8, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 11, 43, 16, 502172, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 11, 43, 16, 502197, tzinfo=<UTC>)}, {'id': 136, 'season_id': 2, 'user_id': 37, 'cluster_id': 1, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 11, 45, 28, 960114, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 11, 45, 28, 960140, tzinfo=<UTC>)}, {'id': 138, 'season_id': 2, 'user_id': 39, 'cluster_id': 1, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 11, 52, 21, 331622, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 11, 52, 21, 331647, tzinfo=<UTC>)}, {'id': 139, 'season_id': 2, 'user_id': 31, 'cluster_id': 1, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 11, 53, 19, 14246, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 11, 53, 19, 14276, tzinfo=<UTC>)}, {'id': 141, 'season_id': 2, 'user_id': 60, 'cluster_id': 2, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 2, 38, 963677, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 2, 38, 963710, tzinfo=<UTC>)}, {'id': 142, 'season_id': 2, 'user_id': 59, 'cluster_id': 2, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 3, 27, 555142, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 3, 27, 555164, tzinfo=<UTC>)}, {'id': 144, 'season_id': 2, 'user_id': 56, 'cluster_id': 2, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 4, 25, 809095, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 4, 25, 809143, tzinfo=<UTC>)}, {'id': 145, 'season_id': 2, 'user_id': 53, 'cluster_id': 2, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 6, 11, 880849, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 6, 11, 880877, tzinfo=<UTC>)}, {'id': 146, 'season_id': 2, 'user_id': 47, 'cluster_id': 2, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 7, 11, 74314, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 7, 11, 74356, tzinfo=<UTC>)}, {'id': 147, 'season_id': 2, 'user_id': 51, 'cluster_id': 3, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 8, 4, 852256, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 8, 4, 852282, tzinfo=<UTC>)}, {'id': 148, 'season_id': 2, 'user_id': 55, 'cluster_id': 3, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 9, 9, 175736, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 9, 9, 175761, tzinfo=<UTC>)}, {'id': 149, 'season_id': 2, 'user_id': 74, 'cluster_id': 3, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 10, 20, 194581, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 10, 20, 194625, tzinfo=<UTC>)}, {'id': 150, 'season_id': 2, 'user_id': 49, 'cluster_id': 3, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 11, 10, 571726, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 11, 10, 571750, tzinfo=<UTC>)}, {'id': 151, 'season_id': 2, 'user_id': 50, 'cluster_id': 3, 'unique_code': '1', 'modified_by_id': 26, 'time_created': datetime.datetime(2020, 4, 6, 12, 11, 50, 247311, tzinfo=<UTC>), 'time_modified': datetime.datetime(2020, 4, 6, 12, 11, 50, 247334, tzinfo=<UTC>)}, {'id': 152, 'season_i ...

# %%
UserFarmerMap.objects.filter(farmer__season_id=3, officer_id=27).count()
# Out:
# 0

# %%
AgentSupervisorSeasonMap.objects.filter(supervisor_id=27, season_id=3).count()
# Out:
# 5

# %%
Farmer.objects.filter().count()
# Out:
# 5957

# %%
AgentFarmerMap.objects.filter(farmer__season_id=1).count()
# Out:
# 2603

# %%
AgentSupervisorSeasonMap.objects.filter(agent_id=33, season_id=3).delete()
# Out:
# (1, {'instance.AgentSupervisorSeasonMap': 1})

# %%
import pandas as pd

issue_request_ids = [21]
agent_id = 59

final_dict = {}

new_bill_code = '43'

#data constriction
final_dict = {}

# new_bill_code = generate_bill_numeber_for_code_bank()

#data constriction
combo_issue_agent_obj = ComboIssueRequestAgentMap.objects.filter(combo_issue_request_id__in=issue_request_ids, agent_id=agent_id)  
agent_details_list = list(combo_issue_agent_obj.values_list('agent__first_name', 'agent__last_name', 'agent__userprofile__code', 'agent__userprofile__village__name', 'agent__userclustermap__cluster__name', 'agent__subordinate_user__superior__username'))
data_dict = pd.DataFrame(agent_details_list, columns=['agent_name', 'father_name', 'agent_code', 'village_ame', 'cluster_name', 'superior_name']).drop_duplicates().to_dict('r')[0]
combo_request_obj = ComboIssueRequestAgentMap.objects.filter(combo_issue_request_id__in=issue_request_ids, agent_id=agent_id)
combo_request_list = list(combo_request_obj.values_list('combo_issue_request', 'combo_issue_request__input_combo_id', 'combo_issue_request__input_combo__name', 'combo_issue_request__input_combo__price', 'combo_issue_request__input_combo__area__quantity_in_acre','quantity_in_numbers' ,'substoreissuelabelagentmap', 'substoreissuelabelagentmap__label', 'substoreissuelabelagentmap__input_sub_store_inventory__input_store_inventory__input_packet_inventory__packet_code', 'substoreissuelabelagentmap__input_sub_store_inventory__section', 'substoreissuelabelagentmap__input_sub_store_inventory', 'combo_issue_request__dispatch_date','combo_issue_request__supervisor__username', 'combo_issue_request__dispatched_by_id', 'combo_issue_request__issue_rised_date'))
combo_request_column = ['combo_issue_request', 'input_combo_id', 'input_combo_name', 'input_combo_price', 'input_combo_acre','quantity_in_numbers', 'store_issue_label_id', 'label', 'store_name', 'section', 'store_id', 'dispatch_date', 'supervisor_name', 'dispatched_by_id','issue_rised_date']
combo_request_df = pd.DataFrame(combo_request_list, columns=combo_request_column)
combo_request_df['total_price'] = 0
combo_request_df['total_acre'] = 0
combo_request_df['total_price'] = combo_request_df['quantity_in_numbers'] * combo_request_df['input_combo_price']
combo_request_df['total_acre'] = combo_request_df['quantity_in_numbers'] * combo_request_df['input_combo_acre']
combo_request_df = combo_request_df.groupby(['combo_issue_request', 'store_id']).agg({'label': list,  'input_combo_name': 'first', 'store_name': 'first', 'section': 'first', 'quantity_in_numbers': 'first', 'total_acre': 'first', 'input_combo_acre': 'first', 'total_price': 'first', 'input_combo_id': 'first', 'input_combo_price': 'first', 'dispatch_date': 'first',  'supervisor_name': 'first', 'dispatched_by_id': 'first', 'issue_rised_date': 'first'}).reset_index()
combo_request_df['label_from'] = combo_request_df.apply(lambda x: x['label'][0], axis=1)
combo_request_df['label_to'] = combo_request_df.apply(lambda x: x['label'][-1], axis=1)
data_dict['input_part_list'] = combo_request_df.groupby('combo_issue_request').apply(lambda x:x.to_dict('r')).to_dict()
data_dict['input_combo_list'] = combo_request_df.drop_duplicates(subset='combo_issue_request', keep="last").to_dict('r')
data_dict['bill_number'] = new_bill_code
input_combo_ids = list(set(list(combo_request_obj.values_list('combo_issue_request__input_combo_id', flat=True))))
input_combo_dict = {}
for input_combo in InputCombo.objects.filter(id__in=input_combo_ids):
    if not input_combo.id in input_combo_dict:
        input_combo_dict[input_combo.id] = {
            'value': 1,
            'unit_name': 'Nos'
        }
    if InputPart.objects.filter(input_combo_id=input_combo).count() == 1:
        input_part_obj = InputPart.objects.get(input_combo_id=input_combo)
        input_combo_dict[input_combo.id]['value'] = input_part_obj.value
        input_combo_dict[input_combo.id]['unit_name'] = input_part_obj.unit.name

data_dict['input_combo_dict'] = input_combo_dict 
data_dict
# Out:
# {'agent_name': 'Nataraju',
#  'father_name': 'Nanjundappa',
#  'agent_code': 'AT033',
#  'village_ame': 'Sagade',
#  'cluster_name': 'Terakanambi',
#  'superior_name': 'naveen',
#  'input_part_list': {21: [{'combo_issue_request': 21,
#     'store_id': 2,
#     'label': ['S21F11M1',
#      'S21F12M1',
#      'S21F13M1',
#      'S21F14M1',
#      'S21F15M1',
#      'S21F16M1',
#      'S21F17M1',
#      'S21F18M1',
#      'S21F19M1',
#      'S21F110M1',
#      'S21F111M1',
#      'S21F112M1',
#      'S21F113M1',
#      'S21F114M1',
#      'S21F115M1',
#      'S21F116M1',
#      'S21F117M1',
#      'S21F118M1',
#      'S21F119M1',
#      'S21F120M1',
#      'S21F121M1',
#      'S21F122M1',
#      'S21F123M1',
#      'S21F124M1',
#      'S21F125M1'],
#     'input_combo_name': 'One Acre Seed Pkt',
#     'store_name': 'IC21008',
#     'section': '',
#     'quantity_in_numbers': 25,
#     'total_acre': Decimal('25.00'),
#     'input_combo_acre': Decimal('1.00'),
#     'total_price': Decimal('57500.00'),
#     'input_combo_id': 8,
#     'input_combo_price': Decimal('2300.00'),
#     'dispatch_date': Timestamp('2021-03-15 08:56:16.465785+0000', tz='UTC'),
#     'supervisor_name': 'naveen',
#     'dispatched_by_id': 82,
#     'issue_rised_date': Timestamp('2021-03-10 04:32:19.053778+0000', tz='UTC'),
#     'label_from': 'S21F11M1',
#     'label_to': 'S21F125M1'}]},
#  'input_combo_list': [{'combo_issue_request': 21,
#    'store_id': 2,
#    'label': ['S21F11M1',
#     'S21F12M1',
#     'S21F13M1',
#     'S21F14M1',
#     'S21F15M1',
#     'S21F16M1',
#     'S21F17M1',
#     'S21F18M1',
#     'S21F19M1',
#     'S21F110M1',
#     'S21F111M1',
#     'S21F112M1',
#     'S21F113M1',
#     'S21F114M1',
#     'S21F115M1',
#     'S21F116M1',
#     'S21F117M1',
#     'S21F118M1',
#     'S21F119M1',
#     'S21F120M1',
#     'S21F121M1',
#     'S21F122M1',
#     'S21F123M1',
#     'S21F124M1',
#     'S21F125M1'],
#    'input_combo_name': 'One Acre Seed Pkt',
#    'store_name': 'IC21008',
#    'section': '',
#    'quantity_in_numbers': 25,
#    'total_acre': Decimal('25.00'),
#    'input_combo_acre': Decimal('1.00'),
#    'total_price': Decimal('57500.00'),
#    'input_combo_id': 8,
#    'input_combo_price': Decimal('2300.00'),
#    'dispatch_date': Timestamp('2021-03-15 08:56:16.465785+0000', tz='UTC'),
#    'supervisor_name': 'naveen',
#    'dispatched_by_id': 82,
#    'issue_rised_date': Timestamp('2021-03-10 04:32:19.053778+0000', tz='UTC'),
#    'label_from': 'S21F11M1',
#    'label_to': 'S21F125M1'}],
#  'bill_number': '43',
#  'input_combo_dict': {8: {'value': Decimal('100.000'), 'unit_name': 'Grams'}}}

# %%
def encode_image_with_out_static(image_path):
    image_path = str(image_path)
    with open(image_path, "rb") as image_file:
        encoded_image = b64encode(image_file.read())
        image = "data:image/pdf;base64," + encoded_image.decode("utf-8")
        return image

# %%
from reportlab.pdfgen import canvas
from reportlab.platypus import BaseDocTemplate, SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.pagesizes import letter, A4
from reportlab.lib.units import inch
from reportlab.lib import colors
from reportlab.lib.colors import HexColor
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
import datetime
import os
import math
from base64 import b64encode, b64decode


#file path
today_date = datetime.datetime.now().date()
file_name = str(new_bill_code) + '.pdf'
try:
    path = os.path.join('static/media/agent_receipt/', str(agent_id), str(today_date))
    os.makedirs(path)
except FileExistsError:
    print('already created')
file_path = os.path.join('static/media/agent_receipt/' + str(agent_id) + '/' + str(today_date) + '/',file_name)

# file generation
mycanvas = canvas.Canvas(file_path, pagesize=A4)

#border line
mycanvas.line(25,820,570,820)
mycanvas.line(25,20,570,20)
mycanvas.line(25,820,25,20)
mycanvas.line(570,820,570,20)
img_file = os.path.join('static/media/',"ccgb_logo.jpeg")
mycanvas.drawInlineImage(img_file, 40, 760,(.6*inch), (.8*inch))


#heading part
mycanvas.setFont('Helvetica-Bold', 17)
mycanvas.drawCentredString(325, 800,'CHENGUANG NATURAL EXTRACTS (INDIA) PVT.LTD.,')
mycanvas.setFont('Helvetica', 12)
mycanvas.drawCentredString(305, 780,'SY.No.251,Thriyambakapura Village,Terakanambi Hobali,Gundlupet Taluk,')
mycanvas.setFont('Helvetica', 13)
mycanvas.drawCentredString(305, 760,'Chamarajanagar District')
mycanvas.setFont('Helvetica-Bold', 17)
mycanvas.drawCentredString(305, 735,'AGENT SEED ISSUE RECEIPT')


#actual pdf part

#left Side
mycanvas.setFont('Helvetica', 12)
mycanvas.drawString(40,700,str('R.No. ')+str(data_dict['bill_number']))
mycanvas.drawString(40,670,str('Agent Name: ')+str(data_dict['agent_name']))
mycanvas.drawString(40,640,str('Father Name: ')+str(data_dict['father_name']))
mycanvas.drawString(40,610,str('Supervisor Name: ')+str(data_dict['superior_name']))
mycanvas.drawString(40,580,str('Permission department: '))

#Right Side
mycanvas.setFont('Helvetica', 12)
mycanvas.drawString(350,700,str('Date: ')+str(datetime.datetime.now().date()))
mycanvas.drawString(350,670,str('Agent Code: ')+str(data_dict['agent_code']))
mycanvas.drawString(350,640,str('Village Name: ')+str(data_dict['village_ame']))
mycanvas.drawString(350,610,str('Cluster: ')+str(data_dict['cluster_name']))
mycanvas.drawString(350,580,str('Out Time: '))


#Table Content
mycanvas.setFont('Helvetica-Bold', 15)
mycanvas.drawCentredString(305, 545,'Seed Details')

#headder part
mycanvas.line(25,538,570,538)
mycanvas.line(25,500,570,500)

mycanvas.setFont('Helvetica-Bold', 12)
mycanvas.drawCentredString(50, 515,'Items')
mycanvas.drawCentredString(105, 515,'Lot No')
mycanvas.drawCentredString(165, 515,'Lable No')
mycanvas.drawCentredString(240, 525,'Req. Date /')
mycanvas.drawCentredString(240, 510,'Dspt. Date')
mycanvas.drawCentredString(305, 515,'Value')

mycanvas.drawCentredString(370, 520,'No Of')
mycanvas.drawCentredString(370, 505,'Pkts')

mycanvas.drawCentredString(420, 515,'Acre')
mycanvas.drawCentredString(460, 515,'Price')
mycanvas.drawCentredString(530, 515,'Amount')

y = 480
x = 110
total_num_of_packet = 0
total_num_of_acre = 0
total_price = 0
mycanvas.setLineWidth(0)
mycanvas.setFont('Helvetica', 10)
supervisor_name = ''
for input_combo in data_dict['input_combo_list']:
    length = len(data_dict['input_part_list'][input_combo['combo_issue_request']])
    length = length/2
    length = math.ceil(length)
    store_id = data_dict['input_part_list'][input_combo['combo_issue_request']][length-1]['store_id']
    for input_part in data_dict['input_part_list'][input_combo['combo_issue_request']]:
        mycanvas.drawString(x-25, y ,str(input_part['store_name'])+" "+str(input_part['section']))
        mycanvas.setFont('Helvetica', 9)
        mycanvas.drawString(x+25, y+5 ,str(input_part['label_from'])+ ' -')
        mycanvas.drawString(x+25, y-5 ,str(input_part['label_to']))
        mycanvas.drawString(x+105, y+5 ,str(input_part['issue_rised_date'].date()))
        mycanvas.drawString(x+105, y-5 ,str(input_part['dispatch_date'].date()))
        mycanvas.setFont('Helvetica', 10)
        if input_part['store_id'] == store_id:
            name = str(input_combo['input_combo_name']).split(' ')
            if len(name) == 1:
                mycanvas.drawString(30, y ,str(name[0][0:8]))
            else:
                mycanvas.drawString(30, y ,str(name[0][0:4]+" "+ str(name[1])[0:4]))
            unit_value = data_dict['input_combo_dict'][input_combo['input_combo_id']]
            mycanvas.drawString(285, y ,str(int(unit_value['value'])) + ' ' + str(unit_value['unit_name']))

            mycanvas.drawRightString(380, y ,str(input_combo['quantity_in_numbers']))
            total_num_of_packet += input_combo['quantity_in_numbers']

            mycanvas.drawRightString(430, y ,str(int(input_combo['total_acre'])))
            total_num_of_acre += input_combo['total_acre']

            mycanvas.drawRightString(480, y ,str(input_combo['input_combo_price']))

            mycanvas.drawRightString(565, y ,str(input_combo['total_price']))
            total_price += input_combo['total_price']
        supervisor_name = input_combo['supervisor_name']
        y -= 14
    mycanvas.line(25,y,570,y)
    y -= 14



mycanvas.line(x-30,538,x-30,y+15)
mycanvas.line(x+20,538,x+20,y+15)
mycanvas.line(200,538,200,y+15)
mycanvas.line(280,538,280,y+15)
mycanvas.line(340,538,340,y-10)
mycanvas.line(440,538,440,y-10)
mycanvas.line(400,538,400,y-10)
mycanvas.line(490,538,490,y-10)

#Total
mycanvas.line(340,y-10,570,y-10)
mycanvas.setFont('Helvetica', 11)
mycanvas.drawString(300, y-3 , 'Total')
mycanvas.drawRightString(380, y-3 ,str(total_num_of_packet))
mycanvas.drawRightString(430, y-3 ,str(int(total_num_of_acre)))
mycanvas.drawRightString(560, y-3 ,str(total_price))

mycanvas.setFont('Helvetica', 11)
bottom_signs_y_axis = y-80

mycanvas.drawRightString(130,  bottom_signs_y_axis, str('Agent Signature'))
mycanvas.drawRightString(280,  bottom_signs_y_axis, str('Supervisor Signature'))
mycanvas.drawRightString(410,  bottom_signs_y_axis, str('Issued Signature'))
mycanvas.drawRightString(530,  bottom_signs_y_axis, str('GM Signature'))

file_name = str(supervisor_name) + '.jpeg'
sup_file = os.path.join('static/media/signs/',file_name)
mycanvas.drawInlineImage(sup_file, 180, 380,(1.4*inch), (.7*inch))
# img_file = os.path.join('static/media/signs/',"Sirinivasa.jpeg")
gm_img_file = os.path.join('static/media/signs/',"gm.png")
mycanvas.drawInlineImage(gm_img_file, 460, 380,(1.4*inch), (.7*inch))

mycanvas.save()

for issue_request in issue_request_ids:
    combo_issue_receipt_obj = ComboIssueAgentInventoryReceipt(combo_issue_request_id=issue_request,
                                                            agent_id=agent_id,
                                                            bill_number=new_bill_code,
                                                            file=file_path)
    combo_issue_receipt_obj.save()
    combo_issue_obj = ComboIssueRequest.objects.get(id=issue_request)
    combo_issue_obj.max_status_id = 9
    combo_issue_obj.save()
final_dict['pdf'] = encode_image_with_out_static(combo_issue_receipt_obj.file)
final_dict['bill_number'] = combo_issue_receipt_obj.bill_number
# Out:
# already created

# %%
farmer_ids = list(FarmerClusterSeasonMap.objects.filter(season_id=3, seasonal_farmer_code__isnull=True).values_list('farmer_id', flat=True))
farmer_ids
# Out:
# [2672, 2666, 3379, 6102]

# %%
def generate_farmer_code(cluster_id, agent_id, officer_id, season_id):
    season = Season.objects.get(id=season_id).year
    season_name = str(season.strftime("%y"))
    cluster_name = Cluster.objects.get(id=cluster_id).name.upper()
    agent_name = UserClusterMap.objects.get(user_id=agent_id, season_id=season_id).unique_code.upper()
    officer_name = User.objects.get(id=officer_id).username[0:1].upper()
    print(cluster_name)
    print(officer_name)
    print(agent_name)
    prefix = season_name + cluster_name[0] + officer_name[0] + agent_name[0]
    print(prefix)
    if IdBank.objects.filter(purpose="farmer", prefix_code=prefix).exists():
        last_code = IdBank.objects.get(purpose="farmer", prefix_code=prefix).last_count
        IdBank.objects.filter(purpose="farmer", prefix_code=prefix).update(
            last_count=last_code + 1
        )
    else:
        last_code = 0
        id_bank_obj = IdBank(
            purpose="farmer", prefix_code=prefix, last_count=1, business_id=1
        )
        id_bank_obj.save()
    generated_code_number = last_code + 1
    suffix = str(generated_code_number).zfill(3)
    code = str(prefix) + suffix
    return code

# %%
farmer_ids = list(FarmerClusterSeasonMap.objects.filter(season_id=3, seasonal_farmer_code__isnull=True).values_list('farmer_id', flat=True))
for farmer_id in farmer_ids:
    season_id=3
    cluster_id = FarmerClusterSeasonMap.objects.get(season_id=season_id, farmer_id=farmer_id).cluster_id
    print(cluster_id)
    agent_id = AgentFarmerMap.objects.get(farmer__farmer_id=farmer_id, farmer__season_id=season_id).agent_id
    print(agent_id)
    officer_id = UserFarmerMap.objects.get(farmer__farmer_id=farmer_id, farmer__season_id=season_id).officer_id
    print(officer_id)
    FarmerClusterSeasonMap.objects.filter(season_id=3,farmer_id=farmer_id).update(seasonal_farmer_code=generate_farmer_code(cluster_id,agent_id, officer_id, season_id))
    print(FarmerClusterSeasonMap.objects.get(season_id=3,farmer_id=farmer_id).seasonal_farmer_code)
# Out:
# 8
# 43
# 24
# NANJANGUD
# P
# C
# 21NPC
# 21NPC011
# 8
# 43
# 24
# NANJANGUD
# P
# C
# 21NPC
# 21NPC012
# 2
# 120
# 29
# TERAKANAMBI
# K
# E
# 21TKE
# 21TKE001
# 2
# 47
# 23
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# <ipython-input-3-4dc5be70d059> in <module>
#       7     officer_id = UserFarmerMap.objects.get(farmer__farmer_id=farmer_id, farmer__season_id=season_id).officer_id
#       8     print(officer_id)
# ----> 9     FarmerClusterSeasonMap.objects.filter(season_id=3,farmer_id=farmer_id).update(seasonal_farmer_code=generate_farmer_code(cluster_id,agent_id, officer_id, season_id))
#      10     print(FarmerClusterSeasonMap.objects.get(season_id=3,farmer_id=farmer_id).seasonal_farmer_code)
#
# <ipython-input-2-25170dc4952e> in generate_farmer_code(cluster_id, agent_id, officer_id, season_id)
#       3     season_name = str(season.strftime("%y"))
#       4     cluster_name = Cluster.objects.get(id=cluster_id).name.upper()
# ----> 5     agent_name = UserClusterMap.objects.get(user_id=agent_id, season_id=season_id).unique_code.upper()
#       6     officer_name = User.objects.get(id=officer_id).username[0:1].upper()
#       7     print(cluster_name)
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     376             return clone._result_cache[0]
#     377         if not num:
# --> 378             raise self.model.DoesNotExist(
#     379                 "%s matching query does not exist." %
#     380                 self.model._meta.object_name
#
# DoesNotExist: UserClusterMap matching query does not exist.

# %%
UserClusterMap.objects.filter(user_id=47, season_id=season_id)
# Out:
# <QuerySet []>

# %%
User.objects.filter(id=47)[0].first_name
# Out:
# 'Manu'

# %%
Cluster.objects.filter(id=2)[0].name
# Out:
# 'Terakanambi'

# %%
FarmerClusterSeasonMap.objects.get(seasonal_farmer_code='21NGE002').time_created
# Out:
# datetime.datetime(2021, 3, 25, 10, 20, 14, 9626, tzinfo=<UTC>)

# %%
UserFarmerMap.objects.filter(farmer_id=6005).time_created
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-379ccd8803c5> in <module>
# ----> 1 UserFarmerMap.objects.filter(farmer_id=6005).time_created
#
# AttributeError: 'QuerySet' object has no attribute 'time_created'

# %%
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=3):
    season_id=3
    farmer_id = farmer.farmer.id
    cluster_id = FarmerClusterSeasonMap.objects.get(season_id=season_id, farmer_id=farmer_id).cluster_id
    agent_id = AgentFarmerMap.objects.get(farmer__farmer_id=farmer_id, farmer__season_id=season_id).agent_id
    officer_id = UserFarmerMap.objects.get(farmer__farmer_id=farmer_id, farmer__season_id=season_id).officer_id
    code = generate_farmer_code(cluster_id,agent_id, officer_id, season_id)
    FarmerClusterSeasonMap.objects.filter(id=farmer.id, season_id=3).update(seasonal_farmer_code=code)
    Farmer.objects.filter(id=farmer.farmer.id).update(code=code)
    print('===========================')
print(FarmerClusterSeasonMap.objects.filter(season_id=3).count())
# Out:
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# TERAKANAMBI
# K
# E
# 21TKE
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# NANJANGUD
# P
# F
# 21NPF
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# GOPALPURA
# N
# I
# 21GNI
# ===========================
# GOPALPURA
# N
# I
# 21GNI
# ===========================
# GOPALPURA
# N
# I
# 21GNI
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# SARGUR
# S
# E
# 21SSE
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# SARGUR
# S
# E
# 21SSE
# ===========================
# SARGUR
# S
# E
# 21SSE
# ===========================
# SARGUR
# S
# E
# 21SSE
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# TERAKANAMBI
# K
# B
# 21TKB
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# HD KOTE
# S
# G
# 21HSG
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# KODASOGE
# P
# E
# 21KPE
# ===========================
# NANJANGUD
# P
# F
# 21NPF
# ===========================
# NANJANGUD
# P
# F
# 21NPF
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# NANJANGUD
# P
# C
# 21NPC
# ===========================
# 86

# %%
def generate_farmer_code(cluster_id, agent_id, officer_id, season_id):
    season = Season.objects.get(id=season_id).year
    season_name = str(season.strftime("%y"))
    cluster_name = Cluster.objects.get(id=cluster_id).name.upper()
    agent_name = UserClusterMap.objects.get(user_id=agent_id, season_id=season_id).unique_code.upper()
    officer_name = User.objects.get(id=officer_id).username[0:1].upper()
    print(cluster_name)
    print(officer_name)
    print(agent_name)
    prefix = season_name + cluster_name[0] + officer_name[0] + agent_name[0]
    print(prefix)
    if IdBank.objects.filter(purpose="farmer", prefix_code=prefix).exists():
        last_code = IdBank.objects.get(purpose="farmer", prefix_code=prefix).last_count
        IdBank.objects.filter(purpose="farmer", prefix_code=prefix).update(
            last_count=last_code + 1
        )
    else:
        last_code = 0
        id_bank_obj = IdBank(
            purpose="farmer", prefix_code=prefix, last_count=1, business_id=1
        )
        id_bank_obj.save()
    generated_code_number = last_code + 1
    suffix = str(generated_code_number).zfill(3)
    code = str(prefix) + suffix
    return code

# %%
temp_code = 213
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=3):
    FarmerClusterSeasonMap.objects.filter(id=farmer.id,).update(seasonal_farmer_code=temp_code)
    Farmer.objects.filter(id=farmer.farmer.id).update(code=temp_code)
    temp_code = temp_code +1

# %%
AgentFarmerMap.objects.get(farmer__season_id=3,agent_id=47).farmer.id
# Out:
# 5996

# %%
import pandas as pd
user_id = 78
user_type_id = UserProfile.objects.get(user=user_id).user_type_id
season_id = 3
# season_id=request.data['season_id']
print("superior id:", user_id)
user_type_id = UserProfile.objects.get(user=user_id).user_type_id
if user_type_id == 5:
    subordinate_user_ids = list(AgentSupervisorSeasonMap.objects.filter(supervisor_id=user_id, season_id=season_id).values_list('supervisor_id', flat=True))
else:
    if user_type_id == 3:
        if UserHierarchyMap.objects.filter(superior_id=user_id).exists():
            subordinates = UserHierarchyMap.objects.filter(superior_id=user_id)
            subordinate_user_ids = list(subordinates.values_list("subordinate", flat=True))
            print("one")
            print(subordinate_user_ids)
            subordinate_user_ids = list(AgentSupervisorSeasonMap.objects.filter(supervisor_id__in=subordinate_user_ids, season_id=season_id).values_list('supervisor_id',flat=True))
            print(len(subordinate_user_ids))
    else:
        subordinate_user_ids = list(AgentSupervisorSeasonMap.objects.filter(season_id=season_id).values_list('supervisor_id',flat=True))
if UserFarmerMap.objects.filter(officer_id__in=subordinate_user_ids, farmer__season_id=season_id).exists():
    # farmer
    print(subordinate_user_ids)
    farmer_ids = list(UserFarmerMap.objects.filter(officer_id__in=subordinate_user_ids, farmer__season_id=season_id).values_list("farmer__farmer_id", flat=True))
    farmer_objs = Farmer.objects.filter(id__in=farmer_ids).order_by("first_name")
    farmer_values = farmer_objs.values_list("id", "first_name", "last_name", "mobile", "alternate_mobile", "email", "address", "state_id", "state__name", "hobli_id", "hobli__name", 
                                            "pincode", "aadhaar_number", "cultivated_for_ccgb_since", "latitude", "longitude", "district_id", "district__name", "taluk_id", 
                                            "taluk__name", "village_id", "village__name", "latitude", "longitude")
    farmer_columns = [ "farmer_id", "first_name", "last_name", "mobile", "alternate_mobile", "email", "street", "state_id", "state__name", "hobli_id", "hobli_name", "pincode", 
                      "aadhaar_number", "collaborated_with_company_on", "latitude", "longitude", "district_id", "district_name", "taluk_id", "taluk_name", "village_id", 
                      "village_name", "latitude", "longitude",]
    farmer_df = pd.DataFrame(list(farmer_values), columns=farmer_columns)

    #  farmer cluster
    farmer_cluster_map_values = FarmerClusterSeasonMap.objects.filter(season_id=season_id).values_list("id", "farmer_id", "seasonal_farmer_code", 'cluster_id', 'cluster__name')
    farmer_cluster_columns = ["farmer_cluster_map_id", "farmer_id","code", "cluster_id", "cluster_name"]
    farmer_cluster_df = pd.DataFrame(list(farmer_cluster_map_values), columns=farmer_cluster_columns)

    # agent farmer map
    agent_farmer_map_values = AgentFarmerMap.objects.filter(farmer__season_id=season_id).values_list("id", "farmer__farmer_id", "agent__first_name", "farmer__season__name", "agent_id","agent__userprofile__mobile")
    agent_farmer_columns = [ "agent_farmer_map_id", "farmer_id", "agent_first_name", "season_name", "agent_id", "agent_mobile"]
    agent_farmer_df = pd.DataFrame(list(agent_farmer_map_values), columns=agent_farmer_columns)

    # merge farmer with agent
    merged_df = pd.merge( farmer_df, agent_farmer_df, left_on="farmer_id", right_on="farmer_id", how="left",)

    # merge farmer with cluster
    farmer_cluster_merged_df = pd.merge( merged_df, farmer_cluster_df, left_on="farmer_id", right_on="farmer_id", how="left",)
    farmer_cluster_merged_df["total_main_crop_area"] = farmer_cluster_merged_df.apply(lambda x: find_main_crop_area(x["farmer_id"], season_id), axis=1)
    farmer_cluster_merged_df["yeild"] = 0
    farmer_cluster_merged_df["total_nursury_crop_area"] = farmer_cluster_merged_df.apply(lambda x: find_nursury_crop_area(x["farmer_id"], season_id), axis=1)
    farmer_cluster_merged_df["nursury_crop_age_list"] = farmer_cluster_merged_df.apply(lambda x: find_nursury_age_list(x["farmer_id"], season_id), axis=1)
    farmer_cluster_merged_df["main_crop_age_list"] = farmer_cluster_merged_df.apply(lambda x: find_main_age_list(x["farmer_id"], season_id), axis=1)
    farmer_cluster_merged_df["harvest_area"] = farmer_cluster_merged_df.apply(lambda x: get_harvest_area(x['farmer_id'], season_id), axis=1)
    farmer_cluster_merged_df["harvest_qty"] = farmer_cluster_merged_df.apply(lambda x: get_harvest_qty(x['farmer_id'], season_id), axis=1)
    farmer_cluster_merged_df["transplanting_gps_status"] = farmer_cluster_merged_df.apply(lambda x: get_gps_status(x["farmer_id"], season_id), axis=1)
    farmer_cluster_merged_df["sowing_gps_status"] = farmer_cluster_merged_df.apply(lambda x: get_gps_status(x["farmer_id"], season_id), axis=1)

    sowing_values = Sowing.objects.filter(farmer_id__in=farmer_ids, season_id=season_id).values_list("id","farmer_id","crop__name","cultivation_phase_id","cultivation_phase__name","sowing_date",)
    sowing_columns = [ "sowing_id", "farmer_id", "crop_name", "cultivation_phase_id", "cultivation_phase__name", "sowing_date",]
    sowing_df = pd.DataFrame(list(sowing_values), columns=sowing_columns)
    today = datetime.date.today()
    sowing_df["crop_age_list"] = today - sowing_df["sowing_date"]
    sowing_df["crop_age_list"] = sowing_df["crop_age_list"].astype("timedelta64[D]")
    sowing_df["crop_age_list"] = sowing_df["crop_age_list"].astype(int)

    sowing_area_df = (sowing_df.groupby("farmer_id")["crop_age_list"].apply(list).to_frame())
    cultivation_phase_merge = (sowing_df.groupby("farmer_id")["cultivation_phase_id"].apply(list).to_frame())

    area_merge = pd.merge(farmer_cluster_merged_df,sowing_area_df,left_on="farmer_id",right_on="farmer_id",how="left",)
    phase_merge = pd.merge(area_merge,cultivation_phase_merge,left_on="farmer_id",right_on="farmer_id",how="left",)

    final_df = phase_merge.fillna(0)
    final_df = final_df.to_dict("r")
else:
    final_df = []
final_df
# Out:
# superior id: 78
# [30, 24, 24, 30, 29, 27, 27, 27, 27, 149, 149, 149, 149, 149, 25, 25, 25, 25, 27, 27, 27, 27, 28, 29, 29, 29, 29, 29, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 24, 24, 24, 24, 24, 28, 28, 28, 24, 28, 30, 30, 30, 30, 30]
# <ipython-input-71-7c19e8753028>:74: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   final_df = final_df.to_dict("r")
# [{'farmer_id': 6208,
#   'first_name': 'alamma',
#   'last_name': 'marigowda',
#   'mobile': '9380615548',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0033511'),
#   'longitude': Decimal('76.3950177'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 377,
#   'village_name': 'Hosaveedu',
#   'agent_farmer_map_id': 6098,
#   'agent_first_name': 'H M Mahadevaswamy',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 87,
#   'agent_mobile': '8105499954',
#   'farmer_cluster_map_id': 6114,
#   'code': '21NPG008',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 5.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 3.0,
#   'nursury_crop_age_list': '2, ',
#   'main_crop_age_list': '-8, ',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 2,
#   'sowing_gps_status': 2,
#   'crop_age_list': [2, -8],
#   'cultivation_phase_id': [1, 2]},
#  {'farmer_id': 6143,
#   'first_name': 'Arun Rasheed',
#   'last_name': 'Mohammed Suleman',
#   'mobile': '9164804806',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0112125'),
#   'longitude': Decimal('76.3917625'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 357,
#   'village_name': 'Hediyala',
#   'agent_farmer_map_id': 6025,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6041,
#   'code': '21NPC028',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 2.0,
#   'nursury_crop_age_list': '-6, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [-6],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6135,
#   'first_name': 'Avinash',
#   'last_name': 'Javaraju',
#   'mobile': '8722783726',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 849,
#   'village_name': 'Chilakahalli',
#   'agent_farmer_map_id': 6017,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6033,
#   'code': '21NPC020',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6138,
#   'first_name': 'Bangara V S',
#   'last_name': 'Sannamadaiah',
#   'mobile': '8088310352',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6020,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6036,
#   'code': '21NPC023',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6108,
#   'first_name': 'basamani',
#   'last_name': 'shivanna',
#   'mobile': '9197189999',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 72,
#   'hobli_name': 'Kavlande',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 163,
#   'village_name': 'Gattavadipura',
#   'agent_farmer_map_id': 5986,
#   'agent_first_name': 'Nataraju',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 59,
#   'agent_mobile': '9731359912',
#   'farmer_cluster_map_id': 6002,
#   'code': '21TKB005',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '14, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [14],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6196,
#   'first_name': 'Basavaiah',
#   'last_name': 'late Basavaiah',
#   'mobile': '8971109516',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '663483556578',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 857,
#   'village_name': 'Jalahalli',
#   'agent_farmer_map_id': 6084,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6100,
#   'code': '21HSG010',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.5,
#   'nursury_crop_age_list': '21, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [21],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6109,
#   'first_name': 'basavanna',
#   'last_name': 'c.mallappa',
#   'mobile': '9353702653',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 72,
#   'hobli_name': 'Kavlande',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 163,
#   'village_name': 'Gattavadipura',
#   'agent_farmer_map_id': 5987,
#   'agent_first_name': 'Nataraju',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 59,
#   'agent_mobile': '9731359912',
#   'farmer_cluster_map_id': 6003,
#   'code': '21TKB006',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '10, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [10],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 2803,
#   'first_name': 'basavanna',
#   'last_name': 'mahadevappa',
#   'mobile': '9663971886',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 10,
#   'hobli_name': 'Terakanambi',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 165,
#   'village_name': 'Guruvinapura',
#   'agent_farmer_map_id': 6092,
#   'agent_first_name': 'Muruga_Terakanambi',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 120,
#   'agent_mobile': '9449203315',
#   'farmer_cluster_map_id': 6108,
#   'code': '21TKE004',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '6, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [6],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6111,
#   'first_name': 'Basavanna M',
#   'last_name': 'Mahadevappa S',
#   'mobile': '9743949632',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 35,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 26,
#   'district_name': 'Mysuru',
#   'taluk_id': 171,
#   'taluk_name': 'Saraguru',
#   'village_id': 845,
#   'village_name': 'Kellipura',
#   'agent_farmer_map_id': 5989,
#   'agent_first_name': 'Suresha',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 140,
#   'agent_mobile': '8494824676',
#   'farmer_cluster_map_id': 6005,
#   'code': '21NPF001',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '14, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [14],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6136,
#   'first_name': 'Basavarajappa',
#   'last_name': 'Nanjundappa',
#   'mobile': '8722928924',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 849,
#   'village_name': 'Chilakahalli',
#   'agent_farmer_map_id': 6018,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6034,
#   'code': '21NPC021',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6186,
#   'first_name': 'Beeraswamy ',
#   'last_name': 'Madegowda',
#   'mobile': '9632377530',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571211,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.9282943'),
#   'longitude': Decimal('76.5700705'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 377,
#   'village_name': 'Hosaveedu',
#   'agent_farmer_map_id': 6074,
#   'agent_first_name': 'H M Mahadevaswamy',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 87,
#   'agent_mobile': '8105499954',
#   'farmer_cluster_map_id': 6090,
#   'code': '21NPG001',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '15, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [15],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6172,
#   'first_name': 'Bellaiah',
#   'last_name': 'Bellaiah',
#   'mobile': '7892049758',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 'undefined , undefined , Yeriyur , Chamrajanagar',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 10,
#   'hobli_name': 'Terakanambi',
#   'pincode': 571111,
#   'aadhaar_number': '470445393503',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 208,
#   'village_name': 'Yariyooru',
#   'agent_farmer_map_id': 6058,
#   'agent_first_name': 'Mahesh  Yariyooru',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 74,
#   'agent_mobile': '9008791197',
#   'farmer_cluster_map_id': 6074,
#   'code': '21KPE003',
#   'cluster_id': 3,
#   'cluster_name': 'kodasoge',
#   'total_main_crop_area': 7.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.5,
#   'nursury_crop_age_list': '8, ',
#   'main_crop_age_list': '2, ',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 2,
#   'sowing_gps_status': 2,
#   'crop_age_list': [8, 2],
#   'cultivation_phase_id': [1, 2]},
#  {'farmer_id': 3420,
#   'first_name': 'bhagya',
#   'last_name': 'gurumallappa',
#   'mobile': '7026323208',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 42,
#   'hobli_name': 'Kowlande',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 26,
#   'district_name': 'Mysuru',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 458,
#   'village_name': 'bedarapura',
#   'agent_farmer_map_id': 6070,
#   'agent_first_name': 'Muruga_Terakanambi',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 120,
#   'agent_mobile': '9449203315',
#   'farmer_cluster_map_id': 6086,
#   'code': '21TKE003',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '3, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [3],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6213,
#   'first_name': 'Bili Thayamma',
#   'last_name': 'late Mahadeva',
#   'mobile': '6361057328',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 69,
#   'hobli_name': 'Antharasanthe',
#   'pincode': 571114,
#   'aadhaar_number': '591509724648',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 859,
#   'village_name': 'Jiyara coloni',
#   'agent_farmer_map_id': 6103,
#   'agent_first_name': 'Parameswaran_hd_kote',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 63,
#   'agent_mobile': '9738080982',
#   'farmer_cluster_map_id': 6119,
#   'code': '21HSE003',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '2, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [2],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6198,
#   'first_name': 'Chamaiah',
#   'last_name': 'Mariyaiah',
#   'mobile': '9632267066',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '530952955151',
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.9961931'),
#   'longitude': Decimal('76.4952763'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 857,
#   'village_name': 'Jalahalli',
#   'agent_farmer_map_id': 6087,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6103,
#   'code': '21HSG011',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.5,
#   'nursury_crop_age_list': '19, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [19],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6188,
#   'first_name': 'Chandra Shekara',
#   'last_name': 'Shivanna',
#   'mobile': '9845733684',
#   'alternate_mobile': '9844055743',
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 23,
#   'hobli_name': 'Sargur',
#   'pincode': 571121,
#   'aadhaar_number': '655311506064',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 856,
#   'village_name': 'Kallambalu ',
#   'agent_farmer_map_id': 6076,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6092,
#   'code': '21HSG002',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '20, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [20],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6200,
#   'first_name': 'Channaiah',
#   'last_name': 'Kempa Siddaiah',
#   'mobile': '9845733683',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '828206118282',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 857,
#   'village_name': 'Jalahalli',
#   'agent_farmer_map_id': 6089,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6105,
#   'code': '21HSG013',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.5,
#   'nursury_crop_age_list': '23, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [23],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6116,
#   'first_name': 'Channegowda',
#   'last_name': 'Eregowda',
#   'mobile': '8747829172',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 357,
#   'village_name': 'Hediyala',
#   'agent_farmer_map_id': 5995,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6011,
#   'code': '21NPC005',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 4109,
#   'first_name': 'chikkusappa',
#   'last_name': 'kempappa',
#   'mobile': '9880485501',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 16,
#   'hobli_name': 'Harave',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 61,
#   'taluk_name': 'Chamarajanagar',
#   'village_id': 488,
#   'village_name': 'maleyuru',
#   'agent_farmer_map_id': 6086,
#   'agent_first_name': 'Nataraju',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 59,
#   'agent_mobile': '9731359912',
#   'farmer_cluster_map_id': 6102,
#   'code': '21TKB009',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 2.0,
#   'nursury_crop_age_list': '7, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [7],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6201,
#   'first_name': 'C Mahadeva',
#   'last_name': 'Channaiah',
#   'mobile': '9632217225',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '293463923101',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 857,
#   'village_name': 'Jalahalli',
#   'agent_farmer_map_id': 6090,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6106,
#   'code': '21HSG014',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '17, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [17],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6220,
#   'first_name': 'Devamma',
#   'last_name': 'Baira Nayaka',
#   'mobile': '9071132023',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571314,
#   'aadhaar_number': '292160772833',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 860,
#   'village_name': 'Ibjala',
#   'agent_farmer_map_id': 6110,
#   'agent_first_name': 'Parameswaran_hd_kote',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 63,
#   'agent_mobile': '9738080982',
#   'farmer_cluster_map_id': 6126,
#   'code': '21HSE007',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '2, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [2],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6117,
#   'first_name': 'Devendrappa',
#   'last_name': 'Basappa',
#   'mobile': '8105812685',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.7904610'),
#   'longitude': Decimal('76.7576444'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 808,
#   'village_name': 'Channagundi',
#   'agent_farmer_map_id': 5997,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6013,
#   'code': '21NPC006',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6154,
#   'first_name': 'Devendrappa C P',
#   'last_name': 'C N Puttasomappa',
#   'mobile': '7760667484',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0113249'),
#   'longitude': Decimal('76.3916175'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 808,
#   'village_name': 'Channagundi',
#   'agent_farmer_map_id': 6036,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6052,
#   'code': '21NPC039',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6217,
#   'first_name': 'E M Nagarajappa',
#   'last_name': 'E M Mahadevappa ',
#   'mobile': '8971512641',
#   'alternate_mobile': '8971512641',
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571314,
#   'aadhaar_number': '293126643026',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 860,
#   'village_name': 'Ibjala',
#   'agent_farmer_map_id': 6107,
#   'agent_first_name': 'Parameswaran_hd_kote',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 63,
#   'agent_mobile': '9738080982',
#   'farmer_cluster_map_id': 6123,
#   'code': '21HSE004',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 3.0,
#   'nursury_crop_age_list': '11, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [11],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6182,
#   'first_name': 'Gopala ',
#   'last_name': 'B S Ramasanjeeva naidu',
#   'mobile': '7259508711',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 23,
#   'hobli_name': 'Sargur',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.8733887'),
#   'longitude': Decimal('76.3752929'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 852,
#   'village_name': 'Doddabaragi',
#   'agent_farmer_map_id': 6068,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6084,
#   'code': '21NPC059',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '9, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [9],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6168,
#   'first_name': 'Govindaiah',
#   'last_name': 'Javaraiah',
#   'mobile': '8496930013',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 574121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0113249'),
#   'longitude': Decimal('76.3916175'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 357,
#   'village_name': 'Hediyala',
#   'agent_farmer_map_id': 6054,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6070,
#   'code': '21NPC057',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6218,
#   'first_name': 'Govindanayaka',
#   'last_name': 'late Kooradasanayaka',
#   'mobile': '9164951372',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571314,
#   'aadhaar_number': '311613210336',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 860,
#   'village_name': 'Ibjala',
#   'agent_farmer_map_id': 6108,
#   'agent_first_name': 'Parameswaran_hd_kote',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 63,
#   'agent_mobile': '9738080982',
#   'farmer_cluster_map_id': 6124,
#   'code': '21HSE005',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '10, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [10],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 2882,
#   'first_name': 'Govindayya',
#   'last_name': 'Javarayya',
#   'mobile': '7353947128',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 26,
#   'district_name': 'Mysuru',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6053,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6069,
#   'code': '21NPC056',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 2672,
#   'first_name': 'Govindegowdru',
#   'last_name': 'Betegowda',
#   'mobile': '9964979742',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 511314,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 26,
#   'district_name': 'Mysuru',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 347,
#   'village_name': 'Bhadagalapura',
#   'agent_farmer_map_id': 5991,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6007,
#   'code': '21NPC014',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6183,
#   'first_name': 'Gowramma',
#   'last_name': 'krishana',
#   'mobile': '7259507506',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 'undefined , undefined , Hosakadajetty , Mysuru',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '882334291368',
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0015047'),
#   'longitude': Decimal('76.5151204'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 853,
#   'village_name': 'Ariyuru',
#   'agent_farmer_map_id': 6071,
#   'agent_first_name': 'Ranga Swamy',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 48,
#   'agent_mobile': '9743165940',
#   'farmer_cluster_map_id': 6087,
#   'code': '21NPD001',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 4.0,
#   'nursury_crop_age_list': '3, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [3],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6125,
#   'first_name': 'Halegowda ',
#   'last_name': 'lingegowda',
#   'mobile': '9902510334',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.8848724'),
#   'longitude': Decimal('76.4753359'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 848,
#   'village_name': 'Bankahalli',
#   'agent_farmer_map_id': 6006,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6022,
#   'code': '21NPC011',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '19, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [19],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6128,
#   'first_name': 'HB Raghu',
#   'last_name': 'HK Basavarajappa',
#   'mobile': '9886946386',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 23,
#   'hobli_name': 'Sargur',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0033615'),
#   'longitude': Decimal('76.3942321'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 676,
#   'village_name': 'Hanchipura',
#   'agent_farmer_map_id': 6009,
#   'agent_first_name': 'H S Yogesh',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 145,
#   'agent_mobile': '9632499326',
#   'farmer_cluster_map_id': 6025,
#   'code': '21SSE002',
#   'cluster_id': 6,
#   'cluster_name': 'Sargur',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '12, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [12],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6137,
#   'first_name': 'H R Srinivasa',
#   'last_name': 'Ramakrishna',
#   'mobile': '9606381753',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0112125'),
#   'longitude': Decimal('76.3917625'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 357,
#   'village_name': 'Hediyala',
#   'agent_farmer_map_id': 6019,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6035,
#   'code': '21NPC022',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6173,
#   'first_name': 'Hunugaiah',
#   'last_name': 'Hunugaiah',
#   'mobile': '9380210280',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 'undefined , undefined , Yeriyur , Chamrajanagar',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 10,
#   'hobli_name': 'Terakanambi',
#   'pincode': 571111,
#   'aadhaar_number': '427203218827',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 208,
#   'village_name': 'Yariyooru',
#   'agent_farmer_map_id': 6059,
#   'agent_first_name': 'Mahesh  Yariyooru',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 74,
#   'agent_mobile': '9008791197',
#   'farmer_cluster_map_id': 6075,
#   'code': '21KPE004',
#   'cluster_id': 3,
#   'cluster_name': 'kodasoge',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '8, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [8],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6194,
#   'first_name': 'Javaramma',
#   'last_name': 'Hanumanthaiah',
#   'mobile': '9880921494',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': '728513312304',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 857,
#   'village_name': 'Jalahalli',
#   'agent_farmer_map_id': 6082,
#   'agent_first_name': 'Puttamallappa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 91,
#   'agent_mobile': '9900949142',
#   'farmer_cluster_map_id': 6098,
#   'code': '21HSG008',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '23, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [23],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6151,
#   'first_name': 'jyothi',
#   'last_name': 'Ramadasaiah',
#   'mobile': '9611845005',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0113249'),
#   'longitude': Decimal('76.3916175'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6033,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6049,
#   'code': '21NPC036',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6140,
#   'first_name': 'Kamalamma',
#   'last_name': 'Javaraiah',
#   'mobile': '9663757102',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 850,
#   'village_name': 'Hadanuru',
#   'agent_farmer_map_id': 6022,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6038,
#   'code': '21NPC025',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6214,
#   'first_name': 'Karishetty',
#   'last_name': 'Venkatashetty',
#   'mobile': '7022516534',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 10,
#   'hobli_name': 'Terakanambi',
#   'pincode': 571111,
#   'aadhaar_number': '635600614745',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 178,
#   'village_name': 'Lakkuru',
#   'agent_farmer_map_id': 6104,
#   'agent_first_name': 'Muruga_Terakanambi',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 120,
#   'agent_mobile': '9449203315',
#   'farmer_cluster_map_id': 6120,
#   'code': '21TKE005',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.5,
#   'nursury_crop_age_list': '1, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [1],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6161,
#   'first_name': 'kempamma',
#   'last_name': 'chaluvaiah',
#   'mobile': '7760645358',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0113249'),
#   'longitude': Decimal('76.3916175'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 355,
#   'village_name': 'Kadabeguru',
#   'agent_farmer_map_id': 6043,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6059,
#   'code': '21NPC046',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6219,
#   'first_name': 'Kendaganna Nayaka',
#   'last_name': 'Nanjunda Nayaka',
#   'mobile': '9148637131',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571314,
#   'aadhaar_number': '589409317903',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 860,
#   'village_name': 'Ibjala',
#   'agent_farmer_map_id': 6109,
#   'agent_first_name': 'Parameswaran_hd_kote',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 63,
#   'agent_mobile': '9738080982',
#   'farmer_cluster_map_id': 6125,
#   'code': '21HSE006',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '6, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [6],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6170,
#   'first_name': 'Kongalappa',
#   'last_name': 'Kongalappa',
#   'mobile': '8660138701',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 'undefined , undefined , Yeriyur , Chamrajanagar',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 10,
#   'hobli_name': 'Terakanambi',
#   'pincode': 571111,
#   'aadhaar_number': '571830638733',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 208,
#   'village_name': 'Yariyooru',
#   'agent_farmer_map_id': 6056,
#   'agent_first_name': 'Mahesh  Yariyooru',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 74,
#   'agent_mobile': '9008791197',
#   'farmer_cluster_map_id': 6072,
#   'code': '21KPE001',
#   'cluster_id': 3,
#   'cluster_name': 'kodasoge',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '8, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [8],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6148,
#   'first_name': 'Krishna V V',
#   'last_name': 'Venkataramanaiah',
#   'mobile': '7090905055',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0112125'),
#   'longitude': Decimal('76.3917625'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6030,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6046,
#   'code': '21NPC033',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6197,
#   'first_name': 'Madhu H P',
#   'last_name': 'Puttabuddi H B',
#   'mobile': '9964258805',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 16,
#   'hobli_name': 'Harave',
#   'pincode': 571111,
#   'aadhaar_number': '409180072588',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 61,
#   'taluk_name': 'Chamarajanagar',
#   'village_id': 858,
#   'village_name': 'Hirebeguru',
#   'agent_farmer_map_id': 6085,
#   'agent_first_name': 'Nataraju',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 59,
#   'agent_mobile': '9731359912',
#   'farmer_cluster_map_id': 6101,
#   'code': '21TKB008',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '5, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [5],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6156,
#   'first_name': 'Madhu kumar',
#   'last_name': 'Mahadevappa',
#   'mobile': '8197461655',
# ...
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6048,
#   'code': '21NPC035',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6133,
#   'first_name': 'Srikanta moorthy',
#   'last_name': 'Nanjaiah',
#   'mobile': '8722620354',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 849,
#   'village_name': 'Chilakahalli',
#   'agent_farmer_map_id': 6015,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6031,
#   'code': '21NPC018',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6134,
#   'first_name': 'Srikanta moorthy N',
#   'last_name': 'Nanjaiah',
#   'mobile': '9844702578',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0112125'),
#   'longitude': Decimal('76.3917625'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 849,
#   'village_name': 'Chilakahalli',
#   'agent_farmer_map_id': 6016,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6032,
#   'code': '21NPC019',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6127,
#   'first_name': 'srikanta swamy',
#   'last_name': 'nanjundappa',
#   'mobile': '8197883857',
#   'alternate_mobile': '8197883857',
#   'email': 0,
#   'street': '',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 23,
#   'hobli_name': 'Sargur',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0033654'),
#   'longitude': Decimal('76.3942303'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 839,
#   'village_name': 'Sargur',
#   'agent_farmer_map_id': 6008,
#   'agent_first_name': 'H S Yogesh',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 145,
#   'agent_mobile': '9632499326',
#   'farmer_cluster_map_id': 6024,
#   'code': '21SSE001',
#   'cluster_id': 6,
#   'cluster_name': 'Sargur',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '19, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [19],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6184,
#   'first_name': 'Srinivasa ',
#   'last_name': 'late puttaswamy ',
#   'mobile': '9743444628',
#   'alternate_mobile': '9743444628',
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 66,
#   'hobli_name': 'Kasaba',
#   'pincode': 571114,
#   'aadhaar_number': '359710797189',
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0711873'),
#   'longitude': Decimal('76.3451455'),
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 854,
#   'village_name': 'Yarahalli',
#   'agent_farmer_map_id': 6072,
#   'agent_first_name': 'Mahadeva Prasad',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 139,
#   'agent_mobile': '8861650010',
#   'farmer_cluster_map_id': 6088,
#   'code': '21HSD001',
#   'cluster_id': 7,
#   'cluster_name': 'HD Kote',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 2.0,
#   'nursury_crop_age_list': '8, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [8],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6181,
#   'first_name': 'Suresha ',
#   'last_name': 'Mahadevappa',
#   'mobile': '9148367581',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.9883500'),
#   'longitude': Decimal('76.5518937'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 639,
#   'village_name': 'Kellupura',
#   'agent_farmer_map_id': 6067,
#   'agent_first_name': 'Suresha',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 140,
#   'agent_mobile': '8494824676',
#   'farmer_cluster_map_id': 6083,
#   'code': '21NPF003',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '14, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [14],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6121,
#   'first_name': 'swamappa',
#   'last_name': 'chikkadevappa',
#   'mobile': '8861782478',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 31,
#   'hobli_name': 'Beguru',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 847,
#   'village_name': 'kamarahalli',
#   'agent_farmer_map_id': 6001,
#   'agent_first_name': 'Kemparaju_Beerambadi',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 121,
#   'agent_mobile': '8073192830',
#   'farmer_cluster_map_id': 6017,
#   'code': '21GNI003',
#   'cluster_id': 1,
#   'cluster_name': 'gopalpura',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '12, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [12],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6110,
#   'first_name': 'swamy',
#   'last_name': 'mahadevappa',
#   'mobile': '9900373517',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 72,
#   'hobli_name': 'Kavlande',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 163,
#   'village_name': 'Gattavadipura',
#   'agent_farmer_map_id': 5988,
#   'agent_first_name': 'Nataraju',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 59,
#   'agent_mobile': '9731359912',
#   'farmer_cluster_map_id': 6004,
#   'code': '21TKB007',
#   'cluster_id': 2,
#   'cluster_name': 'Terakanambi',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '15, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [15],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6141,
#   'first_name': 'Tayamma',
#   'last_name': 'Lt Mahadevaiah',
#   'mobile': '7483769263',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 850,
#   'village_name': 'Hadanuru',
#   'agent_farmer_map_id': 6023,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6039,
#   'code': '21NPC026',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6120,
#   'first_name': 'T S prasad',
#   'last_name': 'swamappa',
#   'mobile': '9663791003',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 31,
#   'hobli_name': 'Beguru',
#   'pincode': 571111,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.9445433'),
#   'longitude': Decimal('76.6706888'),
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 847,
#   'village_name': 'kamarahalli',
#   'agent_farmer_map_id': 6000,
#   'agent_first_name': 'Kemparaju_Beerambadi',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 121,
#   'agent_mobile': '8073192830',
#   'farmer_cluster_map_id': 6016,
#   'code': '21GNI002',
#   'cluster_id': 1,
#   'cluster_name': 'gopalpura',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '12, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [12],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6122,
#   'first_name': 'Ulugaiah',
#   'last_name': 'Gopalaiah',
#   'mobile': '9980989901',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('11.8908551'),
#   'longitude': Decimal('76.4698078'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 848,
#   'village_name': 'Bankahalli',
#   'agent_farmer_map_id': 6003,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6019,
#   'code': '21NPC008',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '7, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [7],
#   'cultivation_phase_id': [1]},
#  {'farmer_id': 6165,
#   'first_name': 'Vekatesh',
#   'last_name': 'Nagarajashetty',
#   'mobile': '9901353471',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0113249'),
#   'longitude': Decimal('76.3916175'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6049,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6065,
#   'code': '21NPC052',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6147,
#   'first_name': 'Venkatesh G',
#   'last_name': 'Govindaiah',
#   'mobile': '9164739938',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 7,
#   'hobli_name': 'Hullahalli',
#   'pincode': 571121,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': Decimal('12.0031818'),
#   'longitude': Decimal('76.3944484'),
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 169,
#   'taluk_name': 'Nanjangud',
#   'village_id': 346,
#   'village_name': 'Vadeyanapura',
#   'agent_farmer_map_id': 6029,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6045,
#   'code': '21NPC032',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6118,
#   'first_name': 'vijaya kumar',
#   'last_name': 'prabhuswamy',
#   'mobile': '919945133829',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 0,
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 8,
#   'hobli_name': 'Kandalike',
#   'pincode': 571315,
#   'aadhaar_number': 0,
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 36,
#   'district_name': 'Mysore',
#   'taluk_id': 233,
#   'taluk_name': 'H D Kote',
#   'village_id': 808,
#   'village_name': 'Channagundi',
#   'agent_farmer_map_id': 5998,
#   'agent_first_name': 'Gopalaa',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 43,
#   'agent_mobile': '7406990508',
#   'farmer_cluster_map_id': 6014,
#   'code': '21NPC007',
#   'cluster_id': 8,
#   'cluster_name': 'Nanjangud',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 0.0,
#   'nursury_crop_age_list': '-',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': 0,
#   'cultivation_phase_id': 0},
#  {'farmer_id': 6174,
#   'first_name': 'Vishwanath',
#   'last_name': 'Vishwanath',
#   'mobile': '8970850582',
#   'alternate_mobile': 0,
#   'email': 0,
#   'street': 'undefined , undefined , Bommalapura , Chamrajnagar',
#   'state_id': 1,
#   'state__name': 'Karnataka',
#   'hobli_id': 29,
#   'hobli_name': 'Hangla',
#   'pincode': 571111,
#   'aadhaar_number': '675777873304',
#   'collaborated_with_company_on': 0,
#   'latitude': 0,
#   'longitude': 0,
#   'district_id': 11,
#   'district_name': 'Chamarajanagar',
#   'taluk_id': 62,
#   'taluk_name': 'Gundlupet',
#   'village_id': 154,
#   'village_name': 'Bommalapura',
#   'agent_farmer_map_id': 6060,
#   'agent_first_name': 'Mahesh  Yariyooru',
#   'season_name': '2021-Marigold-01',
#   'agent_id': 74,
#   'agent_mobile': '9008791197',
#   'farmer_cluster_map_id': 6076,
#   'code': '21KPE005',
#   'cluster_id': 3,
#   'cluster_name': 'kodasoge',
#   'total_main_crop_area': 0.0,
#   'yeild': 0,
#   'total_nursury_crop_area': 1.0,
#   'nursury_crop_age_list': '8, ',
#   'main_crop_age_list': '-',
#   'harvest_area': 0,
#   'harvest_qty': 0,
#   'transplanting_gps_status': 3,
#   'sowing_gps_status': 3,
#   'crop_age_list': [8],
#   'cultivation_phase_id': [1]}]

# %%
def get_sowing_gps_status(farmer_id, season_id):
    data = ''
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id).exists():
        data = 1
        if not Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id, latitude__isnull=True, longitude__isnull=True).exists():
            data = 2
    else:
        data = 3
    return data

# %%
# serving farmers list for portal
def find_main_crop_area_portal(farmer_id, option):
    if option == "all":
        sowing_objs = Sowing.objects.filter()
    else:
        sowing_objs = Sowing.objects.filter(season_id=2)

    if sowing_objs.filter(farmer_id=farmer_id, cultivation_phase_id=2).exists():
        area = Sowing.objects.filter(
            farmer_id=farmer_id, cultivation_phase_id=2
        ).aggregate(Sum("area"))["area__sum"]
    else:
        area = 0
    return area




def find_nursury_age_list(farmer_id, season_id):
    age_list = ""
    today = datetime.date.today()
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id).exists():
        sowings = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id)
        for sowing in sowings:
            diff = today - sowing.sowing_date
            age_list = str(diff.days) + ", " + age_list
    else:
        age_list = "-"
    return age_list


def find_main_crop_area(farmer_id, season_id):
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id).exists():
        area = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id).aggregate(Sum("area"))["area__sum"]
    else:
        area = 0
    return area

def find_nursury_crop_area(farmer_id, season_id):
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id).exists():
        area = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=1, season_id=season_id).aggregate(Sum("area"))["area__sum"]
    else:
        area = 0
    return area



def find_main_age_list(farmer_id, season_id):
    age_list = ""
    today = datetime.date.today()
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id).exists():
        sowings = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id)
        for sowing in sowings:
            diff = today - sowing.sowing_date
            age_list = str(diff.days) + ", " + age_list
    else:
        age_list = "-"
    return age_list


def get_gps_status(farmer_id, season_id):
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id).exists():
        sowings = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id)
        data = 1
        for sowing in sowings:
            if not SowingBoundary.objects.filter(sowing_id=sowing.id).exists():
                data = 2
    else:
        data = 3
    return data

def get_gps_status(farmer_id, season_id):
    if Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id).exists():
        sowings = Sowing.objects.filter(farmer_id=farmer_id, cultivation_phase_id=2, season_id=season_id)
        data = 1
        for sowing in sowings:
            if not SowingBoundary.objects.filter(sowing_id=sowing.id).exists():
                data = 2
    else:
        data = 3
    return data


def get_harvest_area(farmer_id, season_id):
    area = 0
    if Harvest.objects.filter(sowing__farmer__id=farmer_id, sowing__season__id=season_id).exists():
        unique_harvest = (Harvest.objects.filter(sowing__farmer__id=farmer_id, sowing__season__id=season_id).distinct("ticket_number").values_list("id"))
        if (Harvest.objects.filter(id__in=unique_harvest, sowing__season__id=season_id).aggregate(Sum("sowing__area"))["sowing__area__sum"] != None):
            area = Harvest.objects.filter(id__in=unique_harvest, sowing__season__id=season_id).aggregate(Sum("sowing__area"))["sowing__area__sum"]
    return area


def get_harvest_qty(farmer_id, season_id):
    area = 0
    if Harvest.objects.filter(sowing__farmer__id=farmer_id, sowing__season__id=season_id).exists():
        area = Harvest.objects.filter(sowing__farmer__id=farmer_id, sowing__season__id=season_id).aggregate(Sum("value"))["value__sum"]
        area = area / 1000
    return area

# %%
input_name_ids = list(InputGoods.objects.filter(quantity_now__gt=0, season_id=3).values_list('quantity_now',flat=True))
input_combo_ids = list(InputPart.objects.filter(name_id__in=input_name_ids).values_list('input_combo__name',flat=True))

# %%
input_name_ids
# Out:
# [Decimal('30000.00'), Decimal('14987.50'), Decimal('0.05')]

# %%
input_combo_ids
# Out:
# ['One Acre Seed Pkt', 'Half Acre Seed Pkt', '17:17:17', 'Pesticide Pack 3']

# %%
Farmer_id = FarmerClusterSeasonMap.objects.get(seasonal_farmer_code='21SSE002').farmer_id
Sowing.objects.filter(farmer_id=6128, season_id=3)
# Out:
# <QuerySet [<Sowing: Sowing object>]>

# %%
FarmerClusterSeasonMap.objects.get(seasonal_farmer_code="21NPE011").cluster.name
# Out:
# 'Nanjangud'

# %%
AgentFarmerMap.objects.get(farmer_id=6293).agent_id
# Out:
# 46

# %%
UserClusterMap.objects.get(season_id=3, cluster_id=8, user__userprofile__user_type_id=5).user.username[0:1]
# Out:
# 'p'

# %%
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=3):
    farmer_code = farmer.seasonal_farmer_code
    cluster_letter = farmer.cluster.name[:1]
    supervisor_letter = UserFarmerMap.objects.get(farmer_id=farmer.id).officer.username[0:1]
    agent_id = AgentFarmerMap.objects.get(farmer_id=farmer.id).agent_id
    agent_letter = UserClusterMap.objects.get(season_id=3, user_id=agent_id).unique_code
    generated_code = cluster_letter.upper() + supervisor_letter.upper() + agent_letter.upper()
    if generated_code != farmer_code[2:5]:
        print(farmer_code, generated_code)
# Out:
# 21APD002 KPD
# 21KSC001 BSC

# %%
MaxStatus.objects.filter().values()
# Out:
# <QuerySet [{'id': 1, 'name': 'Register'}, {'id': 2, 'name': 'Rised'}, {'id': 3, 'name': 'Approved BySupervisor'}, {'id': 4, 'name': 'Approved By Ass'}, {'id': 5, 'name': 'Issued By Agri '}, {'id': 6, 'name': 'Approved By GM'}, {'id': 7, 'name': 'Delined'}, {'id': 8, 'name': 'Dispatched'}, {'id': 9, 'name': 'Bill issued'}]>

# %%
# farmer cluster
farmer_cluster_values = list(farmer_cluster_season_obj.filter(season_id=2).values_list("id", "farmer_id", "cluster_id", "cluster__name"))
farmer_cluster_column = ["id", "farmer_id", "cluster_id", "cluster_name"]
farmer_cluster_df = pd.DataFrame(farmer_cluster_values, columns=farmer_cluster_column)

merged_df = pd.merge(sowing_df, farmer_cluster_df, left_on="farmer_id", right_on="farmer_id", how="left",)
merged_df = merged_df.fillna(0)
master_list = []
total_dict = {}
total_dict["Cluster"] = "Total"
total_dict["Farmer count"] = 0
total_dict["Farmer TP area"] = 0
total_dict["Gps area"] = 0
total_dict["TP Acres"] = 0
total_dict["Farmer count gps"] = 0
total_dict["Ratio GPS to TP"] = 0
for cluster in cluster_objs:
    filtered_rows = merged_df[merged_df["cluster_id"] == cluster.id]
    temp_dict = {}
    temp_dict["Cluster"] = cluster.name
    temp_dict["Farmer count"] = len(filtered_rows["farmer_id"].unique())
    temp_dict["Farmer TP area"] = round(filtered_rows["area"].sum(), 2)
    temp_dict["Gps area"] = round(merged_df[merged_df["cluster_id"] == cluster.id]["area_calculated_via_geo_fencing"].sum(),2,)
    empty_rows = filtered_rows[filtered_rows["area_calculated_via_geo_fencing"] != 0]
    temp_dict["TP Acres"] = round(empty_rows[empty_rows["cluster_id"] == cluster.id]["area"].sum(), 2)
    temp_dict["Farmer count gps"] = len(empty_rows["farmer_id"].unique())
    print(temp_dict)
    if temp_dict["TP Acres"] != 0:
        temp_dict["Ratio GPS to TP"] = round(temp_dict["Gps area"] / temp_dict["TP Acres"], 2)
    else:
        temp_dict["Ratio GPS to TP"] = 0
    total_dict["Farmer count"] = round(total_dict["Farmer count"] + temp_dict["Farmer count"], 2)
    total_dict["Gps area"] = round(total_dict["Gps area"] + temp_dict["Gps area"], 2)
    total_dict["Farmer TP area"] = round(total_dict["Farmer TP area"] + temp_dict["Farmer TP area"], 2)
    total_dict["TP Acres"] = round(total_dict["TP Acres"] + temp_dict["TP Acres"], 2)
    total_dict["Farmer count gps"] = round(total_dict["Farmer count gps"] + temp_dict["Farmer count gps"], 2)
    if total_dict['TP Acres'] != 0:
        total_dict["Ratio GPS to TP"] = round(total_dict["Ratio GPS to TP"]+ total_dict["Gps area"] / total_dict["TP Acres"],2,)
    else:
        total_dict["Ratio GPS to TP"] = 0
    master_list.append(temp_dict)

master_list.append(total_dict)
df = pd.DataFrame(master_list)
# Out:
# afs logins
# {'Cluster': 'Nanjangud', 'Farmer count': 0, 'Farmer TP area': 0.0, 'Gps area': 0.0, 'TP Acres': 0.0, 'Farmer count gps': 0}

# %%
User.objects.get(username='prasad').id
# Out:
# 24

# %%
user_id = 24
season_id = 3
import pandas as pd
if UserProfile.objects.get(user_id=user_id).user_type_id == 5:
    print('afs logins')
    cluster_ids = list(UserClusterMap.objects.filter(user_id=user_id,season_id=season_id).values_list('cluster_id', flat=True))
    farmer_ids = list(UserFarmerMap.objects.filter(farmer__season_id=season_id, officer_id=user_id).values_list('farmer__farmer_id', flat=True))
    sowing_obj = Sowing.objects.filter(farmer_id__in=farmer_ids, season_id=season_id)
    cluster_objs = Cluster.objects.filter(id__in=cluster_ids)
    farmer_cluster_season_obj = FarmerClusterSeasonMap.objects.filter(season_id=season_id, cluster_id__in=cluster_ids)
else:
    sowing_obj = Sowing.objects.filter( season_id=season_id)
    active_cluster_ids = ClusterSeasonMap.objects.filter(season_id=season_id).values_list('cluster_id', flat=True)
    cluster_objs = Cluster.objects.filter(id__in=active_cluster_ids)
    farmer_cluster_season_obj = FarmerClusterSeasonMap.objects.filter(season_id=season_id)

sowing_values = list(sowing_obj.filter(cultivation_phase_id=2).values_list("id","farmer_id","cultivation_phase__name","sowing_date","area","season_id","area_calculated_via_geo_fencing","latitude","longitude",))
sowing_columns = [ "id", "farmer_id", "cultivation_phase__name", "sowing_date", "area", "season_id", "area_calculated_via_geo_fencing", "latitude", "longitude"]
sowing_df = pd.DataFrame(sowing_values, columns=sowing_columns)
sowing_df.shape
# Out:
# afs logins
# (11, 9)

# %%
# farmer cluster
farmer_cluster_values = list(farmer_cluster_season_obj.filter(season_id=2).values_list("id", "farmer_id", "cluster_id", "cluster__name"))
farmer_cluster_column = ["id", "farmer_id", "cluster_id", "cluster_name"]
farmer_cluster_df = pd.DataFrame(farmer_cluster_values, columns=farmer_cluster_column)

# %%
import pandas as pd
shop_values = list(Shop.objects.filter().values_list('id', 'name', 'type__id', 'type__name'))
shop_list = ['id', 'name', 'type_id', 'type_name']
shop_df = pd.DataFrame(shop_values, columns=shop_list)
shop_df.groupby().app
# Out:
#    id                        name  type_id        type_name
# 0   1                  agri store        1             agri
# 1   5             Direct delivery        2  direct delivery
# 2   4            Shiva agro Cart.        3   External shops
# 3   3  Mallikarjunaswamy Traders.        3   External shops
# 4   2          Shivaleela traders        3   External shops

# %%
import random

letters = ['a', 'b']
random_index = random.randrange(len(letters))

print(letters[random_index])
# Out:
# a

# %%
input_combo_obj = InputCombo.objects.all().order_by('display_ordinal')
list(input_combo_obj.values())
# Out:
# [{'id': 8,
#   'business_id': 1,
#   'name': 'One Acre Seed Pkt',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('2300.00'),
#   'display_ordinal': 1,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 7, 53, 639455, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 14, 20, 115778, tzinfo=<UTC>)},
#  {'id': 9,
#   'business_id': 1,
#   'name': 'Half Acre Seed Pkt',
#   'area_id': 2,
#   'is_active': True,
#   'price': Decimal('1100.00'),
#   'display_ordinal': 2,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 8, 1, 717827, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 22, 17, 692311, tzinfo=<UTC>)},
#  {'id': 3,
#   'business_id': 1,
#   'name': '1st KIT',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 3,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 6, 57, 974293, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 11, 47, 37, 646000, tzinfo=<UTC>)},
#  {'id': 4,
#   'business_id': 1,
#   'name': '2nd KIT',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 4,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 7, 11, 589732, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 11, 56, 46, 119000, tzinfo=<UTC>)},
#  {'id': 5,
#   'business_id': 1,
#   'name': '3rd KIT',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 5,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 7, 17, 363999, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 12, 5, 55, 657000, tzinfo=<UTC>)},
#  {'id': 6,
#   'business_id': 1,
#   'name': 'Pesticide pack 2 - 30 ml coragen',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 6,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 6, 6, 350876, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 12, 10, 41, 736000, tzinfo=<UTC>)},
#  {'id': 7,
#   'business_id': 1,
#   'name': 'Pesticide pack - 60 ml coragen',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 7,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 6, 15, 706610, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 12, 11, 10, 695000, tzinfo=<UTC>)},
#  {'id': 10,
#   'business_id': 1,
#   'name': '17:17:17',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('1100.00'),
#   'display_ordinal': 8,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 8, 1, 717827, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 22, 17, 692311, tzinfo=<UTC>)},
#  {'id': 11,
#   'business_id': 1,
#   'name': 'DAP',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('1100.00'),
#   'display_ordinal': 9,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 8, 1, 717827, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 22, 17, 692311, tzinfo=<UTC>)},
#  {'id': 12,
#   'business_id': 1,
#   'name': '10:26:26',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('1100.00'),
#   'display_ordinal': 10,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 8, 1, 717827, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 22, 17, 692311, tzinfo=<UTC>)},
#  {'id': 13,
#   'business_id': 1,
#   'name': '20:20:0:13',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('1100.00'),
#   'display_ordinal': 11,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 8, 1, 717827, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 25, 12, 22, 17, 692311, tzinfo=<UTC>)},
#  {'id': 14,
#   'business_id': 1,
#   'name': 'Pesticide pack -3 dipping kit',
#   'area_id': 1,
#   'is_active': True,
#   'price': Decimal('10.00'),
#   'display_ordinal': 12,
#   'created_by_id': 1,
#   'modified_by_id': 1,
#   'time_modified': datetime.datetime(2021, 2, 25, 13, 6, 15, 706610, tzinfo=<UTC>),
#   'time_created': datetime.datetime(2021, 2, 24, 12, 11, 10, 695000, tzinfo=<UTC>)}]

# %%
list(UserProfile.objects.filter(user_id__in=list(UserClusterMap.objects.filter(season_id=3).values_list('user_id', flat=True)), user_type_id=5).values_list('user_id',flat=True))
# Out:
# [24, 25, 28, 29, 30, 149, 27, 23]

# %%
MaxStatus.objects.all().values()
# Out:
# <QuerySet [{'id': 1, 'name': 'Register'}, {'id': 2, 'name': 'Rised'}, {'id': 3, 'name': 'Approved BySupervisor'}, {'id': 4, 'name': 'Approved By Ass'}, {'id': 5, 'name': 'Issued By Agri '}, {'id': 6, 'name': 'Approved By GM'}, {'id': 7, 'name': 'Delined'}, {'id': 8, 'name': 'Dispatched'}, {'id': 9, 'name': 'Bill issued'}]>

# %%
in_data = {'start_date': '2021-02-01', 'end_date': '2021-04-27', 'max_status_id': 6}
start_date=in_data['start_date']
end_date = in_data['end_date']
max_status_id = in_data['max_status_id']
import pandas as pd

# %%
combo_issue_request_obj = ComboIssueRequestAgentMap.objects.filter(issue_rised_date__gte=start_date)
combo_issue_request_values = list(combo_issue_request_obj.values_list("agent__first_name","combo_issue_request__input_combo__name","combo_issue_request__quantity_in_numbers","combo_issue_request__request_code","combo_issue_request__issue_rised_date","combo_issue_request__supervisor__username","combo_issue_request__expected_date","combo_issue_request__dispatch_date","shop__name"))
column_names = ["Agent_name","Requested_name","Requested_Qty","Request_code","issue_rised_date","issued_Supervisor","expected_date","dispatch_date","shop_name"]
df = pd.DataFrame(combo_issue_request_values, columns=column_names)

df['issue_rised_date'] = pd.to_datetime(df['issue_rised_date']).dt.date
df['expected_date'] = pd.to_datetime(df['expected_date']).dt.date
df['dispatch_date'] = pd.to_datetime(df['dispatch_date']).dt.date

df1 = df.groupby('Requested_name')

# %%
df
# Out:
#               Agent_name                 Requested_name  Requested_Qty  \
# 0      Mahesh  Yariyooru              One Acre Seed Pkt             80
# 1              Manikanta              One Acre Seed Pkt             80
# 2               Nataraju              One Acre Seed Pkt             25
# 3    Kemparaju_gopalpura              One Acre Seed Pkt             95
# 4    Kemparaju_gopalpura             Half Acre Seed Pkt             60
# ..                   ...                            ...            ...
# 242    Mahesh  Yariyooru                       17:17:17             80
# 243  Rajashekhara Murthy                       17:17:17             80
# 244             Mahesh K  Pesticide pack -3 dipping kit              0
# 245             Gopala H                       17:17:17              0
# 246             Ravi M S                       17:17:17              0
#
#                          Request_code issue_rised_date issued_Supervisor  \
# 0                One Acre Seed Pkt002       2021-03-09            pratap
# 1                One Acre Seed Pkt002       2021-03-09            pratap
# 2                One Acre Seed Pkt003       2021-03-10            naveen
# 3                One Acre Seed Pkt004       2021-02-26             ajith
# 4               Half Acre Seed Pkt001       2021-02-26             ajith
# ..                                ...              ...               ...
# 242                       17:17:17010       2021-04-23            pratap
# 243                       17:17:17010       2021-04-23            pratap
# 244  Pesticide pack -3 dipping kit026       2021-04-21             kiran
# 245                       17:17:17003       2021-04-16            prasad
# 246                       17:17:17002       2021-04-16           siddapa
#
#     expected_date dispatch_date           shop_name
# 0      2021-03-09    2021-03-15                None
# 1      2021-03-09    2021-03-15                None
# 2      2021-03-10    2021-03-15                None
# 3      2021-02-26    2021-02-26                None
# 4      2021-02-26           NaT                None
# ..            ...           ...                 ...
# 242    2021-04-23           NaT                None
# 243    2021-04-23           NaT                None
# 244    2021-04-22           NaT  Shivaleela traders
# 245    2021-04-17           NaT     Direct delivery
# 246    2021-04-17           NaT     Direct delivery
#
# [247 rows x 9 columns]

# %%
ComboIssueRequestAgentMap.objects.filter(issue_rised_date__gte=start_date).values()
# Out:
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-02-01 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# <QuerySet [<ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, <ComboIssueRequestAgentMap: ComboIssueRequestAgentMap object>, '...(remaining elements truncated)...']>

# %%
list(set(ComboIssueRequest.objects.filter().values_list('input_combo_id', flat=True)))
# Out:
# [3, 8, 9, 10, 11, 13, 14]

# %%
import pandas as pd
user_cluster_map = UserClusterMap.objects.filter(user__userprofile__user_type_id=5)
user_cluster_list = list(user_cluster_map.values_list('user_id', 'season_id', 'user__username'))
user_cluster_columns = ['id', 'season_id', 'name']
user_cluster_df = pd.DataFrame(user_cluster_list, columns=user_cluster_columns)
data = user_cluster_df.groupby('season_id').apply(lambda x: x.to_dict('r')).to_dict()
data
# Out:
# {2: [{'id': 14, 'season_id': 2, 'name': '9141402494'},
#   {'id': 29, 'season_id': 2, 'name': 'kiran'},
#   {'id': 28, 'season_id': 2, 'name': 'siddapa'},
#   {'id': 24, 'season_id': 2, 'name': 'prasad'},
#   {'id': 26, 'season_id': 2, 'name': 'mahadevaprasad'},
#   {'id': 26, 'season_id': 2, 'name': 'mahadevaprasad'},
#   {'id': 23, 'season_id': 2, 'name': 'naveen'},
#   {'id': 22, 'season_id': 2, 'name': 'ajith'},
#   {'id': 13, 'season_id': 2, 'name': '9999911111'},
#   {'id': 151, 'season_id': 2, 'name': '8971333190'},
#   {'id': 27, 'season_id': 2, 'name': 'pratap'},
#   {'id': 27, 'season_id': 2, 'name': 'pratap'},
#   {'id': 25, 'season_id': 2, 'name': 'madappa'},
#   {'id': 25, 'season_id': 2, 'name': 'madappa'}],
#  3: [{'id': 29, 'season_id': 3, 'name': 'kiran'},
#   {'id': 28, 'season_id': 3, 'name': 'siddapa'},
#   {'id': 24, 'season_id': 3, 'name': 'prasad'},
#   {'id': 23, 'season_id': 3, 'name': 'naveen'},
#   {'id': 30, 'season_id': 3, 'name': 'srinivasa'},
#   {'id': 27, 'season_id': 3, 'name': 'pratap'},
#   {'id': 25, 'season_id': 3, 'name': 'madappa'},
#   {'id': 149, 'season_id': 3, 'name': 'siddaraju'}]}

# %%
ComboIssueRequestAgentMap.objects.filter(combo_issue_request__issue_rised_date__range=['03-03-2021','24-04-2021']).count()
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-1-5694f509acc6> in <module>
# ----> 1 ComboIssueRequestAgentMap.objects.filter(combo_issue_request__issue_rised_date__range=['03-03-2021','24-04-2021']).count()
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/query.py in filter(self, *args, **kwargs)
#     785         set.
#     786         """
# --> 787         return self._filter_or_exclude(False, *args, **kwargs)
#     788
#     789     def exclude(self, *args, **kwargs):
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/query.py in _filter_or_exclude(self, negate, *args, **kwargs)
#     803             clone.query.add_q(~Q(*args, **kwargs))
#     804         else:
# --> 805             clone.query.add_q(Q(*args, **kwargs))
#     806         return clone
#     807
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/sql/query.py in add_q(self, q_object)
#    1248         existing_inner = set(
#    1249             (a for a in self.alias_map if self.alias_map[a].join_type == INNER))
# -> 1250         clause, _ = self._add_q(q_object, self.used_aliases)
#    1251         if clause:
#    1252             self.where.add(clause, AND)
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/sql/query.py in _add_q(self, q_object, used_aliases, branch_negated, current_negated, allow_joins, split_subq)
#    1271                 joinpromoter.add_votes(needed_inner)
#    1272             else:
# -> 1273                 child_clause, needed_inner = self.build_filter(
#    1274                     child, can_reuse=used_aliases, branch_negated=branch_negated,
#    1275                     current_negated=current_negated, connector=connector,
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/sql/query.py in build_filter(self, filter_expr, branch_negated, current_negated, can_reuse, connector, allow_joins, split_subq)
#    1208         else:
#    1209             col = targets[0].get_col(alias, field)
# -> 1210             condition = self.build_lookup(lookups, col, value)
#    1211             lookup_type = condition.lookup_name
#    1212
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/sql/query.py in build_lookup(self, lookups, lhs, rhs)
#    1102                     lhs = self.try_transform(lhs, name, lookups)
#    1103                     final_lookup = lhs.get_lookup('exact')
# -> 1104                 return final_lookup(lhs, rhs)
#    1105             lhs = self.try_transform(lhs, name, lookups)
#    1106             lookups = lookups[1:]
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/lookups.py in __init__(self, lhs, rhs)
#      22     def __init__(self, lhs, rhs):
#      23         self.lhs, self.rhs = lhs, rhs
# ---> 24         self.rhs = self.get_prep_lookup()
#      25         if hasattr(self.lhs, 'get_bilateral_transforms'):
#      26             bilateral_transforms = self.lhs.get_bilateral_transforms()
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/lookups.py in get_prep_lookup(self)
#     217                 pass
#     218             elif self.prepare_rhs and hasattr(self.lhs.output_field, 'get_prep_value'):
# --> 219                 rhs_value = self.lhs.output_field.get_prep_value(rhs_value)
#     220             prepared_values.append(rhs_value)
#     221         return prepared_values
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py in get_prep_value(self, value)
#    1436
#    1437     def get_prep_value(self, value):
# -> 1438         value = super(DateTimeField, self).get_prep_value(value)
#    1439         value = self.to_python(value)
#    1440         if value is not None and settings.USE_TZ and timezone.is_naive(value):
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py in get_prep_value(self, value)
#    1294     def get_prep_value(self, value):
#    1295         value = super(DateField, self).get_prep_value(value)
# -> 1296         return self.to_python(value)
#    1297
#    1298     def get_db_prep_value(self, value, connection, prepared=False):
#
# ~/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py in to_python(self, value)
#    1418             )
#    1419
# -> 1420         raise exceptions.ValidationError(
#    1421             self.error_messages['invalid'],
#    1422             code='invalid',
#
# ValidationError: ["'03-03-2021' value has an invalid format. It must be in YYYY-MM-DD HH:MM[:ss[.uuuuuu]][TZ] format."]

# %%
# Out:
#         Bank Name          Branch Name    IFSC Code
# 0  Bank of Baroda       Chamarajanagar  BARB0VJCNGR
# 1  Bank of Baroda             Kulagana  BARB0VJKULA
# 2  Bank of Baroda            Nanjangud  BARB0NANJAN
# 3  Bank of Baroda  Venkatayyana Chatra  BARB0VJVECH
# 4   Bank of India       Chamarajanagar  BKID0008964

# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/15h9S408iTJTNxFJzlNS6JH8pBU9iJ1Baz6Cw6YBnG3o/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(5)

for index,bank in df.iterrows():
    if not Bank.objects.filter(ifsc_code=bank['IFSC Code']).exists():
        Bank.objects.create(
            name=bank['Bank Name'],
            branch=bank['Branch Name'],
            ifsc_code=bank['IFSC Code']
        )
        print('saved')
    else:
        print('------------------------------already saved----------------')
# Out:
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# ------------------------------already saved----------------
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# ------------------------------already saved----------------
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# ------------------------------already saved----------------
# saved
# ------------------------------already saved----------------
# ------------------------------already saved----------------

# %%
Bank.objects.filter().delete()
# Out:
# (6, {'knowledgebase.Bank': 6})

# %%
def send_push_notification(title, body, user_ids, data):
    print('user_ids', user_ids)
    print('title', title)
    print('body', body)
    print('======= within in push notification ===========>')
    print(user_ids)
    print("title = {}, body = {}, data = {}".format(title, body, data))
    devices = FCMDevice.objects.filter(user_id__in=user_ids)
    for device in devices:
        device.send_message(title=title, body=body, sound="default", api_key="AIzaSyAw3UA4Y_K3_K87QoJ4UyO_UOEXAq11Tuo", data=data)
        print(device)
        print('-----notification sent success------')
        
title = 'Request Status for DAP008'
body = 'ajith_sfs1 have Approved the request - DAP008'
user_ids = [27]
send_push_notification(title, body, user_ids, {})
# Out:
# user_ids [27]
# title Request Status for DAP008
# body ajith_sfs1 have Approved the request - DAP008
# ======= within in push notification ===========>
# [27]
# title = Request Status for DAP008, body = ajith_sfs1 have Approved the request - DAP008, data = {}
# grower
# -----notification sent success------

# %%
title = 'Request Status for DAP008'
body = 'ajith_sfs1 have Approved the request - DAP008'
user_ids = [27]
FCMDevice.objects.get(id=22).send_message(title=title, body=body, sound="default", api_key="AIzaSyAw3UA4Y_K3_K87QoJ4UyO_UOEXAq11Tuo", data={})
# Out:
# {'multicast_ids': [8480517153378915507],
#  'success': 0,
#  'failure': 1,
#  'canonical_ids': 0,
#  'results': [{'error': 'MismatchSenderId'}],
#  'topic_message_id': None}

# %%
title = 'Request Status for DAP008'
body = 'ajith_sfs1 have Approved the request - DAP008'
FCMDevice.objects.get(id=22).send_message(title=title, body=body)
# Out:
# {'multicast_ids': [3968640669063176903],
#  'success': 1,
#  'failure': 0,
#  'canonical_ids': 0,
#  'results': [{'message_id': '0:1620459028768321%d54e191fd54e191f'}],
#  'topic_message_id': None}

# %%
UserType.objects.filter().values()
# Out:
# <QuerySet [{'id': 1, 'name': 'General Manager', 'notes': None, 'ordinal': 1}, {'id': 2, 'name': 'Assistant Manager (Agri)', 'notes': None, 'ordinal': 2}, {'id': 3, 'name': 'Senior Field Supervisor', 'notes': None, 'ordinal': 3}, {'id': 6, 'name': 'Agent', 'notes': None, 'ordinal': 6}, {'id': 7, 'name': 'Farmer', 'notes': None, 'ordinal': 7}, {'id': 8, 'name': 'Software Developers', 'notes': None, 'ordinal': 8}, {'id': 4, 'name': 'Agriculture Officer', 'notes': None, 'ordinal': 3}, {'id': 5, 'name': 'Asst Field Supervisor', 'notes': None, 'ordinal': 4}, {'id': 10, 'name': 'Partner', 'notes': None, 'ordinal': 3}, {'id': 12, 'name': 'Supply chain executive', 'notes': None, 'ordinal': 4}]>

# %%
list(User.objects.filter(userprofile__user_type_id=2).values())
# Out:
# [{'id': 9,
#   'password': 'pbkdf2_sha256$36000$FfjukZJLYG0Z$GNns8UGXwd31QjXUIwhgJ9w339KBZQ2j7WPc7IWpdDs=',
#   'last_login': None,
#   'is_superuser': False,
#   'username': '7904481699',
#   'first_name': 'Shivakumar',
#   'last_name': 'T Nagarajan',
#   'email': 'tnshivakumar1962@gmail.com',
#   'is_staff': False,
#   'is_active': True,
#   'date_joined': datetime.datetime(2020, 3, 19, 10, 13, 4, tzinfo=<UTC>)},
#  {'id': 93,
#   'password': 'pbkdf2_sha256$36000$stmiQpXqyIGv$9GN25Rj3jccnxFh2DhzKyI0vbqObDbyJHT0qvxuOKLQ=',
#   'last_login': None,
#   'is_superuser': False,
#   'username': '8111010653',
#   'first_name': 'Kultiavate added Venkat',
#   'last_name': 'added',
#   'email': '',
#   'is_staff': False,
#   'is_active': True,
#   'date_joined': datetime.datetime(2020, 4, 10, 14, 14, 22, 622050, tzinfo=<UTC>)},
#  {'id': 79,
#   'password': 'pbkdf2_sha256$36000$a4DYB81sevRR$dvlLj+4pfKT0JZFvJK26eM9OGpNe7E92PvlfJPqhHC4=',
#   'last_login': datetime.datetime(2021, 5, 8, 7, 34, 0, 641974, tzinfo=<UTC>),
#   'is_superuser': True,
#   'username': 'am01',
#   'first_name': 'Assistant Manager',
#   'last_name': 'am',
#   'email': '',
#   'is_staff': True,
#   'is_active': True,
#   'date_joined': datetime.datetime(2020, 3, 21, 8, 50, 40, tzinfo=<UTC>)}]

# %%
list(PositionManUserMap.objects.filter(user__userprofile__user_type_id=2).values())
# Out:
# [{'id': 11,
#   'position_user_map_id': 11,
#   'user_id': 9,
#   'from_date': datetime.date(2020, 1, 1),
#   'time_created': datetime.datetime(2020, 1, 1, 10, 56, 24, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 1, 1, 10, 56, 24, tzinfo=<UTC>)}]

# %%
list(PositionManUserMapTrace.objects.filter().values())
# Out:
# [{'id': 1,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 1, 1),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 10, 59, 56, 885535, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 10, 59, 56, 885559, tzinfo=<UTC>)},
#  {'id': 2,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 1, 1),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 20, 59, 703654, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 20, 59, 703676, tzinfo=<UTC>)},
#  {'id': 3,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 22, 8, 356847, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 22, 8, 356871, tzinfo=<UTC>)},
#  {'id': 4,
#   'position_user_map_id': 2,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 22, 18, 468490, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 22, 18, 468529, tzinfo=<UTC>)},
#  {'id': 5,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 24, 2, 457026, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 24, 2, 457068, tzinfo=<UTC>)},
#  {'id': 6,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 24, 4, 735650, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 24, 4, 735673, tzinfo=<UTC>)},
#  {'id': 7,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 10),
#   'time_created': datetime.datetime(2020, 4, 10, 14, 24, 25, 95882, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 10, 14, 24, 25, 95905, tzinfo=<UTC>)},
#  {'id': 8,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 11),
#   'time_created': datetime.datetime(2020, 4, 11, 5, 22, 5, 376953, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 11, 5, 22, 5, 376978, tzinfo=<UTC>)},
#  {'id': 9,
#   'position_user_map_id': 1,
#   'user_id': 21,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 11),
#   'time_created': datetime.datetime(2020, 4, 11, 5, 22, 16, 413540, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 11, 5, 22, 16, 413562, tzinfo=<UTC>)},
#  {'id': 10,
#   'position_user_map_id': 3,
#   'user_id': 20,
#   'from_date': datetime.date(2020, 1, 1),
#   'to_date': datetime.date(2020, 4, 11),
#   'time_created': datetime.datetime(2020, 4, 11, 5, 22, 44, 498684, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 11, 5, 22, 44, 498715, tzinfo=<UTC>)},
#  {'id': 11,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 11),
#   'time_created': datetime.datetime(2020, 4, 11, 5, 34, 39, 250601, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 11, 5, 34, 39, 250645, tzinfo=<UTC>)},
#  {'id': 12,
#   'position_user_map_id': 1,
#   'user_id': 14,
#   'from_date': datetime.date(2020, 4, 10),
#   'to_date': datetime.date(2020, 4, 11),
#   'time_created': datetime.datetime(2020, 4, 11, 5, 57, 36, 205527, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2020, 4, 11, 5, 57, 36, 205550, tzinfo=<UTC>)},
#  {'id': 13,
#   'position_user_map_id': 9,
#   'user_id': 21,
#   'from_date': datetime.date(2020, 4, 11),
#   'to_date': datetime.date(2021, 3, 24),
#   'time_created': datetime.datetime(2021, 3, 24, 11, 37, 17, 502733, tzinfo=<UTC>),
#   'time_modified': datetime.datetime(2021, 3, 24, 11, 37, 17, 502752, tzinfo=<UTC>)}]

# %%
list(PositionPositionUserMap.objects.filter(user__userprofile__user_type_id=1).values_list('user_id',flat=True))
# Out:
# [78, 116]

# %%
# season_id = get_active_season_id()
import pandas as pd
season_id = 3

season_id = get_active_season_id()
combo_list = list(ReturnableComboItems.objects.filter(season_id=season_id).values_list('input_combo_id','input_combo__name'))
combo_columns = ['input_combo_id','input_combo_name']
combo_df = pd.DataFrame(combo_list,columns=combo_columns)
combo_df.to_dict('r')
# Out:
# [{'input_combo_id': 3, 'input_combo_name': '1st KIT'},
#  {'input_combo_id': 4, 'input_combo_name': '2nd KIT'},
#  {'input_combo_id': 5, 'input_combo_name': '3rd KIT'},
#  {'input_combo_id': 6, 'input_combo_name': 'Pesticide pack 2 - 30 ml coragen'},
#  {'input_combo_id': 7, 'input_combo_name': 'Pesticide pack - 60 ml coragen'},
#  {'input_combo_id': 8, 'input_combo_name': 'One Acre Seed Pkt'},
#  {'input_combo_id': 9, 'input_combo_name': 'Half Acre Seed Pkt'}]

# %%
import pandas as pd
user_id = 92
season_id = 3
subordinates = UserHierarchyMap.objects.filter(superior_id=user_id)
subordinate_user_ids = list(subordinates.values_list("subordinate", flat=True))
agent_ids = list(AgentSupervisorSeasonMap.objects.filter(supervisor_id__in=subordinate_user_ids, season_id=season_id).values_list('agent_id',flat=True))
agent_list = list(UserClusterMap.objects.filter(user_id__in=agent_ids, season_id=season_id).values_list('user_id','user__first_name','user__last_name','user__userprofile__code', 'cluster_id', 'cluster__name'))
agent_col = ['user_id','user__first_name','user__last_name','user__userprofile__code', 'cluster_id', 'cluster__name']
agent_df = pd.DataFrame(agent_list, columns=agent_col)
agent_df.to_dict('r')
# Out:
# [{'user_id': 48,
#   'user__first_name': 'Ranga Swamy',
#   'user__last_name': 'Mahadevashetty',
#   'user__userprofile__code': 'AN038',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 46,
#   'user__first_name': 'Manjesh M',
#   'user__last_name': 'Mallappa',
#   'user__userprofile__code': 'AN051',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 63,
#   'user__first_name': 'Parameswaran_hd_kote',
#   'user__last_name': 'Madashetty',
#   'user__userprofile__code': 'AH034',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 43,
#   'user__first_name': 'Gopala H',
#   'user__last_name': 'Hanumaiah',
#   'user__userprofile__code': 'AY009',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 65,
#   'user__first_name': 'Nagaraju Naika',
#   'user__last_name': 'Jadiyanaika',
#   'user__userprofile__code': 'AS031',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 91,
#   'user__first_name': 'Puttamallappa',
#   'user__last_name': 'Muddappa',
#   'user__userprofile__code': 'AH043',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 90,
#   'user__first_name': 'Ravi M S',
#   'user__last_name': 'Shivanagappa',
#   'user__userprofile__code': 'AS040',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 87,
#   'user__first_name': 'H M Mahadevaswamy',
#   'user__last_name': 'Mahadevappa',
#   'user__userprofile__code': 'AH075',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 85,
#   'user__first_name': 'Nagaraju',
#   'user__last_name': 'Putta Rajappa',
#   'user__userprofile__code': 'AN041',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 58,
#   'user__first_name': 'Muruga_Sargur',
#   'user__last_name': 'Srinivasa',
#   'user__userprofile__code': 'AY018',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 122,
#   'user__first_name': 'Parameswaran_sargur',
#   'user__last_name': 'Madashetty',
#   'user__userprofile__code': 'AS055',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 134,
#   'user__first_name': 'B M Virabhadrappa',
#   'user__last_name': 'Muddappa',
#   'user__userprofile__code': 'AS074',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 135,
#   'user__first_name': 'Mallaraju',
#   'user__last_name': 'Mallegowda',
#   'user__userprofile__code': 'AS042',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 153,
#   'user__first_name': 'M Parameshwaran... Nanjangud',
#   'user__last_name': 'Madashetty',
#   'user__userprofile__code': 'AN002',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 145,
#   'user__first_name': 'H S Yogesh',
#   'user__last_name': 'Shivarudrappa H S',
#   'user__userprofile__code': 'AS076',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 137,
#   'user__first_name': 'Ganesha Nayaka',
#   'user__last_name': 'Channanayaka',
#   'user__userprofile__code': 'AS047',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 139,
#   'user__first_name': 'Mahadeva Prasad',
#   'user__last_name': ' M Madaraju',
#   'user__userprofile__code': 'AS062',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 140,
#   'user__first_name': 'Suresha',
#   'user__last_name': 'S Mahadevappa',
#   'user__userprofile__code': 'AN063',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 141,
#   'user__first_name': 'Praveen Kumar M M',
#   'user__last_name': 'B H Mahadevappa',
#   'user__userprofile__code': 'AH064',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'},
#  {'user_id': 110,
#   'user__first_name': 'Kemparaju_Nanjangud',
#   'user__last_name': 'Madappa',
#   'user__userprofile__code': 'AN070',
#   'cluster_id': 8,
#   'cluster__name': 'Nanjangud'},
#  {'user_id': 142,
#   'user__first_name': 'Nandisha',
#   'user__last_name': 'H S Nanjappaswamy',
#   'user__userprofile__code': 'AS065',
#   'cluster_id': 6,
#   'cluster__name': 'Sargur'},
#  {'user_id': 142,
#   'user__first_name': 'Nandisha',
#   'user__last_name': 'H S Nanjappaswamy',
#   'user__userprofile__code': 'AS065',
#   'cluster_id': 7,
#   'cluster__name': 'HD Kote'}]

# %%
item_ids = [3, 4, 5, 6, 7, 8, 9]
season_id = 3
for data in item_ids:
    ReturnableComboItems.objects.create(season_id=3, input_combo_id=data)

for item in ReturnableComboItems.objects.filter():
    ComboReturnRequestCodeBank.objects.create(input_combo_id=item.input_combo.id,last_digit=0)
item_ids

SubStoreIssueLabelAgentMap.objects.filter().update(status_id=1)
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
import pandas as pd
combo_return_obj = ComboReturnRequest.objects.filter()
combo_list = list(combo_return_obj.values_list('id', 'season_id', 'agent_id', 'agent__first_name', 'agent__userprofile__code', 'request_code', 'input_combo__id', 'input_combo__name', 'request_raised_date', 
                                              'max_status_id', 'max_status__name', 'senior_supervisor_id', 'senior_supervisor__username', 'senior_supervisor_remarks', 'assitant_manager_id', 'assitant_manager__username',
                                             'assitant_manager_status_id', 'assitant_manager_remarks', 'assitant_manager_status_date', 'agri_officer__id','agri_officer__username', 'agri_officer_remarks',
                                             'agri_officer_status_id', 'agri_officer_status_date'))
combo_columns = ['combo_return_request_id', 'season_id', 'agent_id', 'agent_first_name', 'agent_code', 'request_code', 'input_combo_id', 'input_combo_name', 'request_raised_date', 
                                              'max_status_id', 'max_status_name', 'senior_supervisor_id', 'senior_supervisor_username', 'senior_supervisor_remarks', 'assitant_manager_id', 'assitant_manager_username',
                                             'assitant_manager_status_id', 'assitant_manager_remarks', 'assitant_manager_status_date', 'agri_officer__id','agri_officer__username', 'agri_officer_remarks',
                                             'agri_officer_status_id', 'agri_officer_status_date']
combo_request_df = pd.DataFrame(combo_list, columns=combo_columns)
combo_request_df
# Out:
#    combo_return_request_id  season_id  agent_id    agent_first_name  \
# 0                        1          3        37  Mahadevaprasad B S
#
#   agent_code    request_code  input_combo_id input_combo_name  \
# 0      AB014  rtn_1st KIT005               3          1st KIT
#
#         request_raised_date  max_status_id  ... assitant_manager_id  \
# 0 2021-05-10 00:00:00+00:00              3  ...                None
#
#    assitant_manager_username assitant_manager_status_id  \
# 0                       None                       None
#
#   assitant_manager_remarks assitant_manager_status_date agri_officer__id  \
# 0                     None                         None             None
#
#   agri_officer__username agri_officer_remarks agri_officer_status_id  \
# 0                   None                 None                   None
#
#   agri_officer_status_date
# 0                     None
#
# [1 rows x 24 columns]

# %%
IssueRequestStatus.objects.filter().values()
# Out:
# <QuerySet [{'id': 3, 'name': 'Issued'}, {'id': 1, 'name': 'Approved'}, {'id': 2, 'name': 'Declined'}]>

# %%
import pandas as pd
combo_return_obj = ComboReturnRequest.objects.get(id=10)
combo_receipt_obj = ComboIssueAgentInventoryReceipt.objects.filter(combo_issue_request__input_combo_id=combo_return_obj.input_combo_id,  agent_id=combo_return_obj.agent.id)
combo_receipt_list = list(combo_receipt_obj.values_list('id', 'bill_number', 'time_created', 'combo_issue_request'))
combo_receipt_column = ['bill_id', 'bill_number', 'bill_date', 'combo_issue_request_id']
combo_receipt_df = pd.DataFrame(combo_receipt_list, columns=combo_receipt_column)
combo_issue_ids = list(combo_receipt_obj.values_list('combo_issue_request', flat=True))
combo_issue_ids
# Out:
# [418]

# %%
sub_store_label_obj = SubStoreIssueLabelAgentMap.objects.filter(combo_issue_request_agent_map__combo_issue_request__in=combo_issue_ids, agent_id=combo_return_obj.agent.id, status_id=1).order_by('label')
# Out:
# 50

# %%
SubStoreIssueLabelAgentMap.objects.filter(combo_issue_request_agent_map__combo_issue_request__in=combo_issue_ids, agent_id=combo_return_obj.agent.id).count()
# Out:
# 50

# %%
SubStoreIssueLabelAgentMap.objects.filter().update(status_id=1)
# Out:
# 8163
