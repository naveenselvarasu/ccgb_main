# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1EVRMoFIQFzIM3TdI28lUt9jQ0Q6iZwrlUZbRAU1v3ww/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(5)
# Out:
#    Sl.No Employee Name Employee Code   Agent Name Agent Code    Cluster  \
# 0      1       Ajith S         AFS01  Arasashetty      AG001  Gundlupet
# 1      1       Ajith S         AFS01  Arasashetty      AG001  Gundlupet
# 2      2       Ajith S         AFS01  Arasashetty      AG001  Gundlupet
# 3      2       Ajith S         AFS01  Arasashetty      AG001  Gundlupet
# 4      2       Ajith S         AFS01  Arasashetty      AG001  Gundlupet
#
#   Farmer  First Name Farmer Last  Name Farmer Unique Code New Farmer Code  \
# 0            Krishna     Govindashetty          01/01/001          FA0001
# 1         Devashetty       Siddashetty          01/01/002          FA0002
# 2     Mahadevashetty        Ankashetty          01/01/003          FA0003
# 3       Gokulashetty       Bellashetty          01/01/004          FA0004
# 4          Gopalamma      Gopalashetty          01/01/005          FA0005
#
#          Village      Hobli      Taluk        District
# ...

# %%
for index, row in df.iterrows():
    farmer_id = Farmer.objects.get(code=row['New Farmer Code']).id
    agent_id = UserProfile.objects.get(code=row['Agent Code']).id
    farmer_season_cluster_map_id=FarmerClusterSeasonMap.objects.get(season_id=1,farmer_id=farmer_id).id
    if not AgentFarmerMap.objects.filter(farmer_id=farmer_season_cluster_map_id, agent_id=agent_id).exists():
        AgentFarmerMap.objects.create(
            farmer_id=farmer_season_cluster_map_id,
            agent_id=agent_id
        )
        print(farmer_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-62d5cd9b130b> in <module>
#       1 for index, row in df.iterrows():
#       2     farmer_id = Farmer.objects.get(code=row['New Farmer Code']).id
# ----> 3     agent_id = Agent.objects.get(code=row['Agent Code']).id
#       4     farmer_season_cluster_map_id=FarmerClusterSeasonMap.objects.get(season_id=1,farmer_id=farmer_id).id
#       5     if not AgentFarmerMap.objects.filter(farmer_id=farmer_season_cluster_map_id, agent_id=agent_id).exists():
#
# NameError: name 'Agent' is not defined
