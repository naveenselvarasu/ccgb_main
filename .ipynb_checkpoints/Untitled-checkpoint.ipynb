# %% [markdown]
# ### CREATE USER AND CREATE USER TYPE

# %%
1. create user - 156(78)
2. created a user_type
3. create user profile -156(78)
4. create a position 
5. create a position position user map
6. create a user for his position - 157(81)
7. create a user profile this user- 159(81)
8. create the access controls for this user type
for item in UsertypeBasedAccessControl.objects.filter(user_type_id=4):
    UsertypeBasedAccessControl.create(
        user_type_id=13,
        module_id=item.module.id,
        hardware_device=item.hardware_device,
        operation=item.operation
        access=False
        created_by=item.created_by,
        modified_by=modified_by
    )
# Out:
#   File "<ipython-input-1-ff17f09fc0d7>", line 1
#     1. create user - 156(78)
#        ^
# SyntaxError: invalid syntax

# %%
UsertypeBasedAccessControl.objects.filter(user_type_id=3).count()
# Out:
# 66

# %%
for item in UsertypeBasedAccessControl.objects.filter(user_type_id=4):
    UsertypeBasedAccessControl.objects.create(
            user_type_id=13,
            module_id=item.module.id,
            hardware_device=item.hardware_device,
            operation=item.operation,
            access=False,
            created_by=item.created_by,
            modified_by=item.modified_by
        )

# %%
​
​

​
​
​

# %%
def generate_request_code(input_combo_id):
    code_bank_obj = ComboIssueRequestCodeBank.objects.filter(input_combo_id=input_combo_id)[0]
    last_digit_code = code_bank_obj.last_digit
    new_code = last_digit_code + 1
    value = str(code_bank_obj.input_combo.name) + str(new_code).zfill(3)
    code_bank_obj.last_digit = new_code
    code_bank_obj.save()
    return value

# %%
import random
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1QxCyP3uVTvUOG7IuhOCx0V-Qp07BVoIhsHBrj8NxkKU/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df = df.fillna(0)
# df = df.head(2)
df
# Out:
#      SL NO   R. No Distribution/Return Agents New/Old        Date  \
# 0        1  3951.0        Distribution            Old  25-02-2022
# 1        2  3952.0        Distribution            Old  25-02-2022
# 2        3  3953.0        Distribution            Old  25-02-2022
# 3        4  3954.0        Distribution            Old  25-02-2022
# 4        5  3955.0        Distribution            Old  25-02-2022
# ..     ...     ...                 ...            ...         ...
# 126      0     0.0                   0              0           0
# 127      0     0.0                   0              0           0
# 128      0     0.0                   0              0           0
# 129      0     0.0                   0              0           0
# 130  Total     0.0                   0              0           0
#
#           Agent Name Unique Code  Moblie Number Agent code  Cluster Name  \
# 0           Gopala H           A   7.406991e+09       AY009     Matakere
# 1           S Muruga           C   9.449203e+09       AY018       Sargur
# 2    M Parameshwaran           G   9.738881e+09       AN002    Nanjangud
# 3    M Parameshwaran           D   9.738081e+09       AS055       Sargur
# 4    M Parameshwaran           F   9.738081e+09       AH034      HD Kote
# ..               ...         ...            ...         ...          ...
# 126                0           0   0.000000e+00           0            0
# 127                0           0   0.000000e+00           0            0
# 128                0           0   0.000000e+00           0            0
# 129                0           0   0.000000e+00           0            0
# 130                0           0   0.000000e+00           0            0
#
#     Supervisor Name  No of Packets 100  Acre 100      50
# 0       shivakumar0              100.0     100.0   100.0
# 1           siddapa              150.0     150.0   100.0
# 2            prasad               30.0      30.0    40.0
# 3           siddapa              150.0     150.0   200.0
# 4         srinivasa               70.0      70.0    60.0
# ..              ...                ...       ...     ...
# 126               0                0.0       0.0     0.0
# 127               0                0.0       0.0     0.0
# 128               0                0.0       0.0     0.0
# 129               0                0.0       0.0     0.0
# 130               0                0.0       0.0  5641.0
#
# [131 rows x 14 columns]

# %%
season_id=4 
for index, row in df.iterrows():
    aggri_officer_ids= [82, 99]
#     village_name = row['Village Name']
   
    date_string = row['Date']
    date = pd.to_datetime(date_string).date()
       
    print('supervisor_id', row['Supervisor Name'])
    supervisor_id = User.objects.get(username=row['Supervisor Name']).id
    superior_id = UserHierarchyMap.objects.get(season_id=season_id, subordinate=supervisor_id).superior.id
   
    input_combo_obj = InputCombo.objects.get(id=8)
   
    combo_request_obj = ComboIssueRequest(
        request_code=generate_request_code(8),
        season_id=season_id,
        input_combo_id=8,
        quantity_in_numbers=row['No of Packets 100'],
        quantity_for_area=row['Acre 100'],
        expected_date=date,
        issue_rised_date=date,
        max_status_id=6,
        max_status_date=date,
        supervisor_id=User.objects.get(username=row['Supervisor Name']).id,
        senior_supervisor_id=superior_id,
        senior_supervisor_status_id=1,
        senior_supervisor_status_date=date,
        assitant_manager_id=79,
        assitant_manager_status_id=1,
        assitant_manager_status_date=date,
        agri_officer_id=random.choice(aggri_officer_ids),
        agri_officer_status_id = 1,
        agri_officer_status_date=date,
        gm_id = 78,
        gm_status_id =1,
        gm_status_date=date
    )
    combo_request_obj.save()
    if UserProfile.objects.filter(mobile=int(row['Moblie Number'])).exists():
        user_ids = UserProfile.objects.filter(mobile=int(row['Moblie Number'])).values_list('user_id')
        if UserClusterMap.objects.filter(user_id__in=user_ids, unique_code=row['Unique Code'], season_id=season_id):
            agent_id = UserClusterMap.objects.get(user_id__in=user_ids, unique_code=row['Unique Code'], season_id=season_id).user_id
            print(agent_id)
    combo_request_agent_obj = ComboIssueRequestAgentMap(combo_issue_request_id=combo_request_obj.id,
        agent_id=agent_id,
        issue_rised_date=datetime.datetime.now(),
        quantity_in_numbers=row['No of Packets 100'],
        max_status_id=2)
    combo_request_agent_obj.save()
    print(row['Agent code '])
    print(row['Distribution/Return'])
# Out:
# supervisor_id shivakumar0
# 43
# AY009
# Distribution
# supervisor_id siddapa
# 58
# AY018
# Distribution
# supervisor_id prasad
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.563504) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.589813) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.609578) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.629017) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.647279) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.664892) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.681914) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.701896) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.720359) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 153
# AN002
# Distribution
# supervisor_id siddapa
# 122
# AS055
# Distribution
# supervisor_id srinivasa
# 63
# AH034
# Distribution
# supervisor_id prasad
# 173
# AG011
# Distribution
# supervisor_id siddapa
# 145
# AS076
# Distribution
# supervisor_id shivakumar0
# 135
# AS042
# Distribution
# supervisor_id srinivasa
# 91
# AH043
# Distribution
# supervisor_id prasad
# 110
# AN070
# Distribution
# supervisor_id srinivasa
# 203
# AH033
# Distribution
# supervisor_id srinivasa
# 141
# AH064
# Distribution
# supervisor_id siddapa
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.739332) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.767995) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.798587) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.820683) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.842518) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.860558) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.876856) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.894614) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.911880) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.930664) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 90
# AS040
# Distribution
# supervisor_id srinivasa
# 202
# AH032
# Distribution
# supervisor_id srinivasa
# 206
# AH036
# Distribution
# supervisor_id siddapa
# 172
# AG010
# Distribution
# supervisor_id srinivasa
# 139
# AS062
# Distribution
# supervisor_id srinivasa
# 210
# AH040
# Distribution
# supervisor_id siddapa
# 134
# AS074
# Distribution
# supervisor_id srinivasa
# 142
# AS065
# Distribution
# supervisor_id prasad
# 154
# AN003
# Distribution
# supervisor_id siddapa
# 85
# AN041
# Distribution
# supervisor_id prasad
# 48
# AN038
# Distribution
# supervisor_id prasad
# 123
# AN053
# Distribution
# supervisor_id siddapa
# 169
# AG007
# Distribution
# supervisor_id Dudda0
# 182
# AG020
# Distribution
# supervisor_id mahadevappa
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.949997) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.969495) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:22.998129) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:23.033906) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:23.056037) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:23.081191) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-19 05:15:23.101682) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# <ipython-input-4-d0b710e08e1d> in <module>
#       8
#       9     print('supervisor_id', row['Supervisor Name'])
# ---> 10     supervisor_id = User.objects.get(username=row['Supervisor Name']).id
#      11     superior_id = UserHierarchyMap.objects.get(season_id=season_id, subordinate=supervisor_id).superior.id
#      12
#
# ~/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     376             return clone._result_cache[0]
#     377         if not num:
# --> 378             raise self.model.DoesNotExist(
#     379                 "%s matching query does not exist." %
#     380                 self.model._meta.object_name
#
# DoesNotExist: User matching query does not exist.

# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
# google_sheet_url = 'https://docs.google.com/spreadsheets/d/1QxCyP3uVTvUOG7IuhOCx0V-Qp07BVoIhsHBrj8NxkKU/export?format=csv'
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1w1oCUQrlk8ODccERVI02qDndEfcWYkMOkYdLUPPCapY/export?format=csv&sheet={Sheet2}'
                    
r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df = df.fillna(0)
# df = df.head(1)
df

def generate_request_code(input_combo_id):
    code_bank_obj = ComboIssueRequestCodeBank.objects.filter(input_combo_id=input_combo_id)[0]
    last_digit_code = code_bank_obj.last_digit
    new_code = last_digit_code + 1
    value = str(code_bank_obj.input_combo.name) + str(new_code).zfill(3)
    code_bank_obj.last_digit = new_code
    code_bank_obj.save()
    return value

# %%
season_id=4 
for index, row in df.iterrows():
    aggri_officer_ids= [82, 99]
#     village_name = row['Village Name']
   
    date_string = row['Date']
    date = pd.to_datetime(date_string).date()
       
    supervisor_id = User.objects.get(username=row['Supervisor Name']).id
    superior_id = UserHierarchyMap.objects.get(season_id=season_id, subordinate=supervisor_id).superior.id
   
    input_combo_obj = InputCombo.objects.get(id=9)
   
    combo_request_obj = ComboIssueRequest(
        request_code=generate_request_code(9),
        season_id=season_id,
        input_combo_id=9,
        quantity_in_numbers=row['50 Grm Pkt'],
        quantity_for_area=row['0.5 Acre'],
        expected_date=date,
        issue_rised_date=date,
        max_status_id=6,
        max_status_date=date,
        supervisor_id=User.objects.get(username=row['Supervisor Name']).id,
        senior_supervisor_id=superior_id,
        senior_supervisor_status_id=1,
        senior_supervisor_status_date=date,
        assitant_manager_id=79,
        assitant_manager_status_id=1,
        assitant_manager_status_date=date,
        agri_officer_id=random.choice(aggri_officer_ids),
        agri_officer_status_id = 1,
        agri_officer_status_date=date,
        gm_id = 78,
        gm_status_id =1,
        gm_status_date=date
    )
    combo_request_obj.save()
    if UserProfile.objects.filter(mobile=int(row['Moblie Number'])).exists():
        user_ids = UserProfile.objects.filter(mobile=int(row['Moblie Number'])).values_list('user_id')
        if UserClusterMap.objects.filter(user_id__in=user_ids, unique_code=row['Unique Code'], season_id=season_id):
            agent_id = UserClusterMap.objects.get(user_id__in=user_ids, unique_code=row['Unique Code'], season_id=season_id).user_id
            print(agent_id)
    combo_request_agent_obj = ComboIssueRequestAgentMap(combo_issue_request_id=combo_request_obj.id,
        agent_id=agent_id,
        issue_rised_date=datetime.datetime.now(),
        quantity_in_numbers=row['50 Grm Pkt'],
        max_status_id=2)
    combo_request_agent_obj.save()
#     print(row['Agent code '])
    print(row['Distribution/Return'])
# Out:
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-02-25 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:12.909891) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:12.933301) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:12.954806) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:12.977787) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.000205) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.019478) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.039793) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.064339) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.091163) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 43
# Distribution
# 58
# Distribution
# 153
# Distribution
# 122
# Distribution
# 63
# Distribution
# 173
# Distribution
# 145
# Distribution
# 135
# Distribution
# 91
# Distribution
# 110
# Distribution
# 203
# Distribution
# 141
# Distribution
# 90
# Distribution
# 202
# Distribution
# 206
# Distribution
# 172
# Distribution
# 139
# Distribution
# 210
# Distribution
# 134
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.118041) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.139652) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.162812) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.182238) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.200363) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.219072) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.239806) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.262716) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.280767) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.300719) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 142
# Distribution
# 154
# Distribution
# 85
# Distribution
# 48
# Distribution
# 123
# Distribution
# 169
# Distribution
# 182
# Distribution
# 175
# Distribution
# 176
# Distribution
# 199
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.327476) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.357804) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.379749) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.398477) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.417655) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.447505) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.464883) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.484430) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.502030) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.521038) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 171
# Distribution
# 183
# Distribution
# 65
# Distribution
# 184
# Distribution
# 178
# Distribution
# 179
# Distribution
# 170
# Distribution
# 194
# Distribution
# 49
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.543527) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.566987) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.588591) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.611472) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-02-28 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.637168) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.661022) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-02-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.682776) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-05-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.701503) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-07-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.719169) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 121
# Distribution
# 72
# Distribution
# 71
# Distribution
# 51
# Distribution
# 35
# Distribution
# 60
# Distribution
# 74
# Distribution
# 138
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.750234) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.775954) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.797983) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.822233) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.841509) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.863384) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.889630) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.919342) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 55
# Distribution
# 103
# Distribution
# 143
# Distribution
# 44
# Distribution
# Distribution
# 168
# Distribution
# 166
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:13.995362) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.031636) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.060420) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.092477) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.133446) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.155431) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.182089) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 164
# Distribution
# 61
# Distribution
# 181
# Distribution
# 87
# Distribution
# 167
# Distribution
# 41
# Distribution
# 40
# Distribution
# 37
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.209004) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.259154) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.288456) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.312251) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.339796) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.364203) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.387401) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.411452) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Distribution
# 47
# Distribution
# 180
# Distribution
# 173
# Distribution
# 88
# Distribution
# 50
# Distribution
# 59
# Distribution
# 73
# Distribution
# 146
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.444966) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.464590) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.483240) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.500669) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.520508) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.540558) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-08-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.561076) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.586633) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-09-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.616384) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# 182
# Distribution
# 197
# Distribution
# 56
# Distribution
# 31
# Distribution
# 111
# Distribution
# 34
# Distribution
# 165
# Distribution
# 120
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.650585) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.688283) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.714523) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.738859) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.761947) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.780761) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.810056) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-11-03 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# 32
# Distribution
# 144
# Distribution
# 173
# Distribution
# 73
# Distribution
# 88
# Distribution
# 135
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:14.855137) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ...
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-03-18 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# 184
# Distribution
# 202
# Distribution
# 32
# Distribution
# 154
# Distribution
# 90
# Distribution
# 123
# Distribution
# 167
# Distribution
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.066824) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.096387) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-03-31 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.120552) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-07-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.139196) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-09-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.157409) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-11-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.188186) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2022-12-04 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/ruban/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2022-04-26 03:21:15.239843) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"

# %%
User.objects.filter(username="prasad")[0].id
# Out:
# 24

# %%
import pandas
pd.DataFrame(UserFarmerMap.objects.filter(officer_id=24, farmer__season_id=4).values_list('id', 'farmer__seasonal_farmer_code'), columns=['id', 'farmer_code'])
# Out:
#         id farmer_code
# 0    11074    22MNA001
# 1    11075    22MNI001
# 2    11076    22MNI002
# 3    11077    22MNI003
# 4    11078    22MNI004
# ..     ...         ...
# 139  12422    22MNF072
# 140  12427    22MNF073
# 141  12428    22MNF074
# 142  12429    22MNF075
# 143  12430    22MNF076
#
# [144 rows x 2 columns]

# %%
FarmerClusterSeasonMap.objects.get(seasonal_farmer_code='22MNF041').farmer_id
# Out:
# 11275

# %%
for farmer in FarmerClusterSeasonMap.objects.filter(season_id=4):
#     print(farmer.farmer_id)
    cluster_id = farmer.cluster.id
    season_id = 4
    agent_id = AgentFarmerMap.objects.get(farmer_id=farmer.id).agent.id
    officer_id= UserFarmerMap.objects.get(farmer_id=farmer.id).id
    generate_farmer_code(cluster_id, agent_id, officer_id, season_id)
# Out:
# agent_id 123
# 4
# ---------------------------------------------------------------------------
# DoesNotExist                              Traceback (most recent call last)
# <ipython-input-43-e318b44821c5> in <module>
#       5     agent_id = AgentFarmerMap.objects.get(farmer_id=farmer.id).agent.id
#       6     officer_id= UserFarmerMap.objects.get(farmer_id=farmer.id).id
# ----> 7     generate_farmer_code(cluster_id, agent_id, officer_id, season_id)
#
# <ipython-input-42-21e47802a0c9> in generate_farmer_code(cluster_id, agent_id, officer_id, season_id)
#       7     print(season_id)
#       8     agent_name = UserClusterMap.objects.get(user_id=agent_id, season_id=season_id).unique_code.upper()
# ----> 9     officer_name = User.objects.get(id=officer_id).username[0:1].upper()
#      10     # print(cluster_name)
#      11     # print(agent_name)
#
# ~/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Software/virtualenv/ccgb/lib/python3.9/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     376             return clone._result_cache[0]
#     377         if not num:
# --> 378             raise self.model.DoesNotExist(
#     379                 "%s matching query does not exist." %
#     380                 self.model._meta.object_name
#
# DoesNotExist: User matching query does not exist.

# %%
def generate_farmer_code(cluster_id, agent_id, officer_id, season_id):
    season = Season.objects.get(id=season_id).year
    season_name = str(season.strftime("%y"))
    cluster_name = Cluster.objects.get(id=cluster_id).name.upper()
    region_name = Cluster.objects.get(id=cluster_id).notes.upper()
    print('agent_id', agent_id)
    print(season_id)
    agent_name = UserClusterMap.objects.get(user_id=agent_id, season_id=season_id).unique_code.upper()
    print('crossed')
    officer_name = User.objects.get(id=officer_id).username[0:1].upper()
    prefix = season_name + region_name[0] + cluster_name[0] + agent_name[0]
    if IdBank.objects.filter(purpose="farmer", prefix_code=prefix).exists():
        last_code = IdBank.objects.get(purpose="farmer", prefix_code=prefix).last_count
        IdBank.objects.filter(purpose="farmer", prefix_code=prefix).update(last_count=last_code + 1)
    else:
        last_code = 0
        id_bank_obj = IdBank(purpose="farmer", prefix_code=prefix, last_count=1, business_id=1)
        id_bank_obj.save()
    generated_code_number = last_code + 1
    suffix = str(generated_code_number).zfill(3)
    code = str(prefix) + suffix
    return code
