# %% [markdown]
# # SCRIPT FOR UPOADING SEED DISTRIBUTION 2021

# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1xkzCIEflGMhi8ymUBdQpZPZPfjT4ItPSzKeOsUNW2H4/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df = df.fillna(0)

# %%
InputGoods.objects.filter(code='IG21_S0004').delete()
InputGoods.objects.filter(code='IG21_S0005').delete()
InputGoods.objects.filter(code='IC21013').delete()
InputPacketInventory.objects.filter(packet_code='IC21008').delete()
InputPacketInventory.objects.filter(packet_code='IC21009').delete()
InputPacketInventory.objects.filter(packet_code='IC21013').delete()
InputPacketInventory.objects.filter(packet_code='IC21010').delete()
InputPacketInventory.objects.filter(packet_code='IC21011').delete()
ComboIssueRequest.objects.filter(input_combo_id__in=[8,9]).delete()
# Out:
# (6,
#  {'inputdistri.SubStoreIssueLabelAgentMap': 0,
#   'inputdistri.ComboIssueDeleteAgentLog': 0,
#   'inputdistri.ComboIssueAgentInventoryReceipt': 0,
#   'inputdistri.ComboIssueRequestAgentMap': 3,
#   'inputdistri.ComboIssueRequest': 3})

# %%
def generate_request_code(input_combo_id):
    code_bank_obj = ComboIssueRequestCodeBank.objects.filter(input_combo_id=8)[0]
    last_digit_code = code_bank_obj.last_digit
    new_code = last_digit_code + 1
    value = str(code_bank_obj.input_combo.name) + str(new_code).zfill(3)
    code_bank_obj.last_digit = new_code
    code_bank_obj.save()
    return value

def senior_supervisor_id(supervisor_id):
    superior_id = UserHierarchyMap.objects.get(subordinate=supervisor_id).superior_id
    return superior_id

def get_active_season_id():
    season_obj = Season.objects.get(is_active=True)
    return season_obj.id

# %%
@transaction.atomic
def register_agent_inventory(storage_list, combo_issue_request_id, dispatch_date, agri_officer):
    print(storage_list)
    print(combo_issue_request_id)
    print(dispatch_date)
    
    sid = transaction.savepoint()
    try:
        storage_list = storage_list
        for storage in storage_list:
            print('crossed')
            store_quantity = int(storage['entered_qty'])
            storage_obj = InputSubStoreInventory.objects.get(id=storage['id'])
            available_qty = storage_obj.quantity_now
            print('crossed')
            storage_obj.quantity_now = available_qty - int(storage['entered_qty'])
            print('crossed')
            storage_obj.quantity_now_time = datetime.datetime.now()

            storage_obj.save()
            combo_issue_request_obj = ComboIssueRequest.objects.get(id=combo_issue_request_id)
            agents = ComboIssueRequestAgentMap.objects.filter(combo_issue_request_id=combo_issue_request_id)
           
            for agent_combo in agents:
                if store_quantity == 0:
                    break
                if SubStoreIssueLabelAgentMap.objects.filter(agent_id=agent_combo.agent.id, combo_issue_request_agent_map_id=agent_combo.id).exists():
                    label_qty = SubStoreIssueLabelAgentMap.objects.filter(agent_id=agent_combo.agent.id, combo_issue_request_agent_map_id=agent_combo.id).count()
                else:
                    label_qty = 0
                if agent_combo.quantity_in_numbers == label_qty:
                    print('more')
                else:
                    required_qty = agent_combo.quantity_in_numbers - label_qty
                    if required_qty > store_quantity:
                        required_qty = store_quantity
                    if not AgentInventory.objects.filter(combo_issue_request_id=combo_issue_request_id, agent_id=agent_combo.agent.id).exists():
                        agent_inventory_obj = AgentInventory(
                            season_id=get_active_season_id(),
                            combo_issue_request_id=combo_issue_request_id,
                            agent_id=agent_combo.agent.id,
                            date_of_receipt=datetime.datetime.now(),
                            quantity_at_receipt=agent_combo.quantity_in_numbers,
                            quantity_now=agent_combo.quantity_in_numbers,
                            quantity_now_time=datetime.datetime.now(),
                            unit_id=4,
                            price_per_item=10,
                            created_by_id=agri_officer,
                            modified_by_id=agri_officer,
                        )
                        agent_inventory_obj.save()
                    else:
                        agent_inventory_obj = AgentInventory.objects.get(combo_issue_request_id=combo_issue_request_id, agent_id=agent_combo.agent.id)
                    label_from = InputSubStoreInventoryPacketLabel.objects.filter(input_sub_store_inventory_id=storage_obj.id, stock_status_id=1).order_by('id')[0].label
                    if not AgentInventoryStoreLabelRangeMap.objects.filter(agent_inventory_id=agent_inventory_obj.id, input_sub_store_inventory_id=storage_obj.id).exists():
                        agent_inventory_store_lable_map_obj = AgentInventoryStoreLabelRangeMap(agent_inventory_id=agent_inventory_obj.id,
                                                                                               input_sub_store_inventory_id=storage_obj.id,
                                                                                               label_range_from=label_from)
                        agent_inventory_store_lable_map_obj.save()
                    else:
                        agent_inventory_store_lable_map_obj = AgentInventoryStoreLabelRangeMap.objects.get(agent_inventory_id=agent_inventory_obj.id, input_sub_store_inventory_id=storage_obj.id)
                    for i in range(1, required_qty+1):
                        agent_invent_label_obj = InputSubStoreInventoryPacketLabel.objects.filter(input_sub_store_inventory_id=storage_obj.id, stock_status_id=1).order_by('id')[0]
                        agent_invent_label_obj.stock_status_id=2
                        agent_invent_label_obj.save()
                        new_table_obj = SubStoreIssueLabelAgentMap(input_sub_store_inventory_id=storage_obj.id,
                                                                agent_id=agent_combo.agent.id,
                                                                combo_issue_request_agent_map_id=agent_combo.id,
                                                                agent_inventory_id=agent_inventory_obj.id,
                                                                label=agent_invent_label_obj.label,
                                                                created_by_id=agri_officer,
                                                                modified_by_id=agri_officer)
                        new_table_obj.save()
                        label_to = agent_invent_label_obj.label
                    agent_inventory_store_lable_map_obj.label_range_to = label_to
                    agent_inventory_store_lable_map_obj.save()
                    store_quantity -= required_qty
                    print(agent_combo.agent.first_name , ' ', label_from , ' - ', label_to)
            
            if storage_obj.quantity_now == 0:
                storage_obj.label_range_start = '0'
                storage_obj.label_range_end = '0'
            else:
                label_from = InputSubStoreInventoryPacketLabel.objects.filter(input_sub_store_inventory_id=storage_obj.id, stock_status_id=1).order_by('id')[0].label
                storage_obj.label_range_start = label_from
            storage_obj.save()
            combo_issue_request_obj.max_status_id = 8
            combo_issue_request_obj.max_status_date = datetime.datetime.now()
            combo_issue_request_obj.dispatched_by_id = agri_officer
            combo_issue_request_obj.dispatch_status_id = 3
            combo_issue_request_obj.dispatch_date = dispatch_date
            combo_issue_request_obj.save()
#         transaction.savepoint_commit(sid)
        
        print('success')
        print('------------------------')
    except Exception as e:
        print('error on {}'.format(e))
        print('---------------------------problem')
        transaction.savepoint_rollback(sid)

# %%
for index, row in df.iterrows():
    agent_code = row['Agent Code']
    print('run')
    if UserProfile.objects.filter(code = agent_code).exists():
       
        village_name = row['Village Name']
        date_string = row['Date']
        date = pd.to_datetime(date_string).date()

        supervisor_id = User.objects.get(username=row['Supervisor Name']).id
        superior_id = senior_supervisor_id(supervisor_id)
        input_combo_obj = InputCombo.objects.get(id=8)
        combo_request_obj = ComboIssueRequest(request_code=generate_request_code(8),
                                            season_id=3,
                                            input_combo_id=8,
                                            quantity_in_numbers=row['No of Packets 100'],
                                            quantity_for_area=row['Acre 100'],
                                            expected_date=date,
                                            issue_rised_date=date,
                                            max_status_id=6,
                                            max_status_date=date,
                                            supervisor_id=User.objects.get(username=row['Supervisor Name']).id,
                                            senior_supervisor_id=superior_id,
                                            senior_supervisor_status_id=1,
                                            senior_supervisor_status_date=date,
                                            assitant_manager_id=79,
                                            assitant_manager_status_id=1,
                                            assitant_manager_status_date=date,
                                            agri_officer_status_id = 1,
                                            agri_officer_status_date=date,
                                            gm_id = 78,
                                            gm_status_id =1,
                                            gm_status_date=date)

        if senior_supervisor_id == 80:
            combo_request_obj.agri_officer_id=82,
            agri_officer = 82
        else:
            combo_request_obj.agri_officer_id=99
            agri_officer = 99
        combo_request_obj.save()
 
        agent_id = UserProfile.objects.get(code = agent_code).user_id
        combo_request_agent_obj = ComboIssueRequestAgentMap(combo_issue_request_id=combo_request_obj.id,
                                                                    agent_id=agent_id,
                                                                    issue_rised_date=date,
                                                                    quantity_in_numbers=row['No of Packets 100'],
                                                                    max_status_id=2,
                                                                    shop_id=1)

        combo_request_agent_obj.save()
        main_df = pd.DataFrame(list(InputSubStoreInventory.objects.filter(input_store_inventory__input_packet_inventory__input_combo__id__in=[8,9]).order_by('id').values()))
        master_input_dict = []
        new_val = row['No of Packets 100']
        
        for index, row_item in main_df.iterrows():
            print(row_item['id'],row_item['quantity_now'])
            if new_val < row_item['quantity_now'] or new_val == row_item['quantity_now']:
                temp_dict = {}
                temp_dict['id'] = row_item.id
                temp_dict['entered_qty'] = new_val
                master_input_dict.append(temp_dict)
                break;
            else:
                temp_dict = {}
                temp_dict['id'] = row_item.id
                temp_dict['entered_qty'] = row_item['quantity_now']
                master_input_dict.append(temp_dict)
                new_val = new_val - row_item['quantity_now']
        register_agent_inventory(master_input_dict, combo_request_obj.id, date, agri_officer)

print('insterted')
# Out:
# run
# [{'id': 43, 'entered_qty': 53}, {'id': 44, 'entered_qty': 32}]
# 207
# 2021-02-25
# crossed
# crossed
# crossed
# Parameswaran_sargur   S21F186M1  -  S21F1138M1
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.672619) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.682462) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:39.821199) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.822891) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Parameswaran_sargur   S21F1139M1  -  S21F1170M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 80}]
# 208
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:39.931490) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.958244) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:39.960928) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.962469) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:39.966614) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Parameswaran_hd_kote   S21F1171M1  -  S21F1250M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 50}]
# 209
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# Nandisha   S21F1251M1  -  S21F1300M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 65}]
# 210
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.190506) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.214145) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.216871) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.218444) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.222949) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.359028) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.383691) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.386532) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.388082) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.393357) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.587618) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Puttamallappa   S21F1301M1  -  S21F1365M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 40}]
# 211
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.614342) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.616959) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.618386) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.622216) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Mahadeva Prasad   S21F1366M1  -  S21F1405M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 30}]
# 212
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.815715) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.855408) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:40.862569) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.865189) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:40.876443) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.014996) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Praveen Kumar M M   S21F1406M1  -  S21F1435M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 40}]
# 213
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.038463) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.042776) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.044397) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.048449) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.236889) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# B M Virabhadrappa   S21F1436M1  -  S21F1475M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 25}]
# 214
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# H S Yogesh   S21F1476M1  -  S21F1500M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 17}, {'id': 45, 'entered_qty': 58}]
# 215
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.276864) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.281814) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.286084) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.296354) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.383172) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.405645) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.408572) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.410259) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.414602) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.465866) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.467287) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Nagaraju Naika   S21F1501M1  -  S21F1517M1
# crossed
# crossed
# crossed
# Nagaraju Naika   S21F1518M1  -  S21F1575M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 70}]
# 216
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.728559) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.760098) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.763888) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.766550) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.769055) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.770534) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.774334) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Gopala H   S21F1576M1  -  S21F1645M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 60}]
# 217
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.957331) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.982693) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.985361) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.986896) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:41.991014) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.992449) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:41.996280) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Mallaraju   S21F1646M1  -  S21F1705M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 60}]
# 218
# 2021-02-25
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.168642) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.197383) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.199924) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.201410) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.204019) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.205503) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.210414) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Muruga_Sargur   S21F1706M1  -  S21F1765M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 100}]
# 219
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.434516) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.468020) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.472084) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.dispatch_date received a naive datetime (2021-02-26 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.474587) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.479041) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.481375) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.487642) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# K Basappa   S21F1766M1  -  S21F1865M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 160}]
# 220
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.795573) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.821810) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.824814) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.826497) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:42.829378) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.830990) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:42.836111) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Maheshappa   S21F1866M1  -  S21F11025M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 100}]
# 221
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.263649) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.298156) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.301821) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.304134) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.307583) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.309977) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.317198) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Shivakumar   S21F11026M1  -  S21F11125M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 38}, {'id': 46, 'entered_qty': 32}]
# 222
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
#  J Chandrappa   S21F11126M1  -  S21F11163M1
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.672925) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.712336) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.717242) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.720037) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.724366) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.726644) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.732065) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.838250) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.839936) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
#  J Chandrappa   S21F11164M1  -  S21F11195M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 0}, {'id': 46, 'entered_qty': 75}]
# 223
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.944417) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.970938) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.973594) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.975122) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.977626) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.979099) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:43.981614) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.983060) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:43.987142) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Kemparaju_gopalpura   S21F11196M1  -  S21F11270M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 0}, {'id': 46, 'entered_qty': 90}]
# 224
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.204834) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.233322) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.236469) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.238029) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.240982) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.242449) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.244980) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.246447) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField AgentInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.250456) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# Nataraju   S21F11271M1  -  S21F11360M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 0}, {'id': 46, 'entered_qty': 30}]
# 225
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# Basavanna   S21F11361M1  -  S21F11390M1
# success
# ------------------------
# run
# [{'id': 43, 'entered_qty': 0}, {'id': 44, 'entered_qty': 0}, {'id': 45, 'entered_qty': 0}, {'id': 46, 'entered_qty': 50}]
# 226
# 2021-02-26
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.504560) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.540808) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:44.544356) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:44.546164) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# ...
# 2021-03-29
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# crossed
# success
# ------------------------
# insterted
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.713147) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.717705) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.720029) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.724461) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.727670) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.730655) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.732328) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.736212) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.737844) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.740970) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.742687) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.745722) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.747578) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.751072) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.753402) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.758082) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.759607) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.762119) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.expected_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.issue_rised_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.senior_supervisor_status_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.assitant_manager_status_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.agri_officer_status_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.gm_status_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequestAgentMap.issue_rised_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.781818) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.784504) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1390: RuntimeWarning: DateTimeField ComboIssueRequest.dispatch_date received a naive datetime (2021-03-29 00:00:00) while time zone support is active.
#   warnings.warn("DateTimeField %s.%s received a naive datetime "
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.786076) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.788678) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.790158) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.792893) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.794377) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.797006) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.798504) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.801053) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.802689) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.805659) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.807379) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.810240) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.811888) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.814619) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.816293) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.819172) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField InputSubStoreInventory.quantity_now_time received a naive datetime (2021-05-03 20:15:56.820820) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"
# /home/kultivate/Softwares/virtualenv/ccgb/lib/python3.8/site-packages/django/db/models/fields/__init__.py:1448: RuntimeWarning: DateTimeField ComboIssueRequest.max_status_date received a naive datetime (2021-05-03 20:15:56.823656) while time zone support is active.
#   warnings.warn("DateTimeField %s received a naive datetime (%s)"

# %%
main_df = pd.DataFrame(list(InputSubStoreInventory.objects.filter(input_store_inventory__input_packet_inventory__input_combo__id__in=[8,9]).order_by('id').values()))
main_df
# Out:
#    id  season_id  input_store_inventory_id  sub_storage_id section  \
# 0  43          3                        54               1
# 1  44          3                        55               1
# 2  45          3                        56               1
# 3  46          3                        57               1
# 4  47          3                        58               1
# 5  48          3                        59               1
# 6  49          3                        60               1
# 7  50          3                        61               1
# 8  51          3                        62               1
# 9  52          3                        63               1
#
#   sub_section date_of_receipt  quantity_at_receipt  quantity_now  \
# 0                  2021-05-03                  138             0
# 1                  2021-05-03                  379             0
# 2                  2021-05-03                  646             0
# 3                  2021-05-03                  909             0
# 4                  2021-05-03                  391             0
# 5                  2021-05-03                  131             0
# 6                  2021-05-03                  390             0
# 7                  2021-05-03                  251             0
# 8                  2021-05-03                  127             0
# 9                  2021-05-03                  233             0
#
#                  quantity_now_time  unit_id label_range_start label_range_end  \
# 0 2021-05-03 20:15:56.781818+00:00        4                 0               0
# 1 2021-05-03 20:15:56.786076+00:00        4                 0               0
# 2 2021-05-03 20:15:56.790158+00:00        4                 0               0
# 3 2021-05-03 20:15:56.794377+00:00        4                 0               0
# 4 2021-05-03 20:15:56.798504+00:00        4                 0               0
# 5 2021-05-03 20:15:56.802689+00:00        4                 0               0
# 6 2021-05-03 20:15:56.807379+00:00        4                 0               0
# 7 2021-05-03 20:15:56.811888+00:00        4                 0               0
# 8 2021-05-03 20:15:56.816293+00:00        4                 0               0
# 9 2021-05-03 20:15:56.820820+00:00        4                 0               0
#
#    created_by_id  modified_by_id                    time_modified  \
# 0            116             116 2021-05-03 20:15:56.783977+00:00
# 1            116             116 2021-05-03 20:15:56.788176+00:00
# 2            116             116 2021-05-03 20:15:56.792392+00:00
# 3            116             116 2021-05-03 20:15:56.796490+00:00
# 4            116             116 2021-05-03 20:15:56.800561+00:00
# 5            116             116 2021-05-03 20:15:56.805073+00:00
# 6            116             116 2021-05-03 20:15:56.809676+00:00
# 7            116             116 2021-05-03 20:15:56.814034+00:00
# 8            116             116 2021-05-03 20:15:56.818589+00:00
# 9            116             116 2021-05-03 20:15:56.823059+00:00
#
#                       time_created
# 0 2021-05-03 12:52:46.586044+00:00
# 1 2021-05-03 12:52:47.460881+00:00
# 2 2021-05-03 12:52:49.170529+00:00
# 3 2021-05-03 12:52:52.108996+00:00
# 4 2021-05-03 12:52:56.419116+00:00
# 5 2021-05-03 12:52:58.448069+00:00
# 6 2021-05-03 12:52:59.124269+00:00
# 7 2021-05-03 12:53:01.221359+00:00
# 8 2021-05-03 12:53:02.700684+00:00
# 9 2021-05-03 12:53:03.614793+00:00
