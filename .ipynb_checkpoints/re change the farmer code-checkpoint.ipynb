# %%
import re
import datetime
import pandas as pd
import numpy as np
import requests
import io
import json
import random
from random import randint
from base64 import b64encode, b64decode
from django.contrib.auth.hashers import make_password
from django.core.files.base import ContentFile
from decimal import Decimal
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO
    from io import BytesIO
google_sheet_url = 'https://docs.google.com/spreadsheets/d/1HBTh1UQtSpxRIeV8Xhvg303z8nijbhjMO4NvleMT5L0/export?format=csv'

r = requests.get(google_sheet_url)
data = r.content
df = pd.read_csv(BytesIO(data))
local_index = []
df.head(5)
# Out:
#    UNIQUE CODE SUPERVISOR NAME SUPERVISOR USERNAME  UNIQUE CODE.1  \
# 0          1.0        AJITH  S               ajith            1.0
# 1          1.0        AJITH  S               ajith            2.0
# 2          1.0        AJITH  S               ajith            3.0
# 3          1.0        AJITH  S               ajith            4.0
# 4          1.0        AJITH  S               ajith            5.0
#
#      AGENT NAME  AGENT USERNAME UNIQUE CODE TO FARMERS    CLUSTERS CLUSTER_ID  \
# 0   ARASA SETTY      8217357218                GA 01/01  Berambadi          1
# 1  BANGARANAIKA      9980310639                GA 01/02  Berambadi          1
# 2      MAHENDRA  ccgb_kollegala                GA 01/03  Berambadi          1
# 3  MADAPPA  G B      9108390550                GA 01/04  Berambadi          1
# 4       MADAPPA      8548092445               GA  01/05  Berambadi          1
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11 Unnamed: 12
# 0         NaN          NaN          NaN         NaN
# 1         NaN          NaN          NaN         NaN
# 2         NaN          NaN          NaN         NaN
# 3         NaN          NaN          NaN         NaN
# 4         NaN          NaN          NaN         NaN

# %%
# --------------------------------------------
# to know the unmapped cluster farmers
farmers = Farmer.objects.all().order_by('id')
unclustered_farmer_ids = []
agent_unmaped_ids = []
for farmer in farmers:
    if not FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id).exists():
        unclustered_farmer_ids.append(farmer.id)
unclustered_farmer_ids.append(2639)
# unclustered_farmer_ids

# %%
for farmer in Farmer.objects.all().exclude(id__in=unclustered_farmer_ids).order_by('id'):
    print(farmer.id)
    cluster_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].cluster.id
    mapping_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].id
    season_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].season_id
    agent_id = AgentFarmerMap.objects.get(farmer_id=mapping_id).agent.id
    agent_name = AgentFarmerMap.objects.get(farmer_id=mapping_id).agent.username
    if agent_name == '9731636749' or agent_name == '9844840856' or agent_name == '9944318848' or agent_name == '7353104238':
        continue
    print('searching agent first_name:', AgentFarmerMap.objects.get(farmer_id=mapping_id).agent.first_name)
    print('searching agent last_name:', AgentFarmerMap.objects.get(farmer_id=mapping_id).agent.last_name)
    print('searching agent user_name:', AgentFarmerMap.objects.get(farmer_id=mapping_id).agent.username)
    
    officer_name = df[df['AGENT USERNAME']== agent_name]['SUPERVISOR USERNAME'].iloc[0]
    officer_id = User.objects.get(username=officer_name).id
    
    print(farmer.id)
    print('cluster_id :', cluster_id)
    print('map_id: ', mapping_id)
    print('officer_id :', officer_id)
    print('agent_id :', agent_id)
    code = generate_farmer_code(cluster_id, agent_id, officer_id,season_id)
    Farmer.objects.filter(id=farmer.id).update(code=code)
    print('code :', code)
    print('-----------------')
# Out:
# 1
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 1
# cluster_id : 8
# map_id:  224
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA001
# -----------------
# 2
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 2
# cluster_id : 8
# map_id:  225
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA002
# -----------------
# 3
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 3
# cluster_id : 8
# map_id:  226
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA003
# -----------------
# 4
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 4
# cluster_id : 8
# map_id:  227
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA004
# -----------------
# 5
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 5
# cluster_id : 8
# map_id:  228
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA005
# -----------------
# 6
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 6
# cluster_id : 8
# map_id:  229
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA006
# -----------------
# 7
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 7
# cluster_id : 8
# map_id:  230
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA007
# -----------------
# 8
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 8
# cluster_id : 8
# map_id:  231
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA008
# -----------------
# 9
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 9
# cluster_id : 8
# map_id:  232
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA009
# -----------------
# 10
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 10
# cluster_id : 8
# map_id:  233
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA010
# -----------------
# 11
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 11
# cluster_id : 8
# map_id:  234
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA011
# -----------------
# 12
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 12
# cluster_id : 8
# map_id:  235
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA012
# -----------------
# 13
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 13
# cluster_id : 8
# map_id:  236
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA013
# -----------------
# 14
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 14
# cluster_id : 8
# map_id:  237
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA014
# -----------------
# 15
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 15
# cluster_id : 8
# map_id:  238
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA015
# -----------------
# 16
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 16
# cluster_id : 8
# map_id:  239
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA016
# -----------------
# 17
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 17
# cluster_id : 8
# map_id:  240
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA017
# -----------------
# 18
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 18
# cluster_id : 8
# map_id:  241
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA018
# -----------------
# 19
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 19
# cluster_id : 8
# map_id:  242
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA019
# -----------------
# 20
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 20
# cluster_id : 8
# map_id:  243
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA020
# -----------------
# 21
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 21
# cluster_id : 8
# map_id:  244
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA021
# -----------------
# 22
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 22
# cluster_id : 8
# map_id:  245
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA022
# -----------------
# 23
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 23
# cluster_id : 8
# map_id:  246
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA023
# -----------------
# 24
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 24
# cluster_id : 8
# map_id:  247
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA024
# -----------------
# 25
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 25
# cluster_id : 8
# map_id:  248
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA025
# -----------------
# 26
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 26
# cluster_id : 8
# map_id:  249
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA026
# -----------------
# 27
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 27
# cluster_id : 8
# map_id:  250
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA027
# -----------------
# 28
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 28
# cluster_id : 8
# map_id:  251
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA028
# -----------------
# 29
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 29
# cluster_id : 8
# map_id:  252
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA029
# -----------------
# 30
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 30
# cluster_id : 8
# map_id:  253
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA030
# -----------------
# 31
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 31
# cluster_id : 8
# map_id:  254
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA031
# -----------------
# 32
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 32
# cluster_id : 8
# map_id:  255
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA032
# -----------------
# 33
# searching agent first_name: Arasashetty
# searching agent last_name: Kongalashetty
# searching agent user_name: 8217357218
# 33
# cluster_id : 8
# map_id:  256
# officer_id : 22
# agent_id : 31
# 19NAA
# code : 1919NAA033
# -----------------
# 34
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 34
# cluster_id : 8
# map_id:  329
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB001
# -----------------
# 35
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 35
# cluster_id : 8
# map_id:  330
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB002
# -----------------
# 36
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 36
# cluster_id : 8
# map_id:  331
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB003
# -----------------
# 37
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 37
# cluster_id : 8
# map_id:  332
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB004
# -----------------
# 38
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 38
# cluster_id : 8
# map_id:  333
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB005
# -----------------
# 39
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 39
# cluster_id : 8
# map_id:  334
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB006
# -----------------
# 40
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 40
# cluster_id : 8
# map_id:  335
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB007
# -----------------
# 41
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 41
# cluster_id : 8
# map_id:  336
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB008
# -----------------
# 42
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 42
# cluster_id : 8
# map_id:  337
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB009
# -----------------
# 43
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 43
# cluster_id : 8
# map_id:  338
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB010
# -----------------
# 44
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 44
# cluster_id : 8
# map_id:  339
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB011
# -----------------
# 45
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 45
# cluster_id : 8
# map_id:  340
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB012
# -----------------
# 46
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 46
# cluster_id : 8
# map_id:  341
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB013
# -----------------
# 47
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 47
# cluster_id : 8
# map_id:  342
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB014
# -----------------
# 48
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 48
# cluster_id : 8
# map_id:  343
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB015
# -----------------
# 49
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 49
# cluster_id : 8
# map_id:  344
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB016
# -----------------
# 50
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 50
# cluster_id : 8
# map_id:  345
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB017
# -----------------
# 51
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 51
# cluster_id : 8
# map_id:  346
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB018
# -----------------
# 52
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 52
# cluster_id : 8
# map_id:  347
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB019
# -----------------
# 53
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 53
# cluster_id : 8
# map_id:  348
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB020
# -----------------
# 54
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 54
# cluster_id : 8
# map_id:  478
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB021
# -----------------
# 55
# searching agent first_name: Bangaranaika
# searching agent last_name: Siddanaika
# searching agent user_name: 9980310639
# 55
# cluster_id : 8
# map_id:  479
# officer_id : 22
# agent_id : 32
# 19NAB
# code : 1919NAB022
# -----------------
# 56
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 56
# cluster_id : 8
# map_id:  257
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH001
# -----------------
# 57
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 57
# cluster_id : 8
# map_id:  258
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH002
# -----------------
# 58
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 58
# cluster_id : 8
# map_id:  259
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH003
# -----------------
# 59
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 59
# cluster_id : 8
# map_id:  260
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH004
# -----------------
# 60
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 60
# cluster_id : 8
# map_id:  261
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH005
# -----------------
# 61
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 61
# cluster_id : 8
# map_id:  262
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH006
# -----------------
# 62
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 62
# cluster_id : 8
# map_id:  263
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH007
# -----------------
# 63
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 63
# cluster_id : 8
# map_id:  264
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH008
# -----------------
# 64
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 64
# cluster_id : 8
# map_id:  265
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH009
# -----------------
# 65
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 65
# cluster_id : 8
# map_id:  266
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH010
# -----------------
# 66
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 66
# cluster_id : 8
# map_id:  267
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH011
# -----------------
# 67
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 67
# cluster_id : 8
# map_id:  268
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH012
# -----------------
# 68
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 68
# cluster_id : 8
# map_id:  269
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH013
# -----------------
# 69
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 69
# cluster_id : 8
# map_id:  270
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH014
# -----------------
# 70
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 70
# cluster_id : 8
# map_id:  271
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH015
# -----------------
# 71
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 71
# cluster_id : 8
# map_id:  272
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH016
# -----------------
# 72
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 72
# cluster_id : 8
# map_id:  273
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH017
# -----------------
# 73
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 73
# cluster_id : 8
# map_id:  274
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH018
# -----------------
# 74
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 74
# cluster_id : 8
# map_id:  275
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH019
# -----------------
# 75
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 75
# cluster_id : 8
# map_id:  276
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH020
# -----------------
# 76
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 76
# cluster_id : 8
# map_id:  277
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH021
# -----------------
# 77
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 77
# cluster_id : 8
# map_id:  278
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH022
# -----------------
# 78
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 78
# cluster_id : 8
# map_id:  279
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH023
# -----------------
# 79
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 79
# cluster_id : 8
# map_id:  280
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH024
# -----------------
# 80
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 80
# cluster_id : 8
# map_id:  281
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH025
# -----------------
# 81
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 81
# cluster_id : 8
# map_id:  282
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH026
# -----------------
# 82
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 82
# cluster_id : 8
# map_id:  283
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH027
# -----------------
# 83
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 83
# cluster_id : 8
# map_id:  284
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH028
# -----------------
# 84
# searching agent first_name: H N Papanna
# searching agent last_name: Nanjappa
# searching agent user_name: 9945675534
# 84
# cluster_id : 8
# map_id:  480
# officer_id : 22
# agent_id : 34
# 19NAH
# code : 1919NAH029
# -----------------
# 85
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 85
# cluster_id : 8
# map_id:  482
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM001
# -----------------
# 86
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 86
# cluster_id : 8
# map_id:  483
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM002
# -----------------
# 87
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 87
# cluster_id : 8
# map_id:  493
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM003
# -----------------
# 88
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 88
# cluster_id : 8
# map_id:  494
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM004
# -----------------
# 89
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 89
# cluster_id : 8
# map_id:  495
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM005
# -----------------
# 90
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 90
# cluster_id : 8
# map_id:  496
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM006
# -----------------
# 91
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 91
# cluster_id : 8
# map_id:  497
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM007
# -----------------
# 92
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 92
# cluster_id : 8
# map_id:  498
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM008
# -----------------
# 93
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 93
# cluster_id : 8
# map_id:  499
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM009
# -----------------
# 94
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 94
# cluster_id : 8
# map_id:  500
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM010
# -----------------
# 95
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 95
# cluster_id : 8
# map_id:  501
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM011
# -----------------
# 96
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 96
# cluster_id : 8
# map_id:  502
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM012
# -----------------
# 97
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 97
# cluster_id : 8
# map_id:  503
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM013
# -----------------
# 98
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 98
# cluster_id : 8
# map_id:  504
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM014
# -----------------
# 99
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 99
# cluster_id : 8
# map_id:  505
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM015
# -----------------
# 100
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 100
# cluster_id : 8
# map_id:  506
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM016
# -----------------
# 101
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 101
# cluster_id : 8
# map_id:  507
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM017
# -----------------
# 102
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 102
# cluster_id : 8
# map_id:  508
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM018
# -----------------
# 103
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 103
# cluster_id : 8
# map_id:  514
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM019
# -----------------
# 104
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 104
# cluster_id : 8
# map_id:  515
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM020
# -----------------
# 105
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 105
# cluster_id : 8
# map_id:  516
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM021
# -----------------
# 106
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 106
# cluster_id : 8
# map_id:  517
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM022
# -----------------
# 107
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 107
# cluster_id : 8
# map_id:  518
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM023
# -----------------
# 108
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 108
# cluster_id : 8
# map_id:  522
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM024
# -----------------
# 109
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 109
# cluster_id : 8
# map_id:  523
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM025
# -----------------
# 110
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 110
# cluster_id : 8
# map_id:  524
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM026
# -----------------
# 111
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 111
# cluster_id : 8
# map_id:  525
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM027
# -----------------
# 112
# searching agent first_name: Madappa
# searching agent last_name: Gurappa
# searching agent user_name: 8548092445
# 112
# cluster_id : 8
# map_id:  526
# officer_id : 22
# agent_id : 35
# 19NAM
# code : 1919NAM028
# -----------------
# 113
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 113
# cluster_id : 8
# map_id:  527
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM029
# -----------------
# 114
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 114
# cluster_id : 8
# map_id:  528
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM030
# -----------------
# 115
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 115
# cluster_id : 8
# map_id:  529
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM031
# -----------------
# 116
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 116
# cluster_id : 8
# map_id:  530
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM032
# -----------------
# 117
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 117
# cluster_id : 8
# map_id:  531
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM033
# -----------------
# 118
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 118
# cluster_id : 8
# map_id:  532
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM034
# -----------------
# 119
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 119
# cluster_id : 8
# map_id:  533
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM035
# -----------------
# 120
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 120
# cluster_id : 8
# map_id:  534
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM036
# -----------------
# 121
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 121
# cluster_id : 8
# map_id:  535
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM037
# -----------------
# 122
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 122
# cluster_id : 8
# map_id:  536
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM038
# -----------------
# 123
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 123
# cluster_id : 8
# map_id:  537
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM039
# -----------------
# 124
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 124
# cluster_id : 8
# map_id:  538
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM040
# -----------------
# 125
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 125
# cluster_id : 8
# map_id:  539
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM041
# -----------------
# 126
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 126
# cluster_id : 8
# map_id:  540
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM042
# -----------------
# 127
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 127
# cluster_id : 8
# map_id:  541
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM043
# -----------------
# 128
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 128
# cluster_id : 8
# map_id:  542
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM044
# -----------------
# 129
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 129
# cluster_id : 8
# map_id:  543
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM045
# -----------------
# 130
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 130
# cluster_id : 8
# map_id:  544
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM046
# -----------------
# 131
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 131
# cluster_id : 8
# map_id:  545
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM047
# -----------------
# 132
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 132
# cluster_id : 8
# map_id:  546
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM048
# -----------------
# 133
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 133
# cluster_id : 8
# map_id:  547
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM049
# -----------------
# 134
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 134
# cluster_id : 8
# map_id:  548
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM050
# -----------------
# 135
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 135
# cluster_id : 8
# map_id:  549
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM051
# -----------------
# 136
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 136
# cluster_id : 8
# map_id:  550
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM052
# -----------------
# 137
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 137
# cluster_id : 8
# map_id:  551
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM053
# -----------------
# 138
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 138
# cluster_id : 8
# map_id:  552
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM054
# -----------------
# 139
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 139
# cluster_id : 8
# map_id:  553
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM055
# -----------------
# 140
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 140
# cluster_id : 8
# map_id:  554
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM056
# -----------------
# 141
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 141
# cluster_id : 8
# map_id:  555
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM057
# -----------------
# 142
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 142
# cluster_id : 8
# map_id:  556
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM058
# -----------------
# 143
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 143
# cluster_id : 8
# map_id:  558
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM059
# -----------------
# 144
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 144
# cluster_id : 8
# map_id:  559
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM060
# -----------------
# 145
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 145
# cluster_id : 8
# map_id:  560
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM061
# -----------------
# 146
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 146
# cluster_id : 8
# map_id:  561
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM062
# -----------------
# 147
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 147
# cluster_id : 8
# map_id:  562
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM063
# -----------------
# 148
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 148
# cluster_id : 8
# map_id:  563
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM064
# -----------------
# 149
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 149
# cluster_id : 8
# map_id:  564
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM065
# -----------------
# 150
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 150
# cluster_id : 8
# map_id:  565
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM066
# -----------------
# 151
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 151
# cluster_id : 8
# map_id:  509
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM067
# -----------------
# 152
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 152
# cluster_id : 8
# map_id:  510
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM068
# -----------------
# 153
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 153
# cluster_id : 8
# map_id:  511
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM069
# -----------------
# 154
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 154
# cluster_id : 8
# map_id:  512
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM070
# -----------------
# 155
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 155
# cluster_id : 8
# map_id:  566
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM071
# -----------------
# 156
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 156
# cluster_id : 8
# map_id:  567
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM072
# -----------------
# 157
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 157
# cluster_id : 8
# map_id:  568
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM073
# -----------------
# 158
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 158
# cluster_id : 8
# map_id:  569
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM074
# -----------------
# 159
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 159
# cluster_id : 8
# map_id:  570
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM075
# -----------------
# 160
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 160
# cluster_id : 8
# map_id:  571
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM076
# -----------------
# 161
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 161
# cluster_id : 8
# map_id:  572
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM077
# -----------------
# 162
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 162
# cluster_id : 8
# map_id:  573
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM078
# -----------------
# 163
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 163
# cluster_id : 8
# map_id:  574
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM079
# -----------------
# 164
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 164
# cluster_id : 8
# map_id:  575
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM080
# -----------------
# 165
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 165
# cluster_id : 8
# map_id:  576
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM081
# -----------------
# 166
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 166
# cluster_id : 8
# map_id:  577
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM082
# -----------------
# 167
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 167
# cluster_id : 8
# map_id:  578
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM083
# -----------------
# 168
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 168
# cluster_id : 8
# map_id:  579
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM084
# -----------------
# 169
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 169
# cluster_id : 8
# map_id:  580
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM085
# -----------------
# 170
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 170
# cluster_id : 8
# map_id:  581
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM086
# -----------------
# 171
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 171
# cluster_id : 8
# map_id:  582
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM087
# -----------------
# 172
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 172
# cluster_id : 8
# map_id:  583
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM088
# -----------------
# 173
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 173
# cluster_id : 8
# map_id:  584
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM089
# -----------------
# 174
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 174
# cluster_id : 8
# map_id:  585
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM090
# -----------------
# 175
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 175
# cluster_id : 8
# map_id:  586
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM091
# -----------------
# 176
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 176
# cluster_id : 8
# map_id:  587
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM092
# -----------------
# 177
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 177
# cluster_id : 8
# map_id:  588
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM093
# -----------------
# 178
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 178
# cluster_id : 8
# map_id:  589
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM094
# -----------------
# 179
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 179
# cluster_id : 8
# map_id:  590
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM095
# -----------------
# 180
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 180
# cluster_id : 8
# map_id:  591
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM096
# -----------------
# 181
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 181
# cluster_id : 8
# map_id:  592
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM097
# -----------------
# 182
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 182
# cluster_id : 8
# map_id:  593
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM098
# -----------------
# 183
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 183
# cluster_id : 8
# map_id:  594
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM099
# -----------------
# 184
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 184
# cluster_id : 8
# map_id:  595
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM100
# -----------------
# 185
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 185
# cluster_id : 8
# map_id:  596
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM101
# -----------------
# 186
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 186
# cluster_id : 8
# map_id:  597
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM102
# -----------------
# 187
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 187
# cluster_id : 8
# map_id:  598
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM103
# -----------------
# 188
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 188
# cluster_id : 8
# map_id:  599
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM104
# -----------------
# 189
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 189
# cluster_id : 8
# map_id:  600
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM105
# -----------------
# 190
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 190
# cluster_id : 8
# map_id:  601
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM106
# -----------------
# 191
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 191
# cluster_id : 8
# map_id:  602
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM107
# -----------------
# 192
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 192
# cluster_id : 8
# map_id:  603
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM108
# -----------------
# 193
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 193
# cluster_id : 8
# map_id:  604
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM109
# -----------------
# 194
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 194
# cluster_id : 8
# map_id:  605
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM110
# -----------------
# 195
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 195
# cluster_id : 8
# map_id:  606
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM111
# -----------------
# 196
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 196
# cluster_id : 8
# map_id:  607
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM112
# -----------------
# 197
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 197
# cluster_id : 8
# map_id:  608
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM113
# -----------------
# 198
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 198
# cluster_id : 8
# map_id:  609
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM114
# -----------------
# 199
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 199
# cluster_id : 8
# map_id:  610
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM115
# -----------------
# 200
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 200
# cluster_id : 8
# map_id:  611
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM116
# -----------------
# 201
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 201
# cluster_id : 8
# map_id:  612
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM117
# -----------------
# 202
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 202
# cluster_id : 8
# map_id:  613
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM118
# -----------------
# 203
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 203
# cluster_id : 8
# map_id:  614
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM119
# -----------------
# 204
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 204
# cluster_id : 8
# map_id:  615
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM120
# -----------------
# 205
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 205
# cluster_id : 8
# map_id:  616
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM121
# -----------------
# 206
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 206
# cluster_id : 8
# map_id:  617
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM122
# -----------------
# 207
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 207
# cluster_id : 8
# map_id:  618
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM123
# -----------------
# 208
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 208
# cluster_id : 8
# map_id:  619
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM124
# -----------------
# 209
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 209
# cluster_id : 8
# map_id:  620
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM125
# -----------------
# 210
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 210
# cluster_id : 8
# map_id:  621
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM126
# -----------------
# 211
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 211
# cluster_id : 8
# map_id:  622
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM127
# -----------------
# 212
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 212
# cluster_id : 8
# map_id:  623
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM128
# -----------------
# 213
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 213
# cluster_id : 8
# map_id:  624
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM129
# -----------------
# 214
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 214
# cluster_id : 8
# map_id:  625
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM130
# -----------------
# 215
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 215
# cluster_id : 8
# map_id:  626
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM131
# -----------------
# 216
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 216
# cluster_id : 8
# map_id:  627
# officer_id : 22
# agent_id : 36
# 19NAM
# code : 1919NAM132
# -----------------
# 217
# searching agent first_name: Madappa G B
# searching agent last_name: Bellappa
# searching agent user_name: 9108390550
# 217
# cluster_id : 8
# map_id:  628
# officer_id : 22
# ...
# 260
# cluster_id : 8
# map_id:  680
# officer_id : 22
# agent_id : 39
# 19NAM
# code : 1919NAM162
# -----------------
# 261
# searching agent first_name: Manikanta
# searching agent last_name: Shivalingappa
# searching agent user_name: 9743908690
# 261
# cluster_id : 8
# map_id:  681
# officer_id : 22
# agent_id : 39
# 19NAM
# code : 1919NAM163
# -----------------
# 262
# searching agent first_name: Manikanta
# searching agent last_name: Shivalingappa
# searching agent user_name: 9743908690
# 262
# cluster_id : 8
# map_id:  299
# officer_id : 22
# agent_id : 39
# 19NAM
# code : 1919NAM164
# -----------------
# 263
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 263
# cluster_id : 8
# map_id:  633
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS001
# -----------------
# 264
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 264
# cluster_id : 8
# map_id:  634
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS002
# -----------------
# 265
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 265
# cluster_id : 8
# map_id:  635
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS003
# -----------------
# 266
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 266
# cluster_id : 8
# map_id:  636
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS004
# -----------------
# 267
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 267
# cluster_id : 8
# map_id:  637
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS005
# -----------------
# 268
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 268
# cluster_id : 8
# map_id:  638
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS006
# -----------------
# 269
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 269
# cluster_id : 8
# map_id:  639
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS007
# -----------------
# 270
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 270
# cluster_id : 8
# map_id:  640
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS008
# -----------------
# 271
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 271
# cluster_id : 8
# map_id:  641
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS009
# -----------------
# 272
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 272
# cluster_id : 8
# map_id:  642
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS010
# -----------------
# 273
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 273
# cluster_id : 8
# map_id:  643
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS011
# -----------------
# 274
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 274
# cluster_id : 8
# map_id:  644
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS012
# -----------------
# 275
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 275
# cluster_id : 8
# map_id:  645
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS013
# -----------------
# 276
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 276
# cluster_id : 8
# map_id:  646
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS014
# -----------------
# 277
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 277
# cluster_id : 8
# map_id:  647
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS015
# -----------------
# 278
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 278
# cluster_id : 8
# map_id:  648
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS016
# -----------------
# 279
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 279
# cluster_id : 8
# map_id:  649
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS017
# -----------------
# 280
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 280
# cluster_id : 8
# map_id:  650
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS018
# -----------------
# 281
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 281
# cluster_id : 8
# map_id:  651
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS019
# -----------------
# 282
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 282
# cluster_id : 8
# map_id:  652
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS020
# -----------------
# 283
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 283
# cluster_id : 8
# map_id:  653
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS021
# -----------------
# 284
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 284
# cluster_id : 8
# map_id:  654
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS022
# -----------------
# 285
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 285
# cluster_id : 8
# map_id:  655
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS023
# -----------------
# 286
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 286
# cluster_id : 8
# map_id:  656
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS024
# -----------------
# 287
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 287
# cluster_id : 8
# map_id:  657
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS025
# -----------------
# 288
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 288
# cluster_id : 8
# map_id:  658
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS026
# -----------------
# 289
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 289
# cluster_id : 8
# map_id:  659
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS027
# -----------------
# 290
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 290
# cluster_id : 8
# map_id:  660
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS028
# -----------------
# 291
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 291
# cluster_id : 8
# map_id:  358
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS029
# -----------------
# 292
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 292
# cluster_id : 8
# map_id:  359
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS030
# -----------------
# 293
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 293
# cluster_id : 8
# map_id:  360
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS031
# -----------------
# 294
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 294
# cluster_id : 8
# map_id:  361
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS032
# -----------------
# 295
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 295
# cluster_id : 8
# map_id:  362
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS033
# -----------------
# 296
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 296
# cluster_id : 8
# map_id:  363
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS034
# -----------------
# 297
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 297
# cluster_id : 8
# map_id:  364
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS035
# -----------------
# 298
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 298
# cluster_id : 8
# map_id:  365
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS036
# -----------------
# 299
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 299
# cluster_id : 8
# map_id:  366
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS037
# -----------------
# 300
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 300
# cluster_id : 8
# map_id:  367
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS038
# -----------------
# 301
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 301
# cluster_id : 8
# map_id:  368
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS039
# -----------------
# 302
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 302
# cluster_id : 8
# map_id:  369
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS040
# -----------------
# 303
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 303
# cluster_id : 8
# map_id:  370
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS041
# -----------------
# 304
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 304
# cluster_id : 8
# map_id:  371
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS042
# -----------------
# 305
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 305
# cluster_id : 8
# map_id:  372
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS043
# -----------------
# 306
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 306
# cluster_id : 8
# map_id:  373
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS044
# -----------------
# 307
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 307
# cluster_id : 8
# map_id:  374
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS045
# -----------------
# 308
# searching agent first_name: Shanidevara Murthy B K
# searching agent last_name: Krishnaiah
# searching agent user_name: 9900906681
# 308
# cluster_id : 8
# map_id:  375
# officer_id : 22
# agent_id : 40
# 19NAS
# code : 1919NAS046
# -----------------
# 309
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in __get__(self, instance, cls)
#     177         try:
# --> 178             rel_obj = getattr(instance, self.cache_name)
#     179         except AttributeError:
#
# AttributeError: 'FarmerClusterSeasonMap' object has no attribute '_cluster_cache'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3f959d0125b3> in <module>
#       1 for farmer in Farmer.objects.all().exclude(id__in=unclustered_farmer_ids).order_by('id'):
#       2     print(farmer.id)
# ----> 3     cluster_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].cluster.id
#       4     mapping_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].id
#       5     season_id = FarmerClusterSeasonMap.objects.filter(farmer_id=farmer.id)[0].season_id
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in __get__(self, instance, cls)
#     182                 rel_obj = None
#     183             else:
# --> 184                 rel_obj = self.get_object(instance)
#     185                 # If this is a one-to-one relation, set the reverse accessor
#     186                 # cache on the related object to the current instance to avoid
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/fields/related_descriptors.py in get_object(self, instance)
#     157         qs = self.get_queryset(instance=instance)
#     158         # Assuming the database enforces foreign keys, this won't fail.
# --> 159         return qs.get(self.field.get_reverse_related_filter(instance))
#     160
#     161     def __get__(self, instance, cls=None):
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in get(self, *args, **kwargs)
#     372         if self.query.can_filter() and not self.query.distinct_fields:
#     373             clone = clone.order_by()
# --> 374         num = len(clone)
#     375         if num == 1:
#     376             return clone._result_cache[0]
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in __len__(self)
#     230
#     231     def __len__(self):
# --> 232         self._fetch_all()
#     233         return len(self._result_cache)
#     234
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in _fetch_all(self)
#    1119     def _fetch_all(self):
#    1120         if self._result_cache is None:
# -> 1121             self._result_cache = list(self._iterable_class(self))
#    1122         if self._prefetch_related_lookups and not self._prefetch_done:
#    1123             self._prefetch_related_objects()
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in __iter__(self)
#      51         # Execute the query. This will also fill compiler.select, klass_info,
#      52         # and annotations.
# ---> 53         results = compiler.execute_sql(chunked_fetch=self.chunked_fetch)
#      54         select, klass_info, annotation_col_map = (compiler.select, compiler.klass_info,
#      55                                                   compiler.annotation_col_map)
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch)
#     887             cursor = self.connection.cursor()
#     888         try:
# --> 889             cursor.execute(sql, params)
#     890         except Exception as original_exception:
#     891             try:
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      77         start = time()
#      78         try:
# ---> 79             return super(CursorDebugWrapper, self).execute(sql, params)
#      80         finally:
#      81             stop = time()
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/backends/utils.py in execute(self, sql, params)
#      62                 return self.cursor.execute(sql)
#      63             else:
# ---> 64                 return self.cursor.execute(sql, params)
#      65
#      66     def executemany(self, sql, param_list):
#
# ~/Software/virtualenv/ccgb/lib/python3.6/encodings/utf_8.py in decode(input, errors)
#      13 encode = codecs.utf_8_encode
#      14
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      17
#
# KeyboardInterrupt:

# %%
def generate_farmer_code(cluster_id, agent_id, officer_id,season_id):
    season = Season.objects.get(id=season_id).year
    season_name = str(season.strftime('%y'))
    cluster_name = Cluster.objects.get(id=cluster_id).name.upper()
    agent_name = User.objects.get(id=agent_id).first_name.upper()
    officer_name = User.objects.get(id=officer_id).username.upper()
    prefix = season_name + cluster_name[0]  + officer_name[0] + agent_name[0]
    print(prefix)
    if IdBank.objects.filter(purpose='farmer', prefix_code=prefix).exists():
        last_code = IdBank.objects.get(purpose='farmer', prefix_code=prefix).last_count
        IdBank.objects.filter(purpose='farmer', prefix_code=prefix).update(
            last_count = last_code + 1
        )
    else:
        last_code = 0
        id_bank_obj = IdBank(
            purpose = 'farmer',
            prefix_code = prefix,
            last_count = 1,
            business_id=1)
        id_bank_obj.save()
    generated_code_number = last_code + 1
    suffix = str(generated_code_number).zfill(3)
    code = str(prefix) +suffix
    # print(code)
    return code

# %%
idb =1 
for farmer in Farmer.objects.all().exclude(id__in=unclustered_farmer_ids).order_by('id'):
    Farmer.objects.filter(id=farmer.id).update(code=idb)
    idb += 1

# %%
# Out:
# '19'

# %%
for index, row in df.iterrows():
    print('----------------------------------')
    print('agent_name :', row['AGENT NAME'])
    print('cluster_name :', row['CLUSTERS'])
    print('codes', list(AgentFarmerMap.objects.filter(agent__username=row['AGENT USERNAME'], farmer__cluster_id=row['CLUSTER_ID']).values_list('farmer__farmer__code', flat=True)))
# Out:
# ----------------------------------
# agent_name : ARASA SETTY
# cluster_name : Berambadi
# codes ['20BAA059', '20BAA060', '20BAA061', '20BAA062', '20BAA063', '20BAA064', '20BAA065', '20BAA066', '20BAA067', '20BAA068', '20BAA069', '20BAA070', '20BAA071', '20BAA072', '20BAA073', '20BAA074', '20BAA075', '20BAA076', '20BAA077', '20BAA078', '20BAA079', '20BAA080', '20BAA081', '20BAA082', '20BAA083', '20BAA084', '20BAA085', '20BAA086', '20BAA087']
# ----------------------------------
# agent_name : BANGARANAIKA
# cluster_name : Berambadi
# codes ['20BAB235', '20BAB272', '20BAB273', '20BAB274', '20BAB275', '20BAB276', '20BAB277', '20BAB278', '20BAB279', '20BAB280', '20BAB281', '20BAB282', '20BAB283', '20BAB284', '20BAB285', '20BAB286', '20BAB287', '20BAB288', '20BAB289', '20BAB290', '20BAB291', '20BAB292', '20BAB293', '20BAB294', '20BAB295', '20BAB296', '20BAB297', '20BAB298', '20BAB299', '20BAB300', '20BAB301', '20BAB302', '20BAB303', '20BAB304', '20BAB305', '20BAB306', '20BAB307', '20BAB308', '20BAB309', '20BAB310', '20BAB311', '20BAB312', '20BAB313', '20BAB314', '20BAB315', '20BAB316', '20BAB317', '20BAB318', '20BAB319', '20BAB320', '20BAB321', '20BAB322', '20BAB323', '20BAB324', '20BAB325', '20BAB326', '20BAB327', '20BAB328', '20BAB329', '20BAB330', '20BAB331', '20BAB332', '20BAB333', '20BAB334', '20BAB335', '20BAB336', '20BAB337', '20BAB338', '20BAB339', '20BAB340', '20BAB341', '20BAB342']
# ----------------------------------
# agent_name : MAHENDRA
# cluster_name : Berambadi
# codes ['20BAM394', '20BAM387', '20BAM388', '20BAM389', '20BAM390', '20BAM391', '20BAM392', '20BAM393', '20BAM395', '20BAM396', '20BAM397', '20BAM398', '20BAM399']
# ----------------------------------
# agent_name : MADAPPA  G B
# cluster_name : Berambadi
# codes ['20BAM508']
# ----------------------------------
# agent_name : MADAPPA
# cluster_name : Berambadi
# codes ['20BAM386', '20BAM400', '20BAM401', '20BAM402', '20BAM403', '20BAM404', '20BAM405', '20BAM406', '20BAM509', '20BAM510', '20BAM511', '20BAM512', '20BAM513', '20BAM514', '20BAM515', '20BAM516', '20BAM517', '20BAM518', '20BAM519', '20BAM520', '20BAM521', '20BAM522', '20BAM523', '20BAM524', '20BAM525', '20BAM526', '20BAM527', '20BAM528', '20BAM529', '20BAM530', '20BAM531', '20BAM532', '20BAM533', '20BAM534', '20BAM535', '20BAM536', '20BAM537', '20BAM538', '20BAM539', '20BAM540', '20BAM541', '20BAM542', '20BAM543', '20BAM544', '20BAM545', '20BAM546', '20BAM547', '20BAM548', '20BAM549', '20BAM550', '20BAM551', '20BAM552', '20BAM553', '20BAM554', '20BAM555', '20BAM556', '20BAM557', '20BAM558', '20BAM559', '20BAM560', '20BAM561', '20BAM562', '20BAM563']
# ----------------------------------
# agent_name : MADEVAPRASAD B S
# cluster_name : Berambadi
# codes ['20BAM407', '20BAM408', '20BAM409', '20BAM410', '20BAM411', '20BAM412', '20BAM413', '20BAM414', '20BAM415', '20BAM416', '20BAM417', '20BAM418', '20BAM419', '20BAM420', '20BAM421', '20BAM422', '20BAM423', '20BAM424', '20BAM425', '20BAM426', '20BAM427', '20BAM428', '20BAM429', '20BAM430', '20BAM431', '20BAM432', '20BAM433', '20BAM434', '20BAM435', '20BAM436', '20BAM437', '20BAM438', '20BAM439', '20BAM440', '20BAM441', '20BAM442', '20BAM443', '20BAM444', '20BAM445', '20BAM446', '20BAM447', '20BAM448', '20BAM449', '20BAM450', '20BAM451', '20BAM452', '20BAM453', '20BAM454', '20BAM455', '20BAM456', '20BAM457', '20BAM458', '20BAM459', '20BAM460', '20BAM461', '20BAM462', '20BAM463', '20BAM464', '20BAM465', '20BAM466', '20BAM467', '20BAM468', '20BAM469', '20BAM470', '20BAM471', '20BAM472', '20BAM473', '20BAM474', '20BAM475', '20BAM476', '20BAM477', '20BAM478', '20BAM479', '20BAM480', '20BAM481', '20BAM482', '20BAM483', '20BAM484', '20BAM485', '20BAM486', '20BAM487', '20BAM488', '20BAM489', '20BAM490', '20BAM491', '20BAM492', '20BAM493', '20BAM494', '20BAM495', '20BAM496', '20BAM497', '20BAM498', '20BAM499', '20BAM500', '20BAM501', '20BAM502', '20BAM503', '20BAM504', '20BAM505', '20BAM506', '20BAM507']
# ----------------------------------
# agent_name : MAHADEVASWAMY H B
# cluster_name : Berambadi
# codes ['20BAH074', '20BAH075', '20BAH076', '20BAH077', '20BAH078', '20BAH079', '20BAH080', '20BAH081']
# ----------------------------------
# agent_name : S  MANIKANTA
# cluster_name : Berambadi
# codes []
# ----------------------------------
# agent_name : H N PAPPANNA
# cluster_name : Berambadi
# codes ['20BAH073', '20BAH082', '20BAH083', '20BAH084', '20BAH085', '20BAH086', '20BAH087', '20BAH088', '20BAH089', '20BAH090', '20BAH091', '20BAH092', '20BAH093', '20BAH094', '20BAH095', '20BAH096', '20BAH097', '20BAH098', '20BAH099', '20BAH100', '20BAH101', '20BAH102', '20BAH103', '20BAH104', '20BAH105', '20BAH106', '20BAH107', '20BAH108']
# ----------------------------------
# agent_name : SHANIDEVARAMURTHY B K
# cluster_name : Berambadi
# codes ['20BAS330', '20BAS331', '20BAS332', '20BAS333', '20BAS334', '20BAS335', '20BAS336', '20BAS337', '20BAS338', '20BAS339', '20BAS340', '20BAS341', '20BAS342', '20BAS343', '20BAS344', '20BAS345', '20BAS346', '20BAS347', '20BAS348', '20BAS349', '20BAS350', '20BAS351', '20BAS352', '20BAS353', '20BAS354', '20BAS355', '20BAS356', '20BAS357', '20BAS358', '20BAS359', '20BAS360', '20BAS361', '20BAS362', '20BAS363', '20BAS364', '20BAS365', '20BAS366', '20BAS367', '20BAS368', '20BAS369', '20BAS370', '20BAS371', '20BAS372', '20BAS373', '20BAS374', '20BAS375', '20BAS376', '20BAS377', '20BAS378', '20BAS379', '20BAS380', '20BAS381', '20BAS382', '20BAS383', '20BAS384', '20BAS385', '20BAS386', '20BAS387', '20BAS388', '20BAS389', '20BAS390', '20BAS391', '20BAS392', '20BAS393', '20BAS394', '20BAS395', '20BAS396', '20BAS397', '20BAS398', '20BAS399', '20BAS400', '20BAS401', '20BAS402', '20BAS403', '20BAS404', '20BAS405', '20BAS406', '20BAS407', '20BAS408', '20BAS409', '20BAS410', '20BAS411']
# ----------------------------------
# agent_name : SHIVAMAHADEVU
# cluster_name : Berambadi
# codes ['20BAS283', '20BAS284', '20BAS286', '20BAS287', '20BAS288', '20BAS289', '20BAS290', '20BAS292', '20BAS280', '20BAS281', '20BAS291', '20BAS282', '20BAS293', '20BAS295', '20BAS296', '20BAS297', '20BAS298', '20BAS299', '20BAS300', '20BAS301', '20BAS302', '20BAS303', '20BAS304', '20BAS305', '20BAS306', '20BAS307', '20BAS308', '20BAS309', '20BAS310', '20BAS311', '20BAS312', '20BAS313', '20BAS314', '20BAS315', '20BAS316', '20BAS317', '20BAS318', '20BAS319', '20BAS320', '20BAS321', '20BAS322', '20BAS323', '20BAS324', '20BAS325', '20BAS326', '20BAS327', '20BAS328', '20BAS329']
# ----------------------------------
# agent_name : MAHADEVAPPA
# cluster_name : Berambadi
# codes []
# ----------------------------------
# agent_name : BASAVASHETTY
# cluster_name : Berambadi
# codes ['20BAB236', '20BAB237', '20BAB238', '20BAB239', '20BAB240', '20BAB241', '20BAB242', '20BAB243', '20BAB244', '20BAB245', '20BAB246', '20BAB247', '20BAB248', '20BAB249', '20BAB250', '20BAB251', '20BAB252', '20BAB253', '20BAB254', '20BAB255', '20BAB256', '20BAB257', '20BAB258', '20BAB259', '20BAB260', '20BAB261', '20BAB262', '20BAB263', '20BAB264', '20BAB265', '20BAB266', '20BAB267', '20BAB268', '20BAB269', '20BAB270', '20BAB271']
# ----------------------------------
# agent_name : KEMPARAJU
# cluster_name : Berambadi
# codes ['20BAK188', '20BAK135', '20BAK164', '20BAK179', '20BAK143', '20BAK186', '20BAK172', '20BAK156', '20BAK191', '20BAK196', '20BAK182', '20BAK194', '20BAK132', '20BAK147', '20BAK162', '20BAK158', '20BAK144', '20BAK184', '20BAK152', '20BAK142', '20BAK200', '20BAK134', '20BAK151', '20BAK133', '20BAK153', '20BAK149', '20BAK131', '20BAK198', '20BAK180', '20BAK148', '20BAK150', '20BAK154', '20BAK187', '20BAK176', '20BAK138', '20BAK170', '20BAK174', '20BAK197', '20BAK189', '20BAK181', '20BAK146', '20BAK141', '20BAK139', '20BAK173', '20BAK167', '20BAK199', '20BAK155', '20BAK175', '20BAK157', '20BAK177', '20BAK193', '20BAK185', '20BAK159', '20BAK171', '20BAK195', '20BAK201', '20BAK140', '20BAK145', '20BAK183', '20BAK166', '20BAK161', '20BAK137', '20BAK136', '20BAK192', '20BAK178', '20BAK168', '20BAK163', '20BAK169', '20BAK160', '20BAK190', '20BAK165']
# ----------------------------------
# agent_name : Shivamadu
# cluster_name : Berambadi
# codes ['20BAS279', '20BAS285', '20BAS294']
# ----------------------------------
# agent_name : nan
# cluster_name : nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9788066c7754> in <module>
#       3     print('agent_name :', row['AGENT NAME'])
#       4     print('cluster_name :', row['CLUSTERS'])
# ----> 5     print('codes', list(AgentFarmerMap.objects.filter(agent__username=row['AGENT USERNAME'], farmer__cluster_id=row['CLUSTER_ID']).values_list('farmer__farmer__code', flat=True)))
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/manager.py in manager_method(self, *args, **kwargs)
#      83         def create_method(name, method):
#      84             def manager_method(self, *args, **kwargs):
# ---> 85                 return getattr(self.get_queryset(), name)(*args, **kwargs)
#      86             manager_method.__name__ = method.__name__
#      87             manager_method.__doc__ = method.__doc__
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in filter(self, *args, **kwargs)
#     785         set.
#     786         """
# --> 787         return self._filter_or_exclude(False, *args, **kwargs)
#     788
#     789     def exclude(self, *args, **kwargs):
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/query.py in _filter_or_exclude(self, negate, *args, **kwargs)
#     803             clone.query.add_q(~Q(*args, **kwargs))
#     804         else:
# --> 805             clone.query.add_q(Q(*args, **kwargs))
#     806         return clone
#     807
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/sql/query.py in add_q(self, q_object)
#    1248         existing_inner = set(
#    1249             (a for a in self.alias_map if self.alias_map[a].join_type == INNER))
# -> 1250         clause, _ = self._add_q(q_object, self.used_aliases)
#    1251         if clause:
#    1252             self.where.add(clause, AND)
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/sql/query.py in _add_q(self, q_object, used_aliases, branch_negated, current_negated, allow_joins, split_subq)
#    1274                     child, can_reuse=used_aliases, branch_negated=branch_negated,
#    1275                     current_negated=current_negated, connector=connector,
# -> 1276                     allow_joins=allow_joins, split_subq=split_subq,
#    1277                 )
#    1278                 joinpromoter.add_votes(needed_inner)
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/sql/query.py in build_filter(self, filter_expr, branch_negated, current_negated, can_reuse, connector, allow_joins, split_subq)
#    1204             else:
#    1205                 lhs = MultiColSource(alias, targets, sources, field)
# -> 1206             condition = lookup_class(lhs, value)
#    1207             lookup_type = lookup_class.lookup_name
#    1208         else:
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/lookups.py in __init__(self, lhs, rhs)
#      22     def __init__(self, lhs, rhs):
#      23         self.lhs, self.rhs = lhs, rhs
# ---> 24         self.rhs = self.get_prep_lookup()
#      25         if hasattr(self.lhs, 'get_bilateral_transforms'):
#      26             bilateral_transforms = self.lhs.get_bilateral_transforms()
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/fields/related_lookups.py in get_prep_lookup(self)
#     110                 # as we don't get to the direct value branch otherwise.
#     111                 target_field = self.lhs.output_field.get_path_info()[-1].target_fields[-1]
# --> 112                 self.rhs = target_field.get_prep_value(self.rhs)
#     113
#     114         return super(RelatedLookupMixin, self).get_prep_lookup()
#
# ~/Software/virtualenv/ccgb/lib/python3.6/site-packages/django/db/models/fields/__init__.py in get_prep_value(self, value)
#     964         if value is None:
#     965             return None
# --> 966         return int(value)
#     967
#     968     def contribute_to_class(self, cls, name, **kwargs):
#
# ValueError: cannot convert float NaN to integer
